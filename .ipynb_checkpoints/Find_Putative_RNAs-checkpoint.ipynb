# %% [markdown]
# ##### Generate files containing all genic and intergenic regions in reference organism

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from Bio import Entrez, SeqIO, AlignIO, pairwise2, Align, Seq, motifs
from Bio.Seq import Seq
from Bio.SeqFeature import SeqFeature, FeatureLocation
from scipy.stats import binom
import math
import time
from tqdm.auto import tqdm
import random
import copy
from joblib import Parallel, delayed
import os
import shutil
import subprocess
from Bio.Blast import NCBIWWW, NCBIXML
from Bio.Align.Applications import MuscleCommandline
import re
import shutil
from Comparative_Analysis import Sequence_Analysis_Routines as sar
from Comparative_Analysis import Utilities as util
from Comparative_Analysis import Alignment as align
from Comparative_Analysis import Blast_Functions as blastfn
from scipy.stats import chi2
from IPython import display
num_cores = 16
core_numbers = list(range(1, num_cores+1))

project_dir = 'D:/Project_Data/Project_8'
output_dir = project_dir + '/Test'
datasets_dir = project_dir + '/Datasets'
seq_dir = datasets_dir + '/Actinobacteria_Ref_Rep_Lev_Complete'

reference_species = 'NZ_CP102342.1'
tb_species = 'NC_000962.3'

# %% [markdown]
# ##### Parameters for run - Produce data builds dictionaries, etc.   Search region = 'U' Upstream 'D' Downstream.   Use Near Region searches 500 nt up/down of homologous hits.  Use Mycobrowser uses mycobrowser to define inter-feature regions

# %%
produce_data = False
use_near_regions_only = True
search_region = 'U'
use_mycobrowser = False

# %% [markdown]
# #####  Functions and classes

# %%
class Translator:
    def __init__(self):
        self.codon_dict = {}
        with open(datasets_dir + '/Standard_Code.txt', 'r') as f:
       	    for l in f:
                self.codon_dict[str(l[1:4])] = l[5]
    
    def reverse_complement(self, seq_string):
        complement_dict = {'A':'T','C':'G','G':'C','T':'A','N':'N'}
        temp = []
        for char in reversed(seq_string):
            if char in complement_dict:
                temp.append(complement_dict[char])
        else:
                temp.append('A')
        return ''.join(temp)
    
    def translate_sequence(self, input_seq, strand, rf, separate_start_symbol = False, separate_stop_symbol = False):
        output_seq = ''
        if strand == 1:
            seq = input_seq[rf:]
        else:
            seq = self.reverse_complement(input_seq)[rf:]
        for i in range(0,len(seq)-2,3):
            if separate_start_symbol == True and seq[i:(i+3)] in ['ATG','GTG','TTG']:
                output_seq += 'Z'
            elif separate_stop_symbol == True and seq[i:(i+3)] in ['TAG','TGA','TAA']:
                output_seq += 'J'
            else:
                if seq[i:(i+3)] in self.codon_dict:
                    output_seq += self.codon_dict[seq[i:(i+3)]]
                else:
                    output_seq += 'X'
        return output_seq

def list_files(dir):
    r = []
    s = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            if name == '.ipynb_checkpoints':
                pass
            else:
                s.append(name)
    return s

def produce_fasta_file(record_list, output_filename):
    with open(output_filename, 'w',  newline='') as outfile:
        line_length = 60
        for record in tqdm(record_list):
            sequence = record[1]
            lines = []
            sequence_length = len(sequence)
            number_of_lines = math.ceil(sequence_length / line_length)
            lines.append(">" +record[0]+ "\n")
            for i in range(number_of_lines):
                subsequence = sequence[i*line_length:(i+1)*line_length]
                lines.append(subsequence + "\n")
            outfile.write(''.join(lines))

def chunk_list(id_list, num_subsets, subset_num):
    len_ids = len(id_list)
    subset_size = int(len_ids / num_subsets)
    remainder = len_ids % num_subsets
    if subset_num <= remainder:
        ids = id_list[(subset_num - 1) * (subset_size + 1): subset_num * (subset_size + 1)]
    else:
        ids = id_list[len_ids - (num_subsets - (subset_num -1))*subset_size : len_ids - (num_subsets - subset_num)*subset_size]
    return ids


def parse_genome(num_subsets, subset_num, id_list):
    translator = Translator()
    ids = chunk_list(id_list, num_subsets, subset_num)
    temp = []
    for id in ids:
        temp_1 = []
        for genome_record in SeqIO.parse(seq_dir + '/' + id, "genbank"):
            organism_name = genome_record.annotations['organism']
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            organism_accession = organism_name.replace(' ', '_') + '_' + accession_ver
            full_sequence = str(genome_record.seq)            
            if id == filename_dict[tb_species] and use_mycobrowser == True:
                output = []
                features = []
                genome_record = next(SeqIO.parse(seq_dir + '/' + id, "genbank"))
                organism_name = genome_record.annotations['organism']
                accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
                organism_accession = organism_name.replace(' ', '_') + '_' + accession_ver
                full_sequence = str(genome_record.seq)
                mycobrowser_df = pd.read_csv(datasets_dir+'/Mycobrowser_Release_4.csv')
                for i, r in mycobrowser_df.iterrows():
                    #if r['Feature'] == 'CDS':
                    if 1==1:
                        locus_tag = r['Locus']
                        accession_locus = accession_ver + '@' + locus_tag
                        start = int(r['Start'])-1
                        stop = int(r['Stop'])
                        if r['Strand'] == '+':
                            strand = 1
                        else:
                            strand = -1
                        product = r['Product']
                        translation = translator.translate_sequence(full_sequence[start:stop],strand, 0)[:-1]    #Remove stop codon from translation       
                        temp_1.append([organism_name, accession_ver, accession_locus, start, stop, strand, translation, locus_tag, product])     #Mycobrowser is 1-indexed
            else:
                for feature in genome_record.features:
                    a = feature.qualifiers
                    #if feature.type == 'CDS':
                    if feature.type not in ['source','gene']:
                        if a.get("locus_tag")!= None:
                            locus_tag = a.get("locus_tag")[0]
                            accession_locus = accession_ver + '@' + locus_tag
                            translation =  translator.translate_sequence(full_sequence[int(feature.location.start):int(feature.location.end)],int(feature.location.strand), 0)[:-1] 
                            if a.get("product")!= None:
                                product = a.get("product")[0]
                            else:
                                product = 'Product not in annotation'
                            temp_1.append([organism_name, accession_ver, accession_locus, int(feature.location.start), int(feature.location.end), int(feature.location.strand), translation, locus_tag, product])
            temp.append(temp_1)
    return temp

def generate_full_sequence_file(num_subsets, subset_num, id_list):
    ids = chunk_list(id_list, num_subsets, subset_num)
    reference_list = []
    for species in ids:
        for genome_record in SeqIO.parse(seq_dir + '/' + species, "genbank"):
        	feature_info = []
        	accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
        	reference_list.append([accession_ver, str(genome_record.seq)])
    return reference_list

def create_filename_dict(num_subsets, subset_num, id_list):
    ids = chunk_list(id_list, num_subsets, subset_num)
    temp = []
    for id in (ids):
        for genome_record in SeqIO.parse(seq_dir + '/' + id, "genbank"):
            organism_name = genome_record.annotations['organism']
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            temp.append((accession_ver, id))
    return temp

def create_search_regions(num_subsets, subset_num, data_list, search_region):
    data_subset = chunk_list(data_list, num_subsets, subset_num)
    temp = []
    translator = Translator()
    for (accession, filename, start, stop, strand, e_value) in (data_subset):
        for genome_record in SeqIO.parse(seq_dir + '/' + filename, "genbank"):
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            #Multiple sequences in annotation - just use one with appropriate accession
            if not(accession_ver == accession):
                continue
            full_sequence = str(genome_record.seq)
            if search_region == 'D':
                if strand == 1:
                    search_sequence = full_sequence[stop: min(len(full_sequence) - 1, stop + 500)]
                else:
                    search_sequence = translator.reverse_complement(full_sequence[max(start-500, 0):start])
            else:
                if strand == 1:
                    search_sequence = full_sequence[max(0, start - 500): start]
                else:
                    search_sequence = translator.reverse_complement(full_sequence[stop: (stop + 500)])
            temp.append((accession+'/'+str(start)+'-'+str(stop), search_sequence))
    return temp

def align_keep_top_hit_per_species(files_dir, hit_file, alignment_file, output_alignment_file, package, evalue = 1e-5): 
    num_to_keep = 0
    wsl_files_loc = util.wslname(files_dir)
    dict = {}
    if package == 'INFERNAL':
        with open(files_dir + '/' + hit_file, 'r') as f:
            for l in f:
                if not(l[0] == '#'): 
                    a = l.split()
                    accession_id = a[0].split('/')[0]
                    if a[16] == '!':
                        if accession_id in dict:
                            if float(a[15]) < dict[accession_id][1]:
                                dict[accession_id] = (a[0]+'/'+a[7]+'-'+a[8],float(a[15]))
                        else:
                            dict[accession_id] = (a[0]+'/'+a[7]+'-'+a[8],float(a[15]))
    elif package == 'HMMER':
        with open(files_dir + '/' + hit_file, 'r') as f:
            for l in f:
                if not(l[0] == '#'): 
                    a = l.split()
                    accession_id = a[0].split('/')[0]
                    if float(a[12]) < evalue:
                        if accession_id in dict:
                            if float(a[12]) < dict[accession_id][1]:
                                dict[accession_id] = (a[0]+'/'+a[6]+'-'+a[7],float(a[12]))
                        else:
                            dict[accession_id] = (a[0]+'/'+a[6]+'-'+a[7],float(a[12]))
    else:
        pass
    with open(files_dir + '/keep_list.txt', 'w') as f:
        lines = []
        for k, v in dict.items():
            lines.append(v[0] + "\n")
        f.write(''.join(lines))
        num_to_keep = len(lines)
    subprocess.run('wsl cd ' + wsl_files_loc + ' ; esl-alimanip -o '+output_alignment_file + ' --seq-k keep_list.txt '+ alignment_file, shell=True)
    return num_to_keep

def find_features(accession, stop, start):
    output_values = []
    for feature_info in gene_info_dict[accession]:
        start_f = int(feature_info[1])
        stop_f = int(feature_info[2])
        if stop_f - start_f  > 100000:   #Something wrong!
            continue
        start_1 = min(stop, start)
        stop_1 = max(stop, start)
        if stop_1 > start_f and start_1 < stop_f:
            overlap = (min(stop_f, stop_1) - max(start_f, start_1)) / (stop_1 - start_1)
            output_values.append((feature_info, overlap))
    return output_values

# %% [markdown]
# ##### Build filenames dictionary, gene features, full sequence files etc.

# %%
if produce_data == True:
    species_list = list_files(seq_dir)
    species_list = [x for x in species_list if '.gbff' in x]    # Exclude other files generated in directory
    parallel_output = Parallel(n_jobs=-1)(delayed(parse_genome)(num_cores, core_number, species_list) for core_number in core_numbers)
    temp = [item for sublist in parallel_output for item in sublist]
    gene_records = [item for sublist in temp for item in sublist]
    reference_gene_records = [x for x in gene_records if x[1] == reference_species]
    gene_records.sort(key=lambda x: (x[1],x[3]))
    
    filename_dict = {}
    parallel_output = Parallel(n_jobs=-1)(delayed(create_filename_dict)(num_cores, core_number, species_list) for core_number in core_numbers)
    temp = [item for sublist in parallel_output for item in sublist]
    for (accession_ver, filename) in temp:
        filename_dict[accession_ver] = filename
    with open(output_dir + '/filename_dict.pkl', 'wb') as f:
        pickle.dump(filename_dict, f)   
    print("Filenames dictionary generated")
    
    
    gene_info_dict = {}
    for i, record in enumerate(gene_records):
        if record[1] in gene_info_dict:
            gene_info_dict[record[1]].append((record[7],record[3], record[4], (record[7], record[5]), (record[7], record[5]), (record[8], record[8])))
        else:
            gene_info_dict[record[1]] = [(record[7],record[3], record[4], (record[7], record[5]), (record[7], record[5]), (record[8],record[8]))]
        if (i + 1) < len(gene_records):
            next_feature = gene_records[i+1]
            if next_feature[1] == record[1] and next_feature[3] > record[4]:
                gene_info_dict[record[1]].append((record[7] + '_IG', record[4], next_feature[3], (record[7], record[5]), (next_feature[7], next_feature[5]), (record[8], next_feature[8])))
    with open(output_dir + '/gene_info_dict.pkl', 'wb') as f:
        pickle.dump(gene_info_dict, f)   
    print("Gene info generated")
    
    names_dict = {}
    for id in tqdm(species_list):
        for genome_record in SeqIO.parse(seq_dir + '/' + id, "genbank"):
            organism_name = genome_record.annotations['organism']
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            if not(accession_ver in names_dict):
                names_dict[accession_ver] = organism_name
    with open(output_dir + '/names_dict.pkl', 'wb') as f:
        pickle.dump(names_dict, f)   
    print("Names dictionary generated")

    parallel_output = Parallel(n_jobs=-1)(delayed(generate_full_sequence_file)(num_cores, core_number, species_list) for core_number in core_numbers)
    temp = [item for sublist in parallel_output for item in sublist]
    gene_records = [[item[0], item[1]] for item in temp]
    produce_fasta_file(gene_records, seq_dir + '/full_sequences.faa') 
    print("Full sequence file generated")

else:
    with open(output_dir + '/gene_info_dict.pkl', 'rb') as f:
        gene_info_dict = pickle.load(f) 
    with open(output_dir + '/names_dict.pkl', 'rb') as f:
        names_dict = pickle.load(f) 
    with open(output_dir + '/filename_dict.pkl', 'rb') as f:
        filename_dict = pickle.load(f) 

genome_record = next(SeqIO.parse(seq_dir + '/' + filename_dict[reference_species], "genbank"))
product_dict = {}
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None and a.get("product")!=None:
            product_dict[a.get("locus_tag")[0]] = a.get("product")[0]

# %%
#  Produce dataset of feature, upstream and downstream info relating to reference    
features = []
translator = Translator()
genome_record = next(SeqIO.parse(seq_dir + '/' + filename_dict[reference_species], "genbank"))
full_sequence = str(genome_record.seq)
mycobrowser_df = pd.read_csv(datasets_dir+'/Mycobrowser_Release_4.csv')

#for i, r in mycobrowser_df.iterrows():
#    if r['Strand'] == '+':
#        strand = 1
#    else:
#        strand = -1
#    features.append([r['Locus'],r['Start']-1, r['Stop'], strand])

for feature in genome_record.features:
    a = feature.qualifiers
    if feature.type not in ['source','gene']:
        if a.get("locus_tag")!= None:
            locus_tag = a.get("locus_tag")[0]
            features.append([locus_tag, int(feature.location.start), int(feature.location.end), int(feature.location.strand)])
features.sort(key=lambda x: x[1])
feature_info = []
for i, feature in enumerate(features):
    if feature[3] == 1:
        feature_sequence = full_sequence[feature[1]: feature[2]]
    else:
        feature_sequence = translator.reverse_complement(full_sequence[feature[1]: feature[2]])
    exception = 1
    #Upstream
    if feature[1] < feature[2]:  
         if feature[3] == 1:
              if i > 0 and feature[1] > features[i-1][2]:
                  exception = 0
                  utr_coords = (features[i-1][2], feature[1])
                  utr_sequence = full_sequence[features[i-1][2]: feature[1]]
                  utr_length = len(utr_sequence)
         else:
              if i + 1 < len(features) and feature[2] < features[i+1][1]:
                  exception = 0
                  utr_coords = (feature[2], features[i+1][1])
                  utr_sequence =  translator.reverse_complement(full_sequence[feature[2]: features[i+1][1]])
                  utr_length = len(utr_sequence)
    if exception == 1:
         utr_coords = (0,0)
         utr_sequence = ''
         utr_length = 0 
    exception = 1    
    #Downstream
    if feature[1] < feature[2]:  
         if feature[3] == 1:
              if i < len(features) - 1 and feature[2] < features[i+1][1]:
                  exception = 0
                  dtr_coords = (feature[2], features[i+1][1])
                  dtr_sequence = full_sequence[feature[2]: features[i+1][1]]
                  dtr_length = len(dtr_sequence)
         else:
              if i > 0 and features[i-1][2] < feature[1]:
                  exception = 0
                  dtr_coords = (features[i-1][2], feature[1])
                  dtr_sequence =  translator.reverse_complement(full_sequence[features[i-1][2]: feature[1]])
                  dtr_length = len(dtr_sequence)
    if exception == 1:
         dtr_coords = (0,0)
         dtr_sequence = ''
         dtr_length = 0

    feature_info.append([feature[0], feature[1], feature[2], feature_sequence, len(feature_sequence), utr_coords[0], utr_coords[1], utr_sequence, utr_length, dtr_coords[0], dtr_coords[1], dtr_sequence, dtr_length])
genic_intergenic_df = pd.DataFrame(feature_info, columns = ['Locus', 'Start' , 'End', 'Sequence', 'Length', 'Upstream_Start' , 'Upstream_End', 'Upstream_Sequence', 'Upstream_Length', 'Downstream_Start' , 'Downstream_End', 'Downstream_Sequence', 'Downstream_Length'])


#RFAM hits 
temp = pd.read_csv(datasets_dir + '/RFAM_Hits_H37Rv_sorted.csv')
temp_out = []
for i, r in temp.iterrows():
    if r['strand'] == '+':
        start = int(r['seq from'])
        end = int(r['seq to'])
        sequ = full_sequence[start: end]
    else:
        start = int(r['seq to'])
        end = int(r['seq from'])
        sequ = translator.reverse_complement(full_sequence[start:end])
    seq_len = len(sequ)
    temp_out.append([str(r['#idx']), 0, 0, '',0,start, end, sequ, seq_len])
rfam_df = pd.DataFrame(temp_out, columns = ['Locus', 'Start' , 'End', 'Sequence', 'Length', 'Upstream_Start' , 'Upstream_End', 'Upstream_Sequence', 'Upstream_Length'])

# %%
# Loop 

hmmer_eval =  1e-5
hm_model_file = 'hmm.hmm'
for i, r in genic_intergenic_df.iterrows():
    #if (r['Start'] < 0):  
    if not(r['Locus'] in ['NQ428_RS04050']):
        continue
    if ((search_region == 'D' and r['Downstream_Length'] < 40) or (search_region == 'U' and r['Upstream_Length'] <40)):
        continue
    locus_id = r['Locus']
    print(locus_id)
    results_dir = output_dir + '/' + locus_id
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
 
    if use_near_regions_only == True:
         if r['Length'] < 60:
             continue
         query_file = 'genic_region.faa'
         hmmer_eval =  1e-5
         homolog_hits = []
         sequence_list = [[r['Locus'], r['Sequence']]]
         produce_fasta_file(sequence_list, results_dir + '/' + query_file)
         blastfn.nhmmer_search_sequence(results_dir, query_file, seq_dir, 'full_sequences.faa', 'halign_0.sto', 'houtput.txt', 'hsummary_0.txt', hmmer_eval) 
         if not os.path.exists(results_dir +'/hsummary_0.txt'):
             continue
         num_to_keep = align_keep_top_hit_per_species(results_dir, 'hsummary_0.txt', 'halign_0.sto', 'halign_bh_0.sto', 'HMMER', hmmer_eval)
         if num_to_keep ==0:
                continue
         with open(output_dir + '/' + locus_id + '/hsummary_0.txt', 'r') as f:  
             for l in f:
                 if (not ('#' in l)):
                     a = l.split()
                     accession = a[0]
                     species = names_dict[a[0]]
                     seq_from = int(a[6])
                     seq_to = int(a[7])
                     if a[11] == '+':
                         strand = 1
                     else:
                         strand = -1
                     e_value = float(a[12])
                     start = min(seq_from,seq_to) - 1
                     stop = max(seq_from, seq_to)
                     if e_value < 1e-10:
                         for feature in (find_features(accession, start, stop)):
                             if feature[1] > 0.9 and not (feature[0][0][-2:] == 'IG'):
                                 homolog_hits.append((accession, filename_dict[accession], start, stop, strand, e_value))
                                 break

         parallel_output = Parallel(n_jobs=-1)(delayed(create_search_regions)(num_cores, core_number, homolog_hits, search_region) for core_number in core_numbers)

         temp = [item for sublist in parallel_output for item in sublist]
         if len(temp) < 5:
             continue
         else:
             produce_fasta_file(temp, results_dir + '/search_regions.faa')  

    hmmer_eval =  1e-5
    hmmer_eval_2 = 1e-5
    infernal_eval = 1e-5
    query_file = 'intergenic_region.faa'
    hm_model_file = 'hmm.hmm'
    cm_model_file = 'cm.cm'
    if use_near_regions_only == True:
         comparison_dir = results_dir
         comparison_regions = 'search_regions.faa'
    else:
         comparison_dir = seq_dir
         comparison_regions = 'full_sequences.faa'



    if ((search_region == 'D' and r['Downstream_Length'] >= 40) or (search_region == 'U' and r['Upstream_Length'] >=40)):
        if search_region == 'D':
            sequence_list = [[r['Locus'], r['Downstream_Sequence']]]
        else:
            sequence_list = [[r['Locus'], r['Upstream_Sequence']]]
        produce_fasta_file(sequence_list, results_dir + '/' + query_file)

        blastfn.nhmmer_search_sequence(results_dir, query_file, comparison_dir, comparison_regions, 'align_0.sto', 'output.txt', 'hsummary.txt', hmmer_eval_2) 
        if not os.path.exists(results_dir +'/hsummary.txt'):
            continue
        num_to_keep = align_keep_top_hit_per_species(results_dir, 'hsummary.txt', 'align_0.sto', 'align_bh_0.sto', 'HMMER', hmmer_eval)
        if num_to_keep == 0:
            continue
        for i in range(3):
            blastfn.hmmer_build(results_dir, 'align_bh_'+str(i)+'.sto' ,hm_model_file)
            blastfn.nhmmer_search_model(results_dir, hm_model_file, comparison_dir, comparison_regions, 'align_'+str(i+1)+'.sto', 'output.txt', 'hsummary_'+str(i+1)+'.txt', hmmer_eval_2)      #seq_dir, 'full_sequences.faa'
            if not os.path.exists(results_dir +'/hsummary_'+str(i+1)+'.txt'):
                continue
            num_to_keep = align_keep_top_hit_per_species(results_dir, 'hsummary_'+str(i+1)+'.txt', 'align_'+str(i+1)+'.sto', 'align_bh_'+str(i+1)+'.sto', 'HMMER', hmmer_eval_2)
            if num_to_keep == 0:
                continue
            if not os.path.exists(results_dir +'/align_bh_'+str(i+1)+'.sto'):
                continue
            blastfn.run_rscape(results_dir, 'align_bh_'+str(i+1)+'.sto', 'rscape_1')
    

    e_values = []    
    if os.path.exists(results_dir + '/rscape_1.cov'):
         with open(results_dir +  '/rscape_1.cov', 'r') as f:  
             num_pairs = 0
             for l in f:
                 if (not ('#' in l)):
                     a = l.split()
                     if len(a) > 3 and abs(int(a[2])-int(a[1])) > 3:    # Exclude covarying pairs less than 3 bp apart)
                         e_values.append(float(a[4]))
                         num_pairs +=1
     
    if len(e_values) > 1:

        blastfn.infernal_build_and_calib(results_dir, 'align_bh_3.sto' ,'cm_1.cm', False)
        blastfn.infernal_search(results_dir, 'cm_1.cm', comparison_dir, comparison_regions, 'search_1.sto', 'search_hits_1.txt', 'summary_1.txt', infernal_eval) 
        if os.path.getsize(results_dir + '/search_hits_1.txt') > 1e8:
            continue
        num_to_keep = align_keep_top_hit_per_species(results_dir, 'summary_1.txt', 'search_1.sto', 'search_bh_1.sto', 'INFERNAL', infernal_eval)
        if num_to_keep == 0:
            continue
        blastfn.run_rscape(results_dir, 'search_bh_1.sto', 'rscape_1')
        
       
        #2
        blastfn.infernal_build_and_calib(results_dir, 'rscape_1.cacofold.R2R.sto' ,'cm_2.cm')
        #blastfn.infernal_build_and_calib(results_dir, 'search_bh_1.sto' ,'cm_2.cm')

        blastfn.infernal_search(results_dir, 'cm_2.cm', comparison_dir, comparison_regions, 'search_2.sto', 'search_hits_2.txt', 'summary_2.txt', infernal_eval) 
        if os.path.getsize(results_dir + '/search_hits_2.txt') > 1e8:
            continue
        align_keep_top_hit_per_species(results_dir, 'summary_2.txt', 'search_2.sto', 'search_bh_2.sto', 'INFERNAL', infernal_eval)
        blastfn.run_rscape(results_dir, 'search_bh_2.sto', 'rscape_2')

       #3
    
        blastfn.infernal_build_and_calib(results_dir, 'rscape_2.cacofold.R2R.sto' ,'cm_3.cm')
        #infernal_build_and_calib(results_dir, 'search_bh_2.sto' ,'cm_3.cm')
        blastfn.infernal_search(results_dir, 'cm_3.cm', comparison_dir, comparison_regions, 'search_3.sto', 'search_hits_3.txt', 'summary_3.txt', infernal_eval) 
        if os.path.getsize(results_dir + '/search_hits_3.txt') > 1e8:
            continue
        align_keep_top_hit_per_species(results_dir, 'summary_3.txt', 'search_3.sto', 'search_bh_3.sto', 'INFERNAL', infernal_eval)
        blastfn.run_rscape(results_dir, 'search_bh_3.sto', 'rscape_3')

       #Final

        blastfn.infernal_build_and_calib(results_dir, 'rscape_3.cacofold.R2R.sto' ,'cm_4.cm')
        blastfn.infernal_search(results_dir, 'cm_4.cm', comparison_dir, comparison_regions, 'final_search.sto', 'final_search.txt', 'final_summary.txt', infernal_eval)
# Out:
# NQ428_RS04050
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/422 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
genome_record = next(SeqIO.parse(seq_dir + '/' + reference_species_filename, "genbank"))
product_dict = {}
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None and a.get("product")!=None:
            product_dict[a.get("locus_tag")[0]] = a.get("product")[0]

# %%
def display_structure(locus):
    if os.path.exists(screen_dir + '/' + locus + '/rscape_3.cacofold.R2R.sto.svg'):
                return display.SVG(filename =screen_dir + '/' + locus + '/rscape_3.cacofold.R2R.sto.svg')

# %%
screen_dir = project_dir + '/R_Scape_Results_Smegmatis'
seed_species = 'NZ_CP102342.1'
tb_species = 'NC_000962.3' 
screen_filename = filename_dict[seed_species]
tb_filename = filename_dict[tb_species]
genome_record = next(SeqIO.parse(seq_dir + '/' + screen_filename, "genbank"))
product_dict = {}
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None and a.get("product")!=None:
            product_dict[a.get("locus_tag")[0]] = a.get("product")[0]

seed_position_dict = {}
genome_record = next(SeqIO.parse(seq_dir + '/' + screen_filename, "genbank"))
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None:
            seed_position_dict[a.get("locus_tag")[0]] = (int(feature.location.start),int(feature.location.end),int(feature.location.strand))

tb_position_dict = {}
genome_record = next(SeqIO.parse(seq_dir + '/' + tb_filename, "genbank"))
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None:
            seed_position_dict[a.get("locus_tag")[0]] = (int(feature.location.start),int(feature.location.end),int(feature.location.strand))

seq_ids = util.list_dirs(screen_dir)
for id in seq_ids:
    if os.path.exists(screen_dir + '/' + str(id) + '/rscape_1.cov'):
        with open(screen_dir + '/' + str(id) + '/rscape_1.cov', 'r') as f:  
            num_pairs = 0
            e_values = []
            for l in f:
                if (not ('#' in l)):
                    a = l.split()
                    if len(a) > 6 and abs(int(a[2])-int(a[1])) > 3:    # Exclude covarying pairs less than 3 bp apart)
                        e_values.append(float(a[4]))
                        num_pairs +=1
        if len(e_values) > 0:
            tot = sum([math.log(x) for x  in e_values])
            num = len(e_values)
            combined_e_value = 1-chi2.cdf(-2*tot, 2*num)
        else:
            combined_e_value = 999
        if combined_e_value < 1e-5:
            with open(screen_dir + '/' + str(id) + '/align_bh_3.sto', 'r') as g:  
                species_list = []
                tb_loc = 'None'
                ref_loc = 'None'
                for l in g:
        
                    if len(l) > 1 and (not ('#' in l)):
                        species_list.append(l.split()[0])
                        if tb_species in l:
                            tb_loc = (l.split()[0].split('/')[1:])

                        if seed_species in l:
                            ref_loc = (l.split()[0].split('/')[1:])
                num_species = len(set(species_list))
                if os.path.exists(screen_dir + '/' + str(id) + '/rscape_3.cacofold.R2R.sto.svg'):
                    structure_plotted = True
                    print(id, product_dict[id], num_species, num_pairs, combined_e_value, ref_loc, tb_loc, structure_plotted, seed_position_dict[id], find_features(tb_species, int(tb_loc[0].split('-')[0]), int(tb_loc[0].split('-')[1])))
# Out:
# NQ428_RS03880 thiamine phosphate synthase 184 6 3.7392444696138227e-10 ['879598-880282', '367-487'] ['500357-501009', '367-461'] True (879598, 880282, -1) [(('Rv0413', 499712, 500366, ('Rv0413', 1), ('Rv0413', 1), ('8-oxo-dGTP diphosphatase', '8-oxo-dGTP diphosphatase')), 0.013803680981595092), (('Rv0414c', 500349, 501018, ('Rv0414c', -1), ('Rv0414c', -1), ('thiamine-phosphate synthase', 'thiamine-phosphate synthase')), 1.0)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8912/14482322.py in <module>
#      63                 if os.path.exists(screen_dir + '/' + str(id) + '/rscape_3.cacofold.R2R.sto.svg'):
#      64                     structure_plotted = True
# ---> 65                     print(id, product_dict[id], num_species, num_pairs, combined_e_value, ref_loc, tb_loc, structure_plotted, seed_position_dict[id], find_features(tb_species, int(tb_loc[0].split('-')[0]), int(tb_loc[0].split('-')[1])))
#      66
#      67
#
# ValueError: invalid literal for int() with base 10: 'N'

# %%
display_structure('NQ428_RS03930')

# %%
NQ428_RS06720  NQ428_RS01255
# Out:
#   File "C:\Users\nicho\AppData\Local\Temp/ipykernel_8912/2839845799.py", line 1
#     NQ428_RS06720  NQ428_RS01255
#                    ^
# SyntaxError: invalid syntax

# %%
# Out:
# 'GCF_000195955.2_ASM19595v2_genomic.gbff'

# %%
species = 'NZ_CP102342.1'
reference_list = []
for genome_record in SeqIO.parse(seq_dir + '/' + filename_dict[species], "genbank"):
        	accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
        	reference_list.append([accession_ver, str(genome_record.seq)])
util.produce_fasta_file(reference_list, project_dir+'/'+'M.smegmatis_sequence.faa')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 18.80it/s]

# %%
filename_dict[ 'NZ_CP102342.1']
# Out:
# 'GCF_024600175.1_ASM2460017v1_genomic.gbff'

# %%
names_dict['NZ_AP022619.1']
# Out:
# 'Mycobacterium paraseoulense'

# %%
screen_dir = project_dir + '/R_Scape_Results_Smegmatis'
#screen_dir = project_dir + '/R_Scape_Initial_Screen_V2'
seed_species = 'NZ_CP102342.1'
#seed_species = 'NC_000962.3' 
tb_species = 'NC_000962.3' 
#tb_species = 'NZ_CP102342.1'
screen_filename = filename_dict[seed_species]
genome_record = next(SeqIO.parse(seq_dir + '/' + screen_filename, "genbank"))
product_dict = {}
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None and a.get("product")!=None:
            product_dict[a.get("locus_tag")[0]] = a.get("product")[0]

ref_position_dict = {}
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None:
            ref_position_dict[a.get("locus_tag")[0]] = (int(feature.location.start),int(feature.location.end),int(feature.location.strand))

seq_ids = util.list_dirs(screen_dir)
for id in seq_ids:
    species_list = []
    if os.path.exists(screen_dir + '/' + str(id) + '/hsummary_3.txt'):
        with open(screen_dir + '/' + str(id) + '/hsummary_3.txt', 'r') as f:  
            num_sig = 0
            for l in f:
                if (not ('#' in l)):
                    a = l.split()
                    if float(a[12]) < 1e-10:
                        num_sig +=1
        if num_sig > 30:
            with open(screen_dir + '/' + str(id) + '/hsummary_3.txt', 'r') as g:  
                tb_loc = 'None'
                ref_loc = 'None'
                tb_eval = 999
                ref_eval= 999
                for l in g:
                    if len(l) > 1 and (not ('#' in l)):
                        species_list.append(l.split()[0])
                        if tb_species in l:
                            temp_tb_loc = (l.split()[0].split('/')[1:])
                            e_val =  float(l.split()[12]) 
                            if  e_val < tb_eval:
                                tb_loc = temp_tb_loc
                                tb_eval = e_val
                        if seed_species in l:
                            temp_ref_loc = (l.split()[0].split('/')[1:])
                            e_val =  float(l.split()[12]) 
                            if  e_val < ref_eval:
                                ref_loc = temp_ref_loc
                                ref_eval = e_val
                num_species = len(set(species_list))
                if os.path.exists(screen_dir + '/' + str(id) + '/rscape_3.cacofold.R2R.sto.svg'):
                    structure_plotted = True
                print(id, product_dict[id], num_sig, num_species, ref_loc, tb_loc, structure_plotted)
# Out:
# NQ428_RS00025 DNA topoisomerase (ATP-hydrolyzing) subunit B 102 122 ['4590-6618'] ['5239-7267'] True
# NQ428_RS00045 tRNA-Ala 57 95 ['10293-10365'] None True
# NQ428_RS00120 PH domain-containing protein 89 89 ['45851-46260'] ['13154-13557'] True
# NQ428_RS00165 FHA domain-containing protein 85 101 ['55824-56292'] ['23269-23737'] True
# NQ428_RS00170 DUF3662 domain-containing protein 95 109 ['56427-57873'] ['24709-25427'] True
# NQ428_RS00175 tRNA-Leu 95 107 ['58143-58225'] ['25644-25726'] True
# NQ428_RS00245 WhiB family transcriptional regulator 60 65 ['70232-70526'] ['4338198-4338440'] True
# NQ428_RS00250 helix-turn-helix domain-containing protein 39 42 ['70909-71689'] None True
# NQ428_RS00315 WXG100 family type VII secretion target 52 58 ['86995-87298'] ['4352273-4352575'] True
# NQ428_RS00345 hypothetical protein 52 64 ['94606-95338'] ['4357631-4358315'] True
# NQ428_RS00350 IS1634-like element IS1549 family transposase 235 260 ['2890665-2892132'] None True
# NQ428_RS00360 IS1634-like element IS1549 family transposase 235 260 ['2890665-2892132'] None True
# NQ428_RS00410 type VII secretion system ESX-1 serine protease mycosin MycP1 32 36 ['105982-107333'] None True
# NQ428_RS00575 alpha/beta hydrolase 69 94 ['140282-141146'] None True
# NQ428_RS00580 CGNR zinc finger domain-containing protein 46 63 ['141230-141731'] None True
# NQ428_RS00590 TetR/AcrR family transcriptional regulator 76 101 ['141967-142627'] ['186790-187412'] True
# NQ428_RS00640 GntR family transcriptional regulator 82 85 ['150429-151122'] ['194137-194772'] True
# NQ428_RS00645 fatty-acid--CoA ligase FadD5 82 86 ['151271-152906'] ['195044-196622'] True
# NQ428_RS00650 ABC transporter permease 87 90 ['153098-153899'] ['196861-197658'] True
# NQ428_RS00990 ISL3-like element IS1096 family transposase 341 430 ['227949-229272'] None True
# NQ428_RS01030 phosphodiester glycosidase family protein 70 90 ['236060-237149'] ['209703-210761'] True
# NQ428_RS01165 IS1380-like element ISMsm3 family transposase 185 287 ['6227987-6229394'] None True
# NQ428_RS01185 MMPL family transporter 57 89 ['270076-272941'] ['238391-241292'] True
# NQ428_RS01190 hemophore 71 82 ['273262-273844'] ['241507-241922'] True
# NQ428_RS01195 heme-binding protein 40 48 ['274013-274394'] None True
# NQ428_RS01240 tRNA (guanosine(46)-N7)-methyltransferase TrmB 90 100 ['284218-285028'] ['248149-248835'] True
# NQ428_RS01245 hypothetical protein 43 43 ['285145-286186'] ['249047-250073'] True
# NQ428_RS01255 phosphoenolpyruvate carboxykinase (GTP) 96 141 ['287806-289633'] ['251781-253596'] True
# NQ428_RS01420 TIGR03364 family FAD-dependent oxidoreductase 40 43 ['318953-320069'] None True
# NQ428_RS01475 aromatic ring-hydroxylating dioxygenase subunit alpha 37 54 ['329278-330544'] None True
# NQ428_RS01565 DUF3068 domain-containing protein 93 110 ['350874-352071'] ['271685-272853'] True
# NQ428_RS01570 acyltransferase family protein 97 114 ['352311-353430'] ['273177-274234'] True
# NQ428_RS01840 3-oxoacyl-ACP reductase 83 170 ['414922-416275'] ['290664-292011'] True
# NQ428_RS01845 acetyl-CoA C-acetyltransferase 98 179 ['416355-417654'] ['292203-293493'] True
# NQ428_RS01885 MmpS family protein 36 49 ['425344-425764'] None True
# NQ428_RS01960 ISL3-like element IS1096 family transposase 332 401 ['445305-446628'] None True
# NQ428_RS01970 ISL3-like element IS1096 family transposase 343 445 ['447570-448893'] None True
# NQ428_RS02000 YciI family protein 149 224 ['469071-469481'] None True
# NQ428_RS02010 acyl-CoA dehydrogenase 101 116 ['470707-472544'] ['293799-295633'] True
# NQ428_RS02015 dihydrodipicolinate reductase 34 34 ['472781-473870'] None True
# NQ428_RS02080 hypothetical protein 93 96 ['498716-499013'] ['301742-302028'] True
# NQ428_RS02085 isocitrate lyase/phosphoenolpyruvate mutase family protein 57 62 ['499277-500045'] None True
# NQ428_RS02095 Hsp20/alpha crystallin family protein 35 73 ['500705-501131'] ['302177-302652'] True
# NQ428_RS02110 nitrite reductase large subunit NirB 76 117 ['503707-506287'] ['302910-305422'] True
# NQ428_RS02140 NarK/NasA family nitrate transporter 81 238 ['510958-512358'] ['312825-314151'] True
# NQ428_RS02155 allophanate hydrolase subunit 1 34 80 ['514039-514703'] ['315785-316435'] True
# NQ428_RS02160 queuosine precursor transporter 32 73 ['514777-515398'] None True
# NQ428_RS02170 putative sulfate exporter family transporter 47 76 ['516451-517588'] None True
# NQ428_RS02230 gluconokinase 48 70 ['529359-529872'] None True
# NQ428_RS02235 FCD domain-containing protein 49 74 ['529997-530732'] None True
# NQ428_RS02300 L-lysine exporter 153 290 ['546148-546749'] ['2230010-2230593'] True
# NQ428_RS02600 SDR family oxidoreductase 43 47 ['613324-614026'] None True
# NQ428_RS02640 MarR family transcriptional regulator 33 111 ['619847-620340'] None True
# NQ428_RS02875 anti-sigma factor antagonist 66 74 ['664777-665227'] ['608072-608486'] True
# NQ428_RS02975 TetR/AcrR family transcriptional regulator 61 70 ['686060-686690'] ['329719-330315'] True
# NQ428_RS02980 VOC family protein 62 83 ['686804-687404'] ['330421-330982'] True
# NQ428_RS03005 TetR/AcrR family transcriptional regulator 81 102 ['691569-692182'] ['331050-331646'] True
# NQ428_RS03010 oxygenase MpaB family protein 81 109 ['692260-693160'] ['331772-332665'] True
# NQ428_RS03020 type VII secretion system ESX-3 AAA family ATPase EccA3 83 96 ['694210-696037'] ['342221-344025'] True
# NQ428_RS03190 GntR family transcriptional regulator PhnF 31 48 ['734405-735140'] None True
# NQ428_RS03310 L,D-transpeptidase 60 108 ['759116-760127'] ['1611441-1611882'] True
# NQ428_RS03315 cytochrome P450 68 101 ['760326-761544'] ['2010767-2011948'] True
# NQ428_RS03320 TetR/AcrR family transcriptional regulator 77 89 ['761726-762268'] ['2010008-2010546'] True
# NQ428_RS03335 hypothetical protein 107 108 ['763325-765014'] None True
# NQ428_RS03340 UDP-glucose/GDP-mannose dehydrogenase family protein 65 80 ['765095-766442'] ['389260-390570'] True
# NQ428_RS03390 (Fe-S)-binding protein 106 143 ['775698-778782'] ['403220-405797'] True
# NQ428_RS03400 Hsp70 family protein 55 58 ['781650-783438'] None True
# NQ428_RS03405 IniB N-terminal domain-containing protein 74 77 ['783656-784181'] ['408634-408976'] True
# NQ428_RS03410 IniB N-terminal domain-containing protein 55 55 ['784462-785542'] None True
# NQ428_RS03485 molecular chaperone DnaK 469 649 ['799037-800906'] ['419834-421710'] True
# NQ428_RS03540 membrane protein 33 38 ['810994-811994'] None True
# NQ428_RS03545 TetR family transcriptional regulator 36 40 ['812095-812724'] None True
# NQ428_RS03560 IS3 family transposase 392 682 ['1820421-1821647'] None True
# NQ428_RS03590 ATP-dependent chaperone ClpB 168 512 ['819910-822457'] ['459455-462002'] True
# NQ428_RS03705 cation diffusion facilitator family transporter 32 116 ['843494-844388'] None True
# NQ428_RS03720 hypothetical protein 77 98 ['845796-846335'] ['436953-437501'] True
# NQ428_RS03725 adenylosuccinate synthase 63 98 ['846486-847782'] ['435485-436769'] True
# NQ428_RS03870 hypothetical protein 72 96 ['877635-878955'] ['498299-499619'] True
# NQ428_RS03875 NUDIX hydrolase 73 92 ['879112-879615'] ['499746-500206'] True
# NQ428_RS03880 thiamine phosphate synthase 183 184 ['879598-880282'] ['500357-501009'] True
# NQ428_RS03885 glycine oxidase ThiO 150 151 ['880420-881425'] ['501173-502157'] True
# NQ428_RS03935 ISL3-like element IS1096 family transposase 337 418 ['889802-891126'] None True
# NQ428_RS03945 secretion protein EccK 74 74 ['892153-892936'] ['4357630-4358252'] True
# NQ428_RS04050 phosphomethylpyrimidine synthase ThiC 366 376 ['913600-915199'] ['508581-510206'] True
# NQ428_RS04055 MFS transporter 49 53 ['915538-917293'] None True
# NQ428_RS04080 peptide deformylase 100 149 ['921297-921891'] ['517802-518396'] True
# NQ428_RS04085 DUF3263 domain-containing protein 101 164 ['922018-922330'] ['518732-519032'] True
# NQ428_RS04260 DEAD/DEAH box helicase 57 65 ['951877-953585'] None True
# NQ428_RS04305 SDR family NAD(P)-dependent oxidoreductase 72 74 ['965992-966910'] ['75300-76209'] True
# NQ428_RS04310 TetR/AcrR family transcriptional regulator 83 113 ['967014-967578'] ['74643-75176'] True
# NQ428_RS04315 chaperonin GroEL 655 813 ['967805-969431'] ['528607-530230'] True
# NQ428_RS04465 isocitrate lyase 160 219 ['997473-998760'] ['557526-558811'] True
# NQ428_RS04470 3-hydroxybutyryl-CoA dehydrogenase 44 77 ['998890-999751'] None True
# NQ428_RS04490 TetR/AcrR family transcriptional regulator 79 100 ['1002701-1003406'] ['562742-563426'] True
# NQ428_RS04495 DUF445 domain-containing protein 73 99 ['1003525-1004842'] ['563654-564934'] True
# NQ428_RS04500 helix-turn-helix domain-containing protein 135 337 ['1004929-1005358'] ['565021-565405'] True
# NQ428_RS04510 DUF2516 family protein 40 91 ['1006216-1006501'] ['566490-566770'] True
# NQ428_RS04525 DUF2993 domain-containing protein 32 105 ['1007639-1008575'] ['567921-568648'] True
# NQ428_RS04560 SDR family oxidoreductase 90 100 ['1013760-1014510'] ['573077-573775'] True
# NQ428_RS04565 ROK family protein 95 98 ['1014701-1016033'] ['574035-575246'] True
# NQ428_RS04585 two-component system sensor histidine kinase SenX3 94 135 ['1018840-1020031'] ['579350-580480'] True
# NQ428_RS04625 helix-turn-helix domain-containing protein 243 370 ['1026451-1026679'] ['591110-591345'] True
# NQ428_RS04630 AURKAIP1/COX24 domain-containing protein 154 215 ['1026863-1026964'] ['591474-591574'] True
# NQ428_RS04700 DUF2236 domain-containing protein 44 57 ['1038270-1039140'] None True
# NQ428_RS04720 MspA family porin 75 81 ['1041180-1041816'] None True
# NQ428_RS04760 cytochrome c biogenesis protein ResB 50 200 ['1047884-1049411'] ['618325-619831'] True
# NQ428_RS04780 DUF4229 domain-containing protein 69 83 ['1052068-1052341'] ['622364-622637'] True
# NQ428_RS04920 ISL3-like element IS1096 family transposase 334 457 ['1075373-1076697'] None True
# NQ428_RS04930 class I SAM-dependent methyltransferase 35 55 ['1077090-1077906'] None True
# NQ428_RS04945 hypothetical protein 84 84 ['1079971-1080463'] None True
# NQ428_RS04950 cytochrome P450 93 108 ['1080558-1082043'] ['3419515-3420963'] True
# NQ428_RS04955 TetR/AcrR family transcriptional regulator 94 101 ['1082174-1082834'] ['3418740-3419342'] True
# NQ428_RS04980 TetR/AcrR family transcriptional regulator 78 195 ['1087630-1088236'] ['3416138-3416689'] True
# NQ428_RS04990 redoxin NrdH 181 277 ['1089389-1089629'] ['3414732-3414958'] True
# NQ428_RS05035 TetR/AcrR family transcriptional regulator 121 162 ['1096659-1097236'] None True
# NQ428_RS05065 class 1b ribonucleoside-diphosphate reductase subunit beta 111 126 ['1102824-1103799'] ['3408403-3409364'] True
# NQ428_RS05095 ABC transporter substrate-binding protein 102 115 ['1109964-1111038'] ['3405171-3406215'] True
# NQ428_RS05100 cytochrome c oxidase subunit I 104 149 ['1111247-1112975'] ['3403216-3404920'] True
# NQ428_RS05115 PLP-dependent aminotransferase family protein 68 150 ['1114684-1116124'] None True
# NQ428_RS05120 membrane protein 46 147 ['1116330-1117026'] None True
# NQ428_RS05185 ISL3-like element IS1096 family transposase 294 395 ['1509469-1510793'] None True
# NQ428_RS05205 DUF3349 domain-containing protein 45 45 ['1132426-1132750'] None True
# NQ428_RS05210 inorganic phosphate transporter 35 80 ['1133031-1134288'] None True
# NQ428_RS05445 thioredoxin domain-containing protein 38 47 ['1176870-1177549'] None True
# NQ428_RS05450 glycosyltransferase family 1 protein 72 93 ['1177637-1178764'] ['648545-649655'] True
# NQ428_RS05725 YajQ family cyclic di-GMP-binding protein 50 121 ['1230065-1230557'] ['657549-658039'] True
# NQ428_RS05730 tRNA-Tyr 50 119 ['1230666-1230749'] ['658109-658189'] True
# NQ428_RS05770 VOC family protein 116 137 ['1236720-1237185'] ['2965938-2966374'] True
# NQ428_RS05775 metalloregulator ArsR/SmtB family transcription factor 118 130 ['1237285-1237645'] ['2965484-2965837'] True
# NQ428_RS06000 NAD(+)--rifampin ADP-ribosyltransferase 59 59 ['1292855-1293284'] None True
# NQ428_RS06005 IS1634-like element ISMsm6 family transposase 51 175 ['1293476-1295114'] None True
# NQ428_RS06105 ISL3-like element IS1096 family transposase 336 421 ['1311553-1312877'] None True
# NQ428_RS06165 IS3-like element ISMsm7 family transposase 86 245 ['1329718-1330879'] None True
# NQ428_RS06190 AAA family ATPase 45 52 ['1347664-1349878'] None True
# NQ428_RS06205 ISL3-like element IS1096 family transposase 339 430 ['1351407-1352731'] None True
# NQ428_RS06425 helix-turn-helix transcriptional regulator 34 57 ['1399865-1400699'] None True
# NQ428_RS06430 aldo/keto reductase 33 38 ['1400814-1401858'] None True
# NQ428_RS06455 IS1380-like element ISMsm11 family transposase 283 291 ['1406989-1408393'] None True
# NQ428_RS06575 Rrf2 family transcriptional regulator 35 52 ['1438706-1439168'] None True
# NQ428_RS06585 tRNA-Thr 82 130 ['1440522-1440595'] ['731493-731566'] True
# NQ428_RS06615 tRNA-Trp 126 140 ['1442504-1442577'] ['733523-733596'] True
# NQ428_RS06635 50S ribosomal protein L1 64 514 ['1444526-1445234'] ['735516-736216'] True
# NQ428_RS06645 YciI family protein 54 58 ['1446544-1447240'] None True
# NQ428_RS06670 DUF2236 domain-containing protein 49 53 ['1451871-1452877'] None True
# NQ428_RS06675 TetR/AcrR family transcriptional regulator 45 54 ['1452963-1453563'] None True
# NQ428_RS06685 DinB family protein 31 67 ['1454182-1454711'] None True
# NQ428_RS06720 50S ribosomal protein L10 562 620 ['1463208-1463736'] ['748275-748788'] True
# NQ428_RS06730 ABC transporter ATP-binding protein MceG 89 121 ['1464388-1465471'] ['751585-752560'] True
# NQ428_RS06735 DNA-directed RNA polymerase subunit beta 146 152 ['1466170-1469680'] ['759788-763324'] True
# NQ428_RS06740 DNA-directed RNA polymerase subunit beta' 69 141 ['1469743-1473697'] ['763370-767319'] True
# NQ428_RS06800 TetR/AcrR family transcriptional regulator 35 41 ['1485442-1486147'] None True
# NQ428_RS06805 MmpS family transport accessory protein 37 43 ['1486316-1486742'] None True
# NQ428_RS06835 acyl-CoA dehydrogenase family protein 46 100 ['1493294-1494950'] ['771475-773111'] True
# NQ428_RS06890 30S ribosomal protein S12 162 352 ['1502842-1503217'] ['781559-781932'] True
# NQ428_RS06905 elongation factor Tu 88 245 ['1505952-1507143'] ['784820-786009'] True
# NQ428_RS06920 ISL3-like element IS1096 family transposase 343 469 ['1509469-1510792'] None True
# NQ428_RS06975 dimethylarginine dimethylaminohydrolase family protein 85 149 ['1521412-1522186'] ['2595360-2596133'] True
# NQ428_RS06980 Lrp/AsnC family transcriptional regulator 96 136 ['1522413-1522860'] ['2596337-2596767'] True
# NQ428_RS07005 mycofactocin system transcriptional regulator 99 121 ['1526809-1527412'] ['791075-791655'] True
# NQ428_RS07030 mycofactocin biosynthesis peptidyl-dipeptidase MftE 43 94 ['1530406-1531150'] ['794714-795470'] True
# NQ428_RS07045 MFS transporter 35 74 ['1534003-1535545'] None True
# NQ428_RS07075 DUF4442 domain-containing protein 45 45 ['1540868-1541402'] None True
# NQ428_RS07080 30S ribosomal protein S10 364 534 ['1541815-1542121'] ['800486-800792'] True
# NQ428_RS07220 50S ribosomal protein L14 167 237 ['1566478-1566847'] ['811372-811740'] True
# NQ428_RS07240 30S ribosomal protein S8 116 596 ['1568015-1568414'] ['812975-813374'] True
# NQ428_RS07305 class I SAM-dependent methyltransferase 90 113 ['1578717-1579632'] ['823715-824618'] True
# NQ428_RS07310 preprotein translocase subunit SecY 95 102 ['1579981-1581307'] ['824799-826125'] True
# NQ428_RS07365 response regulator transcription factor 34 60 ['1590522-1591186'] None True
# NQ428_RS07370 haloacid dehalogenase 36 43 ['1591303-1592109'] None True
# NQ428_RS07385 CoA-acylating methylmalonate-semialdehyde dehydrogenase 43 119 ['1594272-1595793'] ['844421-845953'] True
# NQ428_RS07490 translation initiation factor IF-1 103 128 ['1616137-1616359'] ['3880433-3880653'] True
# NQ428_RS07500 30S ribosomal protein S13 216 532 ['1616741-1617116'] ['3879695-3880070'] True
# NQ428_RS07515 DNA-directed RNA polymerase subunit alpha 107 522 ['1618261-1619314'] ['3877464-3878507'] True
# NQ428_RS07520 50S ribosomal protein L17 78 121 ['1619388-1619988'] None True
# NQ428_RS07545 EamA family transporter 52 147 ['1623033-1624113'] None True
# NQ428_RS07550 CGNR zinc finger domain-containing protein 45 120 ['1624183-1624744'] None True
# NQ428_RS07595 DEAD/DEAH box helicase 32 41 ['1634822-1636206'] None True
# NQ428_RS07605 aldehyde dehydrogenase family protein 42 202 ['1637875-1639399'] None True
# NQ428_RS07665 50S ribosomal protein L13 141 190 ['1650837-1651281'] ['3861947-3862389'] True
# NQ428_RS07795 co-chaperone GroES 364 646 ['1675719-1676022'] ['3836986-3837287'] True
# NQ428_RS07800 chaperonin GroEL 79 138 ['1676105-1677728'] ['3835271-3836891'] True
# NQ428_RS07835 IS1380-like element ISMsm11 family transposase 283 291 ['1406989-1408393'] None True
# NQ428_RS07860 WhiB family transcriptional regulator 96 126 ['1688205-1688496'] ['3834891-3835171'] True
# NQ428_RS07865 hypothetical protein 93 94 ['1688929-1689736'] ['3833752-3834485'] True
# NQ428_RS07870 sigma-70 family RNA polymerase sigma factor 63 95 ['1689825-1690404'] ['3833039-3833613'] True
# NQ428_RS07880 DUF5319 domain-containing protein 60 115 ['1691626-1692037'] ['3831725-3832107'] True
# NQ428_RS07885 IMP dehydrogenase 56 115 ['1692178-1693720'] ['3829931-3831442'] True
# NQ428_RS07895 GMC family oxidoreductase 38 69 ['1694944-1696681'] None True
# NQ428_RS07975 hypothetical protein 113 123 ['1713776-1714482'] ['3811038-3811614'] True
# NQ428_RS08050 tRNA (cytidine(34)-2'-O)-methyltransferase 46 46 ['1732605-1733070'] ['3777736-3778198'] True
# NQ428_RS08055 sensor histidine kinase 90 87 ['1733375-1736270'] ['3775608-3777409'] True
# NQ428_RS08130 bifunctional o-acetylhomoserine/o-acetylserine sulfhydrylase 184 184 ['1751283-1752615'] ['3726151-3727451'] True
# NQ428_RS08135 NADP-dependent isocitrate dehydrogenase 64 64 ['1753084-1755316'] None True
# NQ428_RS08140 alpha/beta hydrolase 57 84 ['1755392-1756232'] None True
# NQ428_RS08160 multidrug efflux SMR transporter 133 194 ['1759264-1759582'] None True
# NQ428_RS08170 D-alanyl-D-alanine carboxypeptidase 95 106 ['1760563-1761700'] ['3715882-3716992'] True
# NQ428_RS08180 Lrp/AsnC family transcriptional regulator 52 147 ['1763317-1763836'] None True
# NQ428_RS08185 gamma-aminobutyraldehyde dehydrogenase 50 186 ['1763969-1765457'] None True
# NQ428_RS08220 succinate dehydrogenase, cytochrome b556 subunit 95 121 ['1770685-1771102'] ['3704074-3704439'] True
# NQ428_RS08225 cytidine deaminase 90 109 ['1771319-1771718'] ['3703481-3703858'] True
# NQ428_RS08350 FAD-dependent monooxygenase 131 117 ['1797123-1798272'] None True
# NQ428_RS08355 TetR family transcriptional regulator 181 172 ['1798370-1798916'] None True
# NQ428_RS08435 IS3 family transposase 115 495 ['1817154-1818100'] None True
# NQ428_RS08450 IS3 family transposase 258 483 ['1820421-1821647'] None True
# NQ428_RS08470 IS3 family transposase 40 54 ['1823802-1825232'] None True
# NQ428_RS08480 IS3 family transposase 39 221 ['1825718-1826980'] None True
# NQ428_RS08495 IS256 family transposase 172 176 ['2894468-2895755'] None True
# NQ428_RS08540 TetR family transcriptional regulator 58 85 ['1838527-1839203'] None True
# NQ428_RS08750 STAS domain-containing protein 35 35 ['1874884-1875313'] None True
# NQ428_RS08845 acetyl/propionyl/methylcrotonyl-CoA carboxylase subunit alpha 59 96 ['1887975-1889772'] ['3666357-3668158'] True
# NQ428_RS08925 LCP family protein 48 122 ['1903382-1904876'] ['3647933-3649381'] True
# NQ428_RS08930 dTDP-4-dehydrorhamnose reductase 49 119 ['1904943-1905834'] ['3646902-3647795'] True
# NQ428_RS08955 2-phospho-L-lactate transferase 144 147 ['1909693-1910677'] ['3640542-3641529'] True
# NQ428_RS08960 WhiB family transcriptional regulator 152 198 ['1911100-1911358'] ['3639873-3640099'] True
# NQ428_RS08965 metallopeptidase family protein 91 101 ['1911398-1911821'] ['3639425-3639844'] True
# NQ428_RS08970 DUF3499 domain-containing protein 89 102 ['1911950-1912370'] ['3638812-3639250'] True
# NQ428_RS09000 alkane 1-monooxygenase 108 133 ['1919350-1920583'] ['3630747-3631943'] True
# NQ428_RS09020 adenosylhomocysteinase 35 37 ['1921815-1923273'] None True
# NQ428_RS09090 DDE-type integrase/transposase/recombinase 90 94 ['1939357-1940719'] None True
# NQ428_RS09115 IS3 family transposase 41 54 ['1823802-1825232'] None True
# NQ428_RS09125 IS1634-like element IS1549 family transposase 227 259 ['1945042-1946509'] None True
# NQ428_RS09130 IS3 family transposase 47 61 ['1946734-1947880'] None True
# NQ428_RS09165 two-component system response regulator MtrA 67 102 ['1954982-1955669'] ['3626662-3627349'] True
# NQ428_RS09185 ribosome-associated translation inhibitor RaiA 92 104 ['1960141-1960834'] ['3620610-3621220'] True
# NQ428_RS09200 wax ester/triacylglycerol synthase family O-acyltransferase 98 100 ['1964640-1966050'] None True
# NQ428_RS09215 ferredoxin reductase 68 167 ['1968528-1969679'] ['3607112-3608252'] True
# NQ428_RS09220 fatty acid desaturase 100 165 ['1969748-1971005'] ['3605802-3607033'] True
# NQ428_RS09330 benzoate 1,2-dioxygenase large subunit 37 60 ['1995976-1997341'] None True
# NQ428_RS09335 LysR family transcriptional regulator 40 76 ['1997550-1998477'] None True
# NQ428_RS09355 Cys-tRNA(Pro) deacylase 51 60 ['2000800-2001292'] None True
# NQ428_RS09360 sigma-70 family RNA polymerase sigma factor SigH 98 105 ['2001572-2002220'] ['3598900-3599498'] True
# NQ428_RS09370 biotin/lipoyl-binding carrier protein 161 169 ['2002732-2002948'] ['3597553-3597766'] True
# NQ428_RS09380 transcriptional regulator WhiB1 170 198 ['2004692-2004947'] ['3595712-3595967'] True
# NQ428_RS09435 DEAD/DEAH box helicase 101 112 ['2012506-2014015'] ['3587813-3589336'] True
# NQ428_RS09440 ferritin-like fold-containing protein 100 103 ['2014320-2015019'] ['3586850-3587524'] True
# NQ428_RS09445 MmpS family transport accessory protein 38 75 ['2015025-2015850'] None True
# NQ428_RS09450 DUF3107 domain-containing protein 50 90 ['2016152-2016391'] ['3585714-3585948'] True
# NQ428_RS09455 TetR/AcrR family transcriptional regulator 56 91 ['2016398-2017059'] ['3585003-3585690'] True
# NQ428_RS09460 DUF3152 domain-containing protein 59 88 ['2017304-2018339'] None True
# NQ428_RS09535 transcriptional regulator WhiB7 159 225 ['2036326-2036638'] ['3568405-3568640'] True
# NQ428_RS09590 tRNA-Met 51 221 ['2052146-2052219'] ['3559369-3559442'] True
# NQ428_RS09780 ISL3-like element IS1096 family transposase 334 456 ['1128589-1129913'] None True
# NQ428_RS09910 SDR family oxidoreductase 57 84 ['2112684-2113437'] None True
# NQ428_RS09915 TetR/AcrR family transcriptional regulator 67 100 ['2113514-2114108'] None True
# NQ428_RS10080 NADH-quinone oxidoreductase subunit A 56 79 ['2147360-2147730'] None True
# NQ428_RS10140 homogentisate 1,2-dioxygenase 58 79 ['2156568-2157673'] None True
# NQ428_RS10155 esterase family protein 36 40 ['2160048-2161026'] None True
# NQ428_RS10170 acyl-CoA dehydrogenase family protein 69 152 ['2163436-2164834'] ['3505363-3506768'] True
# NQ428_RS10185 FAD-dependent oxidoreductase 51 86 ['2166159-2167528'] ['3474006-3475377'] True
# NQ428_RS10190 peptide chain release factor 2 55 81 ['2167699-2168806'] ['3472768-3473882'] True
# NQ428_RS10225 transfer-messenger RNA 53 106 ['2173804-2174172'] ['3467967-3468333'] True
# NQ428_RS10290 DUF4185 domain-containing protein 94 98 ['2187776-2189192'] ['1984979-1986445'] True
# NQ428_RS10340 PTS transporter subunit EIIC 35 58 ['2195504-2196890'] None True
# NQ428_RS10345 PTS glucose transporter subunit IIA 32 32 ['2197127-2197598'] None True
# NQ428_RS10445 tRNA-Ala 72 131 ['2217689-2217761'] ['3431839-3431911'] True
# NQ428_RS10505 DDE-type integrase/transposase/recombinase 91 94 ['1939357-1940719'] None True
# NQ428_RS10550 hypothetical protein 84 84 ['2238859-2239161'] ['2917884-2918167'] True
# NQ428_RS10555 thioester reductase domain-containing protein 217 218 ['3026715-3029372'] ['2918635-2921375'] True
# NQ428_RS10620 AAA family ATPase 154 175 ['2255673-2257884'] None True
# NQ428_RS10805 helix-turn-helix transcriptional regulator 36 94 ['2296326-2297166'] None True
# NQ428_RS10850 enoyl-CoA hydratase-related protein 60 70 ['2305818-2306641'] None True
# NQ428_RS10855 enoyl-CoA hydratase/isomerase family protein 31 32 ['2306911-2307796'] None True
# NQ428_RS10865 TetR family transcriptional regulator 51 74 ['2309089-2309842'] None True
# NQ428_RS10880 enoyl-CoA hydratase 60 69 ['2311820-2312642'] None True
# NQ428_RS10975 TIGR03857 family LLM class F420-dependent oxidoreductase 60 66 ['2334698-2335742'] None True
# NQ428_RS10990 rifampin monooxygenase 177 197 ['2338572-2339996'] None True
# NQ428_RS11000 multidrug ABC transporter ATPase 44 71 ['2341378-2342878'] None True
# NQ428_RS11005 LLM class F420-dependent oxidoreductase 42 62 ['2343035-2344088'] ['1531367-1532363'] True
# NQ428_RS11135 ISL3-like element IS1096 family transposase 334 457 ['1075373-1076697'] None True
# NQ428_RS11145 class I SAM-dependent methyltransferase 35 55 ['1077090-1077906'] None True
# NQ428_RS11160 hypothetical protein 84 84 ['1079971-1080463'] None True
# NQ428_RS11165 cytochrome P450 93 108 ['1080558-1082043'] ['3419515-3420963'] True
# NQ428_RS11170 TetR/AcrR family transcriptional regulator 94 101 ['1082174-1082834'] ['3418740-3419342'] True
# NQ428_RS11195 TetR/AcrR family transcriptional regulator 78 195 ['1087630-1088236'] ['3416138-3416689'] True
# NQ428_RS11205 redoxin NrdH 181 277 ['1089389-1089629'] ['3414732-3414958'] True
# NQ428_RS11250 TetR/AcrR family transcriptional regulator 121 162 ['1096659-1097236'] None True
# NQ428_RS11280 class 1b ribonucleoside-diphosphate reductase subunit beta 111 126 ['1102824-1103799'] ['3408403-3409364'] True
# NQ428_RS11310 ABC transporter substrate-binding protein 102 115 ['1109964-1111038'] ['3405171-3406215'] True
# NQ428_RS11315 cytochrome c oxidase subunit I 104 149 ['1111247-1112975'] ['3403216-3404920'] True
# NQ428_RS11330 PLP-dependent aminotransferase family protein 68 150 ['1114684-1116124'] None True
# NQ428_RS11335 membrane protein 46 147 ['1116330-1117026'] None True
# NQ428_RS11400 ISL3-like element IS1096 family transposase 322 421 ['1075373-1076697'] None True
# NQ428_RS11460 class I SAM-dependent methyltransferase 102 130 ['2436363-2437149'] ['3389172-3389926'] True
# NQ428_RS11465 electron transfer flavoprotein subunit beta/FixA family protein 101 136 ['2437365-2438157'] ['3388070-3388870'] True
# NQ428_RS11485 GNAT family N-acetyltransferase 79 117 ['2440874-2441708'] ['3386075-3386917'] True
# NQ428_RS11555 PQQ-dependent sugar dehydrogenase 90 101 ['2456146-2457268'] ['3364740-3365830'] True
# NQ428_RS11560 DoxX family protein 93 105 ['2457414-2458257'] ['3363693-3364531'] True
# NQ428_RS11565 PH domain-containing protein 84 84 ['2458287-2458686'] ['3363318-3363682'] True
# NQ428_RS11570 acetolactate synthase large subunit 350 411 ['2458999-2460856'] ['3361129-3362986'] True
# NQ428_RS11610 MFS transporter 42 78 ['2467906-2469094'] None True
# NQ428_RS11630 tRNA-Gln 89 121 ['2472777-2472852'] ['3348657-3348730'] True
# NQ428_RS11635 tRNA-Glu 49 95 ['2472921-2472993'] ['3348547-3348617'] True
# NQ428_RS11640 IclR family transcriptional regulator 33 191 ['2473174-2473876'] ['3346147-3346845'] True
# NQ428_RS11645 3-isopropylmalate dehydratase large subunit 41 191 ['2473987-2475442'] ['3344661-3346056'] True
# NQ428_RS11655 HU family DNA-binding protein 154 181 ['2476262-2476889'] ['3343201-3343820'] True
# NQ428_RS11715 50S ribosomal protein L28 95 106 ['2487348-2487543'] None True
# NQ428_RS11720 DAK2 domain-containing protein 92 102 ['2487777-2489442'] None True
# NQ428_RS11790 DivIVA domain-containing protein 101 123 ['2503074-2503812'] ['3241223-3241959'] True
# NQ428_RS11835 ammonium transporter 174 521 ['2513076-2514425'] ['3231174-3232476'] True
# NQ428_RS11885 30S ribosomal protein S16 151 350 ['2524560-2525031'] ['3217227-3217643'] True
# NQ428_RS11905 LppW family protein 99 99 ['2526530-2527475'] ['3214627-3215572'] True
# NQ428_RS11910 50S ribosomal protein L19 101 129 ['2527808-2528150'] ['3213911-3214253'] True
# NQ428_RS12070 MFS transporter 51 71 ['2562068-2563327'] None True
# NQ428_RS12270 HNH endonuclease 114 292 ['2604249-2605950'] ['1251624-1252825'] True
# NQ428_RS12290 M23 family metallopeptidase 131 141 ['2608943-2609447'] ['3200382-3200796'] True
# NQ428_RS12295 30S ribosomal protein S2 326 440 ['2609755-2610589'] ['3199121-3199982'] True
# NQ428_RS12310 ABC transporter permease 32 32 ['2613166-2614351'] None True
# NQ428_RS12395 UMP kinase 63 112 ['2629742-2630489'] ['3192373-3193070'] True
# NQ428_RS12410 DMT family transporter 31 33 ['2631931-2632816'] None True
# NQ428_RS12415 LysR family transcriptional regulator 41 49 ['2632992-2633886'] None True
# NQ428_RS12495 SMP-30/gluconolactonase/LRE family protein 64 69 ['2649798-2650683'] None True
# NQ428_RS12500 hypothetical protein 31 32 ['2650758-2651463'] None True
# NQ428_RS12610 penicillin-binding transpeptidase domain-containing protein 50 101 ['2670715-2672536'] ['3175460-3177265'] True
# NQ428_RS12665 glutamine synthetase family protein 34 45 ['2682659-2684033'] None True
# NQ428_RS12750 alpha/beta hydrolase 94 166 ['2696671-2697703'] None True
# NQ428_RS12755 malate dehydrogenase (quinone) 113 326 ['2698016-2699486'] ['3160589-3162013'] True
# NQ428_RS12810 ribosome maturation factor RimP 100 101 ['2710495-2711041'] ['3149455-3149963'] True
# NQ428_RS12820 DUF448 domain-containing protein 86 86 ['2712244-2712467'] ['3147972-3148190'] True
# NQ428_RS12825 translation initiation factor IF-2 158 244 ['2712570-2715375'] ['3145171-3147867'] True
# NQ428_RS12910 DUF3558 domain-containing protein 72 92 ['2730559-2731144'] ['3107811-3108395'] True
# NQ428_RS12915 IS110 family transposase 133 139 ['2731306-2732518'] None True
# NQ428_RS12945 manganese-binding transcriptional regulator MntR 46 78 ['2737810-2738521'] None True
# NQ428_RS12950 bifunctional riboflavin kinase/FAD synthetase 46 88 ['2738603-2739580'] ['3093926-3094878'] True
# NQ428_RS12955 30S ribosomal protein S15 100 212 ['2739681-2739951'] ['3093478-3093748'] True
# NQ428_RS12965 polyribonucleotide nucleotidyltransferase 352 458 ['2740792-2743084'] ['3090383-3092597'] True
# NQ428_RS12980 alanine dehydrogenase 53 112 ['2745362-2746478'] ['3086819-3087915'] True
# NQ428_RS12985 Lrp/AsnC family transcriptional regulator 62 95 ['2746573-2747089'] ['3086221-3086691'] True
# NQ428_RS13000 HNH endonuclease 61 218 ['2748508-2750221'] None True
# NQ428_RS13065 hypothetical protein 269 300 ['1820421-1820691'] ['1542935-1543197'] True
# NQ428_RS13070 MMPL family transporter 109 180 ['2759174-2760230'] ['1716434-1717443'] True
# NQ428_RS13125 antibiotic biosynthesis monooxygenase 79 82 ['2769990-2770305'] ['3062504-3062818'] True
# NQ428_RS13130 DNA translocase FtsK 96 134 ['2770469-2773100'] ['3059860-3062350'] True
# NQ428_RS13135 amino-acid N-acetyltransferase 36 99 ['2773110-2773593'] ['3059297-3059786'] True
# NQ428_RS13140 CDP-diacylglycerol--glycerol-3-phosphate 3-phosphatidyltransferase 39 91 ['2773699-2774304'] ['3058634-3059200'] True
# NQ428_RS13155 phage shock protein PspA 49 94 ['2775470-2776310'] ['3057311-3058063'] True
# NQ428_RS13200 IS110 family transposase 149 158 ['2781390-2782596'] None True
# NQ428_RS13240 hydrogenase maturation protease 63 64 ['2788577-2789060'] None True
# NQ428_RS13270 hydrogenase expression protein HypE 44 58 ['2794656-2795712'] None True
# NQ428_RS13285 recombinase RecA 225 480 ['2797156-2798206'] ['3050668-3051420'] True
# NQ428_RS13310 amino acid ABC transporter ATP-binding protein 45 57 ['2801240-2801969'] None True
# NQ428_RS13315 tRNA (N6-isopentenyl adenosine(37)-C2)-methylthiotransferase MiaB 51 100 ['2802130-2803669'] ['3045031-3046454'] True
# NQ428_RS13325 DUF349 domain-containing protein 95 126 ['2804309-2805638'] ['3043163-3044363'] True
# NQ428_RS13330 DMT family transporter 66 74 ['2805800-2806688'] ['3041626-3042464'] True
# NQ428_RS13365 hypothetical protein 55 58 ['2814986-2817422'] None True
# NQ428_RS13370 transcriptional repressor LexA 241 487 ['2817431-2818163'] ['3031783-3032498'] True
# NQ428_RS13375 LysM peptidoglycan-binding domain-containing protein 96 96 ['2818426-2818984'] ['3031039-3031420'] True
# NQ428_RS13380 transcriptional regulator NrdR 64 92 ['2819145-2819598'] ['3030433-3030877'] True
# NQ428_RS13405 Si-specific NAD(P)(+) transhydrogenase 36 84 ['2823465-2824873'] ['3025441-3026840'] True
# NQ428_RS13410 DUF4192 domain-containing protein 37 99 ['2825048-2826110'] ['3024282-3025309'] True
# NQ428_RS13420 sigma-70 family RNA polymerase sigma factor 127 166 ['2827060-2828050'] ['3022430-3023433'] True
# NQ428_RS13440 hypothetical protein 110 113 ['2829978-2830170'] None True
# NQ428_RS13445 DUF952 domain-containing protein 115 119 ['2830327-2830693'] ['3019875-3020189'] True
# NQ428_RS13450 RNA polymerase sigma factor 100 132 ['2831020-2832422'] ['3018072-3019419'] True
# NQ428_RS13465 envelope integrity protein Cei 101 103 ['2834429-2835080'] ['3015202-3015850'] True
# NQ428_RS13470 DUF4193 domain-containing protein 101 103 ['2835245-2835548'] ['3014662-3014964'] True
# NQ428_RS13490 alpha/beta hydrolase 86 106 ['2837371-2838070'] ['3011921-3012611'] True
# NQ428_RS13495 OB-fold nucleic acid binding domain-containing protein 85 107 ['2838205-2838577'] ['3011399-3011760'] True
# NQ428_RS13530 Na+/H+ antiporter NhaA 156 429 ['2845432-2846728'] None True
# NQ428_RS13615 hypothetical protein 185 259 ['2861938-2862674'] ['2983915-2984601'] True
# NQ428_RS13625 FadR family transcriptional regulator 48 98 ['2864176-2864839'] None True
# NQ428_RS13630 MFS transporter 54 109 ['2864978-2866139'] None True
# NQ428_RS13645 3-deoxy-7-phosphoheptulonate synthase 94 113 ['2868584-2869637'] None True
# NQ428_RS13735 hypothetical protein 33 33 ['2884054-2885008'] None True
# NQ428_RS13745 IS3 family transposase 48 47 ['2886206-2886337'] None True
# NQ428_RS13750 hypothetical protein 57 62 ['2888032-2888845'] None True
# NQ428_RS13760 IS1380 family transposase 51 52 ['2889478-2889619'] None True
# NQ428_RS13770 IS1634-like element IS1549 family transposase 234 259 ['2890665-2892132'] None True
# NQ428_RS13775 IS1634-like element IS1549 family transposase 197 265 ['1945042-1946150'] None True
# NQ428_RS13785 IS256 family transposase 169 176 ['1829063-1830350'] None True
# NQ428_RS13795 IS1634-like element IS1549 family transposase 234 259 ['2890665-2892132'] None True
# NQ428_RS13800 IS1634-like element IS1549 family transposase 239 268 ['1945042-1946150'] None True
# NQ428_RS13815 ISL3-like element IS1096 family transposase 344 437 ['2901347-2902670'] None True
# NQ428_RS13855 tRNA-Gly 102 156 ['2906204-2906276'] ['2969753-2969825'] True
# NQ428_RS13860 tRNA-Val 80 93 ['2906743-2906818'] ['2969494-2969567'] True
# NQ428_RS13920 MFS transporter 53 67 ['2922467-2923877'] None True
# NQ428_RS13925 helix-turn-helix transcriptional regulator 57 143 ['2923951-2924353'] None True
# NQ428_RS14130 IclR family transcriptional regulator 62 81 ['2964074-2964959'] None True
# NQ428_RS14200 IS110 family transposase 144 156 ['2976773-2977980'] None True
# NQ428_RS14265 response regulator transcription factor 65 87 ['2990582-2991287'] ['1157962-1158664'] True
# NQ428_RS14370 pyridoxal 5'-phosphate synthase lyase subunit PdxS 32 60 ['3010643-3011555'] None True
# NQ428_RS14400 crossover junction endodeoxyribonuclease RuvC 76 260 ['3015225-3015783'] ['2924815-2925382'] True
# NQ428_RS14465 thioester reductase domain-containing protein 82 97 ['3026715-3030222'] ['2917882-2921376'] True
# NQ428_RS14485 preprotein translocase subunit YajC 37 65 ['3033665-3033989'] ['2915889-2916181'] True
# NQ428_RS14560 peptidylprolyl isomerase 37 77 ['3050815-3051679'] None True
# NQ428_RS14565 MBL fold metallo-hydrolase 39 71 ['3051847-3052525'] None True
# NQ428_RS14595 urea ABC transporter substrate-binding protein 36 36 ['3057869-3059138'] None True
# NQ428_RS14600 hypothetical protein 31 43 ['3059375-3059807'] None True
# NQ428_RS14745 thiolase family protein 67 72 ['3092527-3093712'] None True
# NQ428_RS14750 helix-turn-helix transcriptional regulator 68 74 ['3093810-3094280'] None True
# NQ428_RS14800 hypothetical protein 71 117 ['3106557-3107187'] ['2877918-2878540'] True
# NQ428_RS14805 secondary thiamine-phosphate synthase enzyme YjbQ 48 54 ['3107311-3107713'] ['2876576-2876976'] True
# NQ428_RS14895 bifunctional pyr operon transcriptional regulator/uracil phosphoribosyltransferase PyrR 487 624 ['3126009-3126567'] ['1552691-1553231'] True
# NQ428_RS14930 integration host factor MihF 131 141 ['3135907-3136225'] ['1563948-1564257'] True
# NQ428_RS14950 methionine adenosyltransferase 34 83 ['3138680-3139880'] ['1566833-1568034'] True

# %%
[x for x in gene_info_dict[reference_species] if x[0] == 'NQ428_RS12295']
# Out:
# [('NQ428_RS12295',
#   2609755,
#   2610589,
#   ('NQ428_RS12295', 1),
#   ('NQ428_RS12295', 1),
#   ('30S ribosomal protein S2', '30S ribosomal protein S2'))]
