# %% [markdown]
# #### Import packages, set directories and parameters

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from Bio import Entrez, SeqIO, AlignIO, pairwise2, Align, Seq, motifs
from Bio.Seq import Seq
from Bio.SeqFeature import SeqFeature, FeatureLocation
import math
from tqdm import tqdm
from Comparative_Analysis import Utilities as util
from joblib import Parallel, delayed
from Comparative_Analysis import Blast_Functions as blastfn
import time
import os
import copy
from scipy.stats import chi2, binom
from Comparative_Analysis import Alignment as alignfn
from Bio.Align.Applications import MuscleCommandline
import subprocess
pd.options.mode.chained_assignment = None  # default='warn'

# %%
project_dir = 'F:/Project_Data/mabR_Project'
mycobacteria_seq_dir = 'F:/Datasets/NCBI_Refseq_Mycobacteriaceae_Complete_Annot_20230511/data'
actinobacteria_seq_dir = 'F:/Datasets/NCBI_Refseq_Actinomycetes_Complete_Annot_20230511/data'
tb_species = 'AL123456.3' 
tb_annotation_dirname = 'GCA_000195955.2'
min_region_length = 7 
full_build = False
num_cores = 16
core_numbers = list(range(1, num_cores+1))
muscle_exe = 'C:/Users/nicho/Muscle/muscle3.8.31_i86win32.exe'
full_run = False

# %%
mycobacteria_dirs = []
for dir in util.list_dirs(mycobacteria_seq_dir):
    if os.path.exists(mycobacteria_seq_dir + '/' + dir + '/genomic.gbff'):
        mycobacteria_dirs.append(dir)

# %%
actinobacteria_dirs = []
for dir in util.list_dirs(actinobacteria_seq_dir):
    if os.path.exists(actinobacteria_seq_dir + '/' + dir + '/genomic.gbff'):
        actinobacteria_dirs.append(dir)

# %%
tb_mycobacteria_rbh = pd.read_csv(project_dir + '/tb_mycobacteria_reciprocal_best_hits.csv')

# %%
names_dict = {}
dirname_dict = {}
for dirname in (mycobacteria_dirs):
        for genome_record in SeqIO.parse(mycobacteria_seq_dir + '/' + dirname + '/genomic.gbff', "genbank"):
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            names_dict[accession_ver] = genome_record.annotations['organism']
        dirname_dict[dirname] = genome_record.annotations['organism']

# %%
def reverse_complement(seq_string):
    temp = []
    for char in reversed(seq_string):
        if char == 'A':
            comp = 'T'
        elif char == 'T':
            comp = 'A'
        elif char == 'C':
            comp = 'G'
        elif char == 'G':
            comp = 'C'
        else:
            comp = char
        temp.append(comp)
    return ''.join(temp)

# %% [markdown]
# #### Lookup function to find orthologs in M.tb based on reciprocal best hit outputs

# %%
def ortholog_in_mtb(accession_ver, locus):
    gene = accession_ver + '@' + locus
    temp = tb_mycobacteria_rbh.query('target_ref == @gene and query_species == @tb_species')
    if len(temp) == 1:
        for i, r in temp.iterrows():
            temp2 = r['query_ref']
            return temp2.split('@')[1]
    else:
        return 'No_orth'

# %% [markdown]
# #### Produce reference FASTA files (a) TB and (b, c) all mycobacteria, actionobacteria for searching against motifs

# %%
genome_record = next(SeqIO.parse(mycobacteria_seq_dir + '/' + tb_annotation_dirname + '/genomic.gbff', "genbank"))
tot = 0
for feature in genome_record.features:
    a = feature.qualifiers
    if feature.type not in ['source','gene'] and (int(feature.location.start) < int(feature.location.end)) and (int(feature.location.end) - int(feature.location.start)) < 1000000:
        if feature.type == 'CDS':
            tot+=1
print(tot)
# Out:
# 4031

# %%
genome_record = next(SeqIO.parse(mycobacteria_seq_dir + '/' + tb_annotation_dirname + '/genomic.gbff', "genbank"))
mtb_sequence = str(genome_record.seq)
accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
util.produce_fasta_file([[accession_ver, mtb_sequence]], project_dir + '/mtb_seq')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 11.82it/s]

# %%
if full_run == True:
    temp = []
    for dir in util.list_dirs(mycobacteria_seq_dir): 
        if os.path.exists(mycobacteria_seq_dir + '/' + dir + '/genomic.gbff'):
            for genome_record in (SeqIO.parse(mycobacteria_seq_dir + '/' + dir + '/genomic.gbff', "genbank")):
                accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
                full_sequence = str(genome_record.seq)
                temp.append([accession_ver, full_sequence])
    util.produce_fasta_file(temp, project_dir + '/all_seq')

# %%
if 1==1:
#if full_run == True:
    temp = []
    for dir in util.list_dirs(actinobacteria_seq_dir): 
        if os.path.exists(actinobacteria_seq_dir + '/' + dir + '/genomic.gbff'):
            for genome_record in (SeqIO.parse(actinobacteria_seq_dir + '/' + dir + '/genomic.gbff', "genbank")):
                accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
                full_sequence = str(genome_record.seq)
                temp.append([accession_ver, full_sequence])
    util.produce_fasta_file(temp, project_dir + '/all_actinobacteria_seq')
# Out:
# 100%|██████████| 900/900 [01:03<00:00, 14.18it/s]

# %% [markdown]
# #### Functions to locate arbitrary region in organism

# %%
def annotated_regions_dataset(num_subsets, subset_num, dir_list, seqdir, cds_only = False): 
    output = []
    sequence_dirs = util.chunk_list(dir_list, num_subsets, subset_num)
    for dirname in sequence_dirs:
        annotated_regions = []
        intergenic_regions = []
        for record in (SeqIO.parse(seqdir + '/'+dirname+'/genomic.gbff', "genbank")):
            accession_ver = record.annotations['accessions'][0] + '.' + str(record.annotations['sequence_version'])
            for feature in record.features:
                a = feature.qualifiers
                if feature.type not in ['source','gene'] and (int(feature.location.start) < int(feature.location.end)) and (int(feature.location.end) - int(feature.location.start)) < 1000000:
                    if cds_only == True and not(feature.type == 'CDS'):
                        continue
                    else:
                        if not(a.get("product") == None):
                               product = a.get("product")[0]
                        else:
                               product = ''
                        if not(a.get("locus_tag")==None):
                            locus_tag = a.get("locus_tag")[0]
                        else:
                            locus_tag = feature.type
                        annotated_regions.append((locus_tag, product, feature.type, int(feature.location.start), int(feature.location.end), str(feature.location.strand)))
            annotated_regions.sort(key = lambda x: x[4])
            prev_strand = 0
            prev_locus = ''
            prev_product = ''
            max_stop = 0
            for n, (locus, product, feature_type, start, stop, strand) in enumerate(annotated_regions):
                if start > max_stop:
                    intergenic_regions.append([prev_locus+':'+locus, prev_product + ':' + product, 'Inter-feature',max_stop, start, str(prev_strand)+':'+str(strand)])
                if stop > max_stop:
                    prev_locus = locus
                    prev_product = product
                    prev_strand = strand
                max_stop = max(max_stop, stop)    
            for x in intergenic_regions:
                annotated_regions.append(x)
            annotated_regions.sort(key = lambda x : x[4])
            output.append([accession_ver, annotated_regions])
    return output

# %%
parallel_output = Parallel(n_jobs=-1)(delayed(annotated_regions_dataset)(num_cores, core_number, mycobacteria_dirs, mycobacteria_seq_dir) for core_number in core_numbers)
annotated_regions_dict = {}
for x in parallel_output:
    for y in x:
        annotated_regions_dict[y[0]] = y[1]
parallel_output = Parallel(n_jobs=-1)(delayed(annotated_regions_dataset)(num_cores, core_number, mycobacteria_dirs, mycobacteria_seq_dir, True) for core_number in core_numbers)
cds_annotated_regions_dict = {}
for x in parallel_output:
    for y in x:
        cds_annotated_regions_dict[y[0]] = y[1]

# %%
def location(accession_ver, start1, end1, annotation_lookup_dictionary):
    feature_matches = []
    for (locus, product, feature, start, stop, strand) in annotation_lookup_dictionary[accession_ver]:
            if start< end1 and stop > start1:
                overlap = str(int(100*(min(end1, stop) - max(start1, start))/ (end1-start1)))+'%'
                feature_matches.append([locus, product, feature, overlap, strand])
    return feature_matches

# %% [markdown]
# #### Create dictionary of upstream sequences - sequence continue upstream to the next CDS not next feature (e.g. if intervening repeat region this is included

# %%
def generate_upstream_sequence_dataset(num_subsets, subset_num, dir_list, seqdir, additional_offset = 0):     # Set additional offset = 3 if you want start codon of downstream CDS to be included - useful for alignment 
    sequence_dirs = util.chunk_list(dir_list, num_subsets, subset_num)
    upstream_cds_regions = []
    for dirname in (sequence_dirs):
        all_features = []
        cds_features = []
        for genome_record in SeqIO.parse(mycobacteria_seq_dir + '/' + dirname + '/genomic.gbff', "genbank"):
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            full_sequence = str(genome_record.seq)
            len_full_sequence = len(full_sequence)
            for feature in genome_record.features:
                if feature.type in ['gene', 'source']:
                    continue
                a = feature.qualifiers
                feature_type = feature.type
                if a.get("locus_tag") != None:
                    locus_tag = a.get("locus_tag")[0]
                    accession_locus = accession_ver + '@' + locus_tag
                else:
                    accession_locus  = ''
                (start, stop, strand) = (int(feature.location.start), int(feature.location.end), int(feature.location.strand))
                all_features.append([accession_locus, feature_type, start, stop, strand])
                if feature_type == 'CDS':
                    cds_features.append([accession_locus, feature_type, start, stop, strand])
            
            features = cds_features  # Replace with line below if you want to go upstream only to next annotated feature and not next CDS
            #features = all_features
            
            # Positive strand upstream 
            features.sort(key = lambda x: x[2])
            max_stop = 0
            for (accession_locus, feature_type, start, stop, strand) in features:
                if max_stop < start and feature_type == 'CDS' and strand == 1 and start - max_stop < 100000:    #Avoid joins where biopython interprets inconsistently 
                    upstream_cds_regions.append([accession_locus, max_stop, start, strand, full_sequence[max_stop: start+additional_offset]])
                max_stop = max(max_stop, stop)
            # Negative strand upstream
            features.sort(key = lambda x: x[3], reverse = True)
            min_start = len(full_sequence)-1
            for (accession_locus, feature_type, start, stop, strand) in features:
                if stop < min_start and feature_type == 'CDS' and strand == -1 and min_start - stop < 100000:
                    upstream_cds_regions.append([accession_locus, stop, min_start, strand, reverse_complement(full_sequence[stop-additional_offset: min_start])])
                min_start = min(min_start, start)
    return (upstream_cds_regions)

# %%
if full_build == True:
#if 1==1:
    mycobacteria_upstream_dict = {}
    parallel_output = Parallel(n_jobs=-1)(delayed(generate_upstream_sequence_dataset)(num_cores, core_number, mycobacteria_dirs, mycobacteria_seq_dir) for core_number in core_numbers)
    for x in parallel_output:
        for n in x:
            mycobacteria_upstream_dict[n[0]] = [n[1], n[2], n[3], n[4]]
    with open(project_dir + '/mycobacteria_upstream_dict.pkl', 'wb') as f:
        pickle.dump(mycobacteria_upstream_dict, f) 
else:
    with open(project_dir + '/mycobacteria_upstream_dict.pkl', 'rb') as f:
        mycobacteria_upstream_dict = pickle.load(f)

# %% [markdown]
# #### Functions to run MEME and FIMO

# %%
def run_meme(search_regions_loc, output_dir, min_width, min_sites):
    subprocess.run('wsl export PATH=$HOME/meme/bin:$HOME/meme/libexec/meme-5.4.1:usr/bin:$PATH ; meme '+ util.wslname(search_regions_loc) + ' -oc '+ util.wslname(output_dir) +' -dna -evt 0.001 -p 8 -revcomp -mod anr -brief 4000 -minw ' + str(min_width) +' -maxw 200 -minsites ' + str(min_sites)
               , shell=True)

# %%
def run_fimo(motif_file, sequence_to_search_file, output_dir):
    subprocess.run('wsl export PATH=$HOME/meme/bin:$HOME/meme/libexec/meme-5.4.1:usr/bin:$PATH ; fimo -oc ' + util.wslname(output_dir) + ' ' + util.wslname(motif_file) + ' ' + util.wslname(sequence_to_search_file)
               , shell=True)

# %%
def produce_matched_sequence_file(hit_df, output_file, q_value):
    matched_sequences = []
    for i, r in hit_df.iterrows():
        if '#' in r['motif_id']:
            continue
        if float(r['q-value']) < q_value:
            matched_sequences.append([str(r['start'])+'_'+str(r['stop']), r['matched_sequence']])
    util.produce_fasta_file(matched_sequences, output_file)

# %% [markdown]
# #### Import list of significantly up/downregulated genes and produce fasta file of upstream sequences

# %%
regulation_type_dict = {}
p_val_dict = {}
downreg_genes = pd.read_excel(project_dir + '/2022-10-02_data_NU_NAs_renamed.xlsx', sheet_name = 'significant genes downregulated')
upreg_genes = pd.read_excel(project_dir + '/2022-10-02_data.xlsx', sheet_name = 'significant genes upregulated')
all_genes = pd.read_excel(project_dir + '/2022-10-02_data.xlsx', sheet_name = 'all genes')
gene_list = []
for i, r in downreg_genes.iterrows():
    gene_list.append(r['Locus'])
    regulation_type_dict[r['Locus']] = 'Downregulated'
for i, r in upreg_genes.iterrows():
    gene_list.append(r['Locus'])
    regulation_type_dict[r['Locus']] = 'Upregulated'
for i, r in all_genes.iterrows():
    if r['padj'] == 'NA':
        p_val_dict[r['Locus']] = 999
    else:    
        p_val_dict[r['Locus']] = r['padj']

# %%
significant_upstream_tb_regions = []
temp_dict = {}
for gene in gene_list:
    locus = tb_species + '@' + str(gene)
    if locus in mycobacteria_upstream_dict:
        upstream_region = mycobacteria_upstream_dict[locus][3]  
        (start, stop) = (mycobacteria_upstream_dict[locus][0],  mycobacteria_upstream_dict[locus][1])
        if (start, stop) in temp_dict:
            pass  # Eliminate upstream region if already there (e.g if neighbouring divergent pair)
        else:
            temp_dict[(start, stop)] = 1      
            if len(upstream_region) >= min_region_length:
                significant_upstream_tb_regions.append([locus, upstream_region])
util.produce_fasta_file(significant_upstream_tb_regions, project_dir + '/significant_upstream_tb_regions.faa')
# Out:
# 100%|██████████| 175/175 [00:00<00:00, 175137.96it/s]

# %% [markdown]
# #### Run MEME, search against tb using FIMO and process hits into final MEME Run = Second_MEME_Upstream_Output

# %%
run_fimo(project_dir + '/MEME_Upstream_Output/meme.txt', project_dir + '/mtb_seq' , project_dir + '/FIMO_Upstream_Output')
fimo_upstream_hits = pd.read_csv(project_dir + '/FIMO_Upstream_Output/fimo.tsv', sep='\t')
produce_matched_sequence_file(fimo_upstream_hits, project_dir + '/fimo_upstream_hit_sequences.faa', q_value = 1e-3)
run_meme(project_dir + '/fimo_upstream_hit_sequences.faa', project_dir + '/Second_MEME_Upstream_Output',3,5)
# Out:
# 100%|██████████| 110/110 [00:00<?, ?it/s]

# %% [markdown]
# ##### Produce FIMO hits for TB and all mycobacteria and all actinobacteria

# %%
run_fimo(project_dir + '/Second_MEME_Upstream_Output/meme.txt', project_dir + '/mtb_seq' , project_dir + '/Second_FIMO_Upstream_Output')

# %%
run_fimo(project_dir + '/Second_MEME_Upstream_Output/meme.txt', project_dir + '/all_seq' , project_dir + '/All_Species_Second_FIMO_Upstream_Output')

# %%
run_fimo(project_dir + '/Second_MEME_Upstream_Output/meme.txt', project_dir + '/all_actinobacteria_seq' , project_dir + '/All_Actinobacteria_Species_Second_FIMO_Upstream_Output')

# %% [markdown]
# #### Use all species hits as a template for MEME (All_Species_Output) and search these motifs in other species (then refine into motif and search again),  Hits in /Single_Species_MEME_FIMO Final motif in /Temp_Second_Meme_Upstream_Output,

# %%
fimo_upstream_hits = pd.read_csv(project_dir + '/All_Species_Second_FIMO_Upstream_Output/fimo.tsv', sep='\t')
produce_matched_sequence_file(fimo_upstream_hits, project_dir + '/all_species_hit_sequences.faa', q_value = 1e-3)
run_meme(project_dir + '/all_species_hit_sequences.faa', project_dir + '/All_Species_Output',3,5)

# %%
if full_run == True:
    for dirname in tqdm(mycobacteria_dirs):
        temp = []
        for genome_record in (SeqIO.parse(mycobacteria_seq_dir + '/' + dirname + '/genomic.gbff', "genbank")):
            ntsequence = str(genome_record.seq)
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            temp.append([accession_ver, ntsequence])
        util.produce_fasta_file(temp, project_dir + '/temp_seq')
        run_fimo(project_dir + '/All_Species_Output/meme.txt', project_dir + '/temp_seq' , project_dir + '/Single_Species_MEME_FIMO/' + dirname)
        fimo_upstream_hits = pd.read_csv(project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/fimo.tsv', sep='\t')
        produce_matched_sequence_file(fimo_upstream_hits, project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/temp_fimo_upstream_hit_sequences.faa', q_value = 1e-3)
        run_meme(project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/temp_fimo_upstream_hit_sequences.faa', project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/Temp_Second_MEME_Upstream_Output',3,5)

        run_fimo(project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/Temp_Second_MEME_Upstream_Output/meme.txt', project_dir + '/temp_seq' , project_dir + '/Single_Species_MEME_FIMO/' + dirname)
        fimo_upstream_hits = pd.read_csv(project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/fimo.tsv', sep='\t')
        produce_matched_sequence_file(fimo_upstream_hits, project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/temp_fimo_upstream_hit_sequences.faa', q_value = 1e-3)
        run_meme(project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/temp_fimo_upstream_hit_sequences.faa', project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/Temp_Second_MEME_Upstream_Output',3,5)

# %% [markdown]
# #### Produce dictionary of hits for each species based on ortholog of hits in M.tb

# %%
appearance_dict = {}
for dirname in tqdm(mycobacteria_dirs):
    temp_set = set()
    temp_set_2 = set()
    temp_list_3 = []
    temp_fimo_hits = pd.read_csv(project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/fimo.tsv', sep='\t')
    for i, r in temp_fimo_hits.iterrows():
        if '#' in r['motif_id']:
            continue
        organism = r['sequence_name']
        motif_id = r['motif_alt_id']
        if float(r['q-value']) < 1e-5:
            temp = location(r['sequence_name'],int(r['start']), int(r['stop']), cds_annotated_regions_dict)
            ortholog_orientations = []
            for x in temp:
                if len(x[0].split(':')) == 1:
                    ortholog_orientations.append((ortholog_in_mtb(organism, x[0]), 'I'))
                else:
                    a = x[0].split(':')
                    b = x[4].split(':')
                    if b[0] == '1':
                        ortholog_orientations.append((ortholog_in_mtb(organism, a[0]), 'U'))
                    else:
                        ortholog_orientations.append((ortholog_in_mtb(organism, a[0]), 'D'))
                    if b[1] == '1':
                        ortholog_orientations.append((ortholog_in_mtb(organism, a[1]), 'D'))
                    else:
                        ortholog_orientations.append((ortholog_in_mtb(organism, a[1]), 'U'))
            for x in ortholog_orientations:
                temp_list_3.append(x)                                          
            temp2 = ([x[0].split(':') for x in temp])
            for x in temp2:
                temp_set = temp_set.union({ortholog_in_mtb(organism, w) for w in set(x)})
                temp_set_2 = temp_set_2.union(set(x))
    #print(temp_set)
    temp_set_3 = set(temp_list_3)
    
    for ortholog in temp_set_3:
        if ortholog in appearance_dict:
            appearance_dict[ortholog].append(dirname_dict[dirname])
        else:
            appearance_dict[ortholog] = [dirname_dict[dirname]]
# Out:
# 100%|██████████| 100/100 [05:26<00:00,  3.26s/it]

# %%
out_file = []
temp = []
for k, v in appearance_dict.items():
    temp.append((k[0], k[1], len(v), v))
temp.sort(key = lambda x: x[2], reverse = True)
for (x, y, l, m) in temp:
    if 1==1:
        out_file.append([str(x)+'_'+str(y), l])
    #print(x, y, l, m)
out_df = pd.DataFrame(out_file, columns = ['Orthologue_region', 'Species_hits'])
out_df.to_csv(project_dir + '/out_df.csv')
#sns.barplot(data = out_df, x = 'Orthologue_region', y = 'Species_hits')
#plt.xticks(rotation=45)

# %% [markdown]
# #### Output motifs per species for display in R

# %%
temp = []
from Bio import motifs
dirnames = ['GCA_010726505.1']
for dirname in mycobacteria_dirs:
    filename = project_dir + '/Single_Species_MEME_FIMO/'+dirname +'/Temp_Second_MEME_Upstream_Output/meme.xml'
    if os.path.exists(filename):
        with open(filename) as f:
            record = motifs.parse(f, 'MEME')
        for motif in record:
            if motif.id == 'motif_1':
                temp.append([dirname_dict[dirname].replace(' ','_').replace('[','').replace(']',''), str(motif.consensus)])
util.produce_fasta_file(temp, project_dir + '/unaligned_motifs.faa')
cline = MuscleCommandline(muscle_exe, input= project_dir + '/unaligned_motifs.faa', out = project_dir + '/aligned_motifs.faa')
stdout, stderr = cline()
# Out:
# 100%|██████████| 66/66 [00:00<00:00, 65973.32it/s]

# %%
temp = util.read_fasta_to_array(project_dir + '/aligned_motifs.faa')

# %%
for dirname in mycobacteria_dirs:
    species = dirname_dict[dirname].replace(' ','_').replace('[','').replace(']','')
    if species in temp[0]:
        pass
    else:
        temp[0].append(species)
        temp[1].append('-'*len(temp[1][0]))
temp_2 = []
for (x, y) in zip(temp[0],temp[1]):
    temp_2.append([x,y])
util.produce_fasta_file(temp_2, project_dir + '/aligned_motifs_plus_blanks.faa')
# Out:
# 100%|██████████| 100/100 [00:00<?, ?it/s]

# %% [markdown]
# #### Final motif and searches

# %%
#temp_fimo_hits = pd.read_csv(project_dir + '/Second_FIMO_Upstream_Output/fimo.tsv', sep='\t')
hit_dict = {}
for dirname in tqdm(mycobacteria_dirs):
    temp_fimo_hits = pd.read_csv(project_dir + '/Single_Species_MEME_FIMO/' + dirname + '/fimo.tsv', sep='\t')

    for i, r in temp_fimo_hits.iterrows():
        if '#' in r['motif_id']:
            continue
        organism = r['sequence_name']
        motif_id = r['motif_alt_id']
        temp = location(r['sequence_name'],int(r['start']), int(r['stop']), annotated_regions_dict)
        if len(temp) > 0:
            temp.sort(key = lambda x: float(x[3].strip('%')), reverse = True)
            main_location = temp[0] #temp[0]
        else:
            main_location = ''
        info = [int(r['start']), int(r['stop']), r['strand'], float(r['q-value']), main_location, r['matched_sequence'], r['motif_alt_id']]
        if organism in hit_dict:
            hit_dict[organism].append(info)
        else:
            hit_dict[organism] = [info]

for k, v in hit_dict.items():
    v.sort(key = lambda x: x[0])
# Out:
# 100%|██████████| 100/100 [07:06<00:00,  4.26s/it]

# %% [markdown]
# #### Print tb hits

# %%
for n, (start, stop, strand, q, loc, matched_seq, motif_id) in enumerate(hit_dict[tb_species]):
    if q > 1e-2 or not(motif_id == 'MEME-1'):
        continue
    print((start, stop, strand, q, loc, matched_seq, motif_id))

# %% [markdown]
# #### Print tb hits split by whether they are near (the motif + 17 complement motif pattern)

# %%
paired_motif_sequences = []
unpaired_motif_sequences = []
temp_df_list =[]
gene_pairs = []
sole_genes = []
inter_distances = []
occurrences = 0
pairs = 0
no_pairs = 0
v = hit_dict[tb_species]
last_stop = -999
pair_poss = 0
for n, (start, stop, strand, q, loc, matched_seq, motif_id) in enumerate(v):
    if q > 1e-2 or not(motif_id == 'MEME-1'):
        continue
    else:
        occurrences +=1
        if start - last_stop < 100 and pair_poss == 1:
            inter_distances.append(start-last_stop)
            last_temp = copy.deepcopy(v[last_n])
            last_temp.append("paired")
            latest_temp = copy.deepcopy(v[n])
            latest_temp.append("paired")
            temp_df_list.append(last_temp)
            temp_df_list.append(latest_temp)
            if start - last_stop < 20:
                genes = v[n][4][0].split(":")
                genes2 = v[last_n][4][0].split(":")
                pref = 'H37Rv_'
                for gene in genes:
                    if gene in set(gene_list):
                        pref = v[n][4][0] + '___H37Rv_'
                for gene in genes2:
                    if gene in set(gene_list):
                        pref = v[last_n][4][0] + '___H37Rv_'
                paired_motif_sequences.append([pref+str(v[last_n][0])+'_'+str(v[n][1]), mtb_sequence[v[last_n][0]:v[n][1]]])
            pair_poss = 0
            pairs+=1
            for x in v[n][4][0].split(':'):
                gene_pairs.append(x)
            for x in v[last_n][4][0].split(':'):
                gene_pairs.append(x)

        elif pair_poss == 1:
            last_temp = copy.deepcopy(v[last_n])
            last_temp.append("Unpaired")
            temp_df_list.append(last_temp)
            #print("no_pair", v[last_n])
            no_pairs+=1#
            for x in v[last_n][4][0].split(':'):
                sole_genes.append(x)
            genes2 = v[last_n][4][0].split(":")
            pref = 'NP_H37Rv_'
            for gene in genes2:
                if gene in set(gene_list):
                    pref = v[last_n][4][0] + '___NP_H37Rv_'
            if v[last_n][2] == '+':
                unpaired_motif_sequences.append([pref+str(v[last_n][0]-30)+'_'+str(v[last_n][1]+40), mtb_sequence[v[last_n][0]-30:v[last_n][1]+40]])
            else:
                unpaired_motif_sequences.append([pref+str(v[last_n][0]-30)+'_'+str(v[last_n][1]+40), util.reverse_complement(mtb_sequence[v[last_n][0]-30:v[last_n][1]+40])])
        else:
            pair_poss=1
        last_stop = stop
        last_n = n
print(pairs, no_pairs)
print(len(inter_distances))
print(inter_distances)
print(occurrences)
# Out:
# 69 23
# 69
# [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 98, 17, 17, 17, 17, 19, 17, 17, 17, 17, 17, 17, 16, 17, 17, 17, 17, 17, 18, 17, 17, 17, 17, 17, 17, 18, 17, 17, 17, 14, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]
# 162

# %%
util.produce_fasta_file(paired_motif_sequences, project_dir + '/unaligned_pair_motifs.faa')
cline = MuscleCommandline(muscle_exe, input= project_dir + '/unaligned_pair_motifs.faa', out = project_dir + '/aligned_pair_motifs.faa')
stdout, stderr = cline()
util.produce_fasta_file(unpaired_motif_sequences, project_dir + '/unaligned_unpaired_motifs.faa')
cline = MuscleCommandline(muscle_exe, input= project_dir + '/unaligned_unpaired_motifs.faa', out = project_dir + '/aligned_unpaired_motifs.faa')
stdout, stderr = cline()
# Out:
# 100%|██████████| 68/68 [00:00<?, ?it/s]
# 100%|██████████| 23/23 [00:00<?, ?it/s]

# %%
blastfn.convert_fasta_to_stockholm(project_dir, 'aligned_pair_motifs.faa', 'aligned_pair_motifs.sto')
blastfn.run_rscape(project_dir, 'aligned_pair_motifs.sto', 'rscape_')

# %%
temp= pd.DataFrame(temp_df_list, columns = ['start','stop','strand','q_val','region_info','matched_seq','motif','pair'])

# %%
temp['study_association'] = ''
for i, r in temp.iterrows():
    temp.at[i, 'type'] = r['region_info'][2]
    temp.at[i, 'product'] = r['region_info'][1]
    temp.at[i,'pct_occupancy'] = r['region_info'][3]
    genes = r['region_info'][0].split(":")
    associated_genes = []
    for gene in genes:
        if gene in set(gene_list):
            associated_genes.append(gene)
    temp.at[i, 'study_association'] = associated_genes
temp.to_csv(project_dir + '/motif_hits.csv')

# %%
temp
# Out:
#        start     stop strand         q_val  \
# 0      93380    93401      +  3.650000e-03
# 1     183232   183253      -  1.030000e-03
# 2     183270   183291      +  9.690000e-07
# 3     231365   231386      +  5.810000e-03
# 4     234447   234468      -  7.910000e-08
# ..       ...      ...    ...           ...
# 156  4237935  4237956      -  8.640000e-08
# 157  4237973  4237994      +  2.280000e-07
# 158  4246526  4246547      -  1.110000e-07
# 159  4246564  4246585      +  3.930000e-08
# 160  4252853  4252874      -  5.600000e-07
#
#                                            region_info  \
# 0    [Rv0085, Possible hydrogenase HycP, CDS, 100%, 1]
# 1    [Rv0154c:Rv0155, Probable acyl-CoA dehydrogena...
# 2    [Rv0154c:Rv0155, Probable acyl-CoA dehydrogena...
# 3    [Rv0195, Possible two component transcriptiona...
# 4      [Rv0197, Possible oxidoreductase, CDS, 100%, 1]
# ..                                                 ...
# 156  [Rv3792, Arabinofuranosyltransferase AftA, CDS...
# 157  [Rv3792, Arabinofuranosyltransferase AftA, CDS...
# 158  [Rv3795, Integral membrane indolylacetylinosit...
# 159  [Rv3795, Integral membrane indolylacetylinosit...
# 160  [Rv3797, Probable acyl-CoA dehydrogenase FadE3...
#
#                 matched_seq   motif      pair study_association  \
# 0    GGGCCATTGTGCGGCTGCTGGC  MEME-1  Unpaired                []
# 1    AGGGACTTATGCGTCTGCTAGC  MEME-1    paired         [Rv0154c]
# 2    AGGGGGTTTTGCGTCTGCTCGC  MEME-1    paired         [Rv0154c]
# 3    TGGCGGTGCTGCGTCTGCTAGC  MEME-1  Unpaired                []
# 4    GGGCGATTCTGCGTCTGCTCGG  MEME-1  Unpaired                []
# ..                      ...     ...       ...               ...
# 156  GGGGGCTTTTGCGTCTGCTCGG  MEME-1    paired          [Rv3792]
# 157  GGGGGCTTTTACGTCTGCTCGC  MEME-1    paired          [Rv3792]
# 158  GGGTGCTTTTGCGTCTGCTCGC  MEME-1    paired          [Rv3795]
# 159  GGGGGCTTTTGCGTCTGCTCGC  MEME-1    paired          [Rv3795]
# 160  GGGGGCTTTTACGTCTGCTCGG  MEME-1  Unpaired                []
#
#               type                                            product  \
# 0              CDS                          Possible hydrogenase HycP
# 1    Inter-feature  Probable acyl-CoA dehydrogenase FadE2:Probable...
# 2    Inter-feature  Probable acyl-CoA dehydrogenase FadE2:Probable...
# 3              CDS  Possible two component transcriptional regulat...
# 4              CDS                            Possible oxidoreductase
# ..             ...                                                ...
# 156            CDS                   Arabinofuranosyltransferase AftA
# 157            CDS                   Arabinofuranosyltransferase AftA
# 158            CDS  Integral membrane indolylacetylinositol arabin...
# 159            CDS  Integral membrane indolylacetylinositol arabin...
# 160            CDS             Probable acyl-CoA dehydrogenase FadE35
#
#     pct_occupancy
# 0            100%
# 1            100%
# 2            100%
# 3            100%
# 4            100%
# ..            ...
# 156          100%
# 157          100%
# 158          100%
# 159          100%
# 160           61%
#
# [161 rows x 12 columns]

# %%
genes = []
v = hit_dict[tb_species]
for (start, stop, strand, q, loc, matched_seq, motif_id) in v:
    if q > 1e-2 or not(motif_id == 'MEME-1'):
        continue
    for x in loc[0].split(':'):
        genes.append(x)

# %%
b = set(genes)
inters = b.intersection(set(gene_list))
print(len(b), len(inters), len(gene_list))
print(1- binom.cdf(len(inters), len(b),(len(gene_list))/4031))
# Out:
# 163 20 236
# 0.0005947770818272025

# %%
a = list(b.intersection(set(gene_list)))
a.sort()
a
# Out:
# ['Rv0154c',
#  'Rv0211',
#  'Rv0467',
#  'Rv0468',
#  'Rv0711',
#  'Rv0860',
#  'Rv0896',
#  'Rv0926c',
#  'Rv0927c',
#  'Rv1058',
#  'Rv1180',
#  'Rv2845c',
#  'Rv2846c',
#  'Rv3028c',
#  'Rv3140',
#  'Rv3319',
#  'Rv3383c',
#  'Rv3416',
#  'Rv3792',
#  'Rv3795']

# %%
for k, v in hit_dict.items():
    for x in v:
        print(x)

# %% [markdown]
# #### Number of motif hits in different species and output so can be merged with R to display info against phylo tree

# %%
hit_info = []
for k, v in hit_dict.items():
    temp = []
    for (start, stop, strand, q, loc, matched_seq) in v:
        for x in loc[0].split(':'):
            temp.append(x)
    hit_info.append([names_dict[k].replace(' ','_'),'Num_hits', len(set(temp))])
pd.DataFrame(hit_info, columns = ['name', 'variable', 'value']).to_csv(project_dir + '/Hit_Counts.csv')

# %%
tb_mycobacteria_rbh = pd.read_csv(project_dir + '/tb_mycobacteria_reciprocal_best_hits.csv')
ortholog_info = []
Rv_2242_orthologs = []
temp = tb_species+"@"+"Rv2242"
temp = tb_mycobacteria_rbh.query('query_ref == @temp')
for i, r in temp.iterrows():
    Rv_2242_orthologs.append(r['target_species_name'].replace(' ','_'))
for dirname in mycobacteria_dirs:
    species = dirname_dict[dirname].replace(' ','_').replace('[','').replace(']','')
    if species in Rv_2242_orthologs:
        ortholog_info.append([species, 'Ortholog', 1])
    else:
        ortholog_info.append([species, 'Ortholog', 0])
pd.DataFrame(ortholog_info, columns = ['name', 'variable', 'value']).to_csv(project_dir + '/Rv_2242_Hits.csv')

# %%
for dirname in mycobacteria_dirs:
    species = dirname_dict[dirname].replace(' ','_').replace('[','').replace(']','')

# %%
temp = tb_species+"@"+"Rv2242"
temp = tb_mycobacteria_rbh.query('query_ref == @temp')
temp2 = tb_mycobacteria_rbh
set((list(temp['target_species_name'].unique()))).symmetric_difference(set((list(temp2['target_species_name'].unique()))))
temp
# Out:
#         Unnamed: 0          query_ref                     target_ref  \
# 146346      452995  AL123456.3@Rv2242         CP097320.1@M5I08_12060
# 146347      452966  AL123456.3@Rv2242      LR130759.1@MB901379_03007
# 146348      452992  AL123456.3@Rv2242          AP022606.1@MBRA_35650
# 146349      452960  AL123456.3@Rv2242          HE572590.1@MCAN_22641
# 146350      452981  AL123456.3@Rv2242          AP022613.1@MCNS_32520
# ...            ...                ...                            ...
# 146440      453042  AL123456.3@Rv2242  LT906483.1@SAMEA4412656_01789
# 146441      453006  AL123456.3@Rv2242          AP022600.1@MTOK_56240
# 146442      453051  AL123456.3@Rv2242           CP011491.1@MYVA_3575
# 146443      453029  AL123456.3@Rv2242           CP000511.1@Mvan_3753
# 146444      453054  AL123456.3@Rv2242          AP018165.1@MSTE_01798
#
#         query_length  subject_length  percent_identical_matches  \
# 146346           414             437                     83.902
# 146347           414             436                     92.067
# 146348           414             435                     84.300
# 146349           414             414                    100.000
# 146350           414             446                     88.889
# ...              ...             ...                        ...
# 146440           414             428                     75.550
# 146441           414             429                     80.549
# 146442           414             427                     74.572
# 146443           414             428                     75.245
# 146444           414             426                     70.202
#
#         alignment_length  number_mismatches  number_of_gap_openings  \
# 146346               410                 55                       2
# 146347               416                 27                       2
# 146348               414                 57                       1
# 146349               414                  0                       0
# 146350               414                 45                       1
# ...                  ...                ...                     ...
# 146440               409                 89                       2
# 146441               401                 70                       1
# 146442               409                 93                       2
# 146443               408                 90                       2
# 146444               396                109                       2
#
#         query_start_alignment  ...  target_start_alignment  \
# 146346                      1  ...                       1
# 146347                      1  ...                       1
# 146348                      1  ...                       1
# 146349                      1  ...                       1
# 146350                      1  ...                       1
# ...                       ...  ...                     ...
# 146440                      1  ...                       1
# 146441                      8  ...                       6
# 146442                      1  ...                       2
# 146443                      1  ...                       1
# 146444                     13  ...                      16
#
#         target_end_alignment  e_value  bit_score  query_species  \
# 146346                   399      0.0      683.0     AL123456.3
# 146347                   413      0.0      736.0     AL123456.3
# 146348                   406      0.0      700.0     AL123456.3
# 146349                   414      0.0      832.0     AL123456.3
# 146350                   413      0.0      715.0     AL123456.3
# ...                      ...      ...        ...            ...
# 146440                   398      0.0      584.0     AL123456.3
# 146441                   398      0.0      619.0     AL123456.3
# 146442                   399      0.0      561.0     AL123456.3
# 146443                   397      0.0      590.0     AL123456.3
# 146444                   402      0.0      555.0     AL123456.3
#
#        target_species                query_species_name  \
# 146346     CP097320.1  Mycobacterium tuberculosis H37Rv
# 146347     LR130759.1  Mycobacterium tuberculosis H37Rv
# 146348     AP022606.1  Mycobacterium tuberculosis H37Rv
# 146349     HE572590.1  Mycobacterium tuberculosis H37Rv
# 146350     AP022613.1  Mycobacterium tuberculosis H37Rv
# ...               ...                               ...
# 146440     LT906483.1  Mycobacterium tuberculosis H37Rv
# 146441     AP022600.1  Mycobacterium tuberculosis H37Rv
# 146442     CP011491.1  Mycobacterium tuberculosis H37Rv
# 146443     CP000511.1  Mycobacterium tuberculosis H37Rv
# 146444     AP018165.1  Mycobacterium tuberculosis H37Rv
#
#                               target_species_name species_count  \
# 146346  Candidatus Mycobacterium methanotrophicum           101
# 146347                   Mycobacterium basiliense           101
# 146348                     Mycobacterium branderi           101
# 146349      Mycobacterium canettii CIPT 140010059           101
# 146350                   Mycobacterium conspicuum           101
# ...                                           ...           ...
# 146440        Mycolicibacterium thermoresistibile           101
# 146441                Mycolicibacterium tokaiense           101
# 146442             Mycolicibacterium vaccae 95051           101
# 146443        Mycolicibacterium vanbaalenii PYR-1           101
# 146444            [Mycobacterium] stephanolepidis           101
#
#         reciprocal_best_hit
# 146346                    Y
# 146347                    Y
# 146348                    Y
# 146349                    Y
# 146350                    Y
# ...                     ...
# 146440                    Y
# 146441                    Y
# 146442                    Y
# 146443                    Y
# 146444                    Y
#
# [99 rows x 21 columns]

# %% [markdown]
# #### Build phylo tree

# %%
max_len = len(tb_mycobacteria_rbh['target_species_name'].unique())

# %%
full_ortholog_refs = []
temp = tb_mycobacteria_rbh.groupby('query_ref').agg({'target_ref': "count", 'percent_identical_matches': "min"}).reset_index()
temp = temp.query('target_ref == @max_len and percent_identical_matches > 85')
for i, r in temp.iterrows():
    full_ortholog_refs.append(r['query_ref'])

# %%
def generate_protein_dataset(num_subsets, subset_num, dir_list, seqdir): 
    sequence_dirs = util.chunk_list(dir_list, num_subsets, subset_num)
    all_cds = []
    for dirname in (sequence_dirs):
        for genome_record in SeqIO.parse(seqdir + '/' + dirname + '/genomic.gbff', "genbank"):
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            full_sequence = str(genome_record.seq)
            for feature in genome_record.features:
                a = feature.qualifiers
                if feature.type == 'CDS' and a.get("translation") != None and a.get("locus_tag") != None:
                    locus_tag = a.get("locus_tag")[0]
                    accession_locus = accession_ver + '@' + locus_tag
                    translation = a.get("translation")[0]
                    all_cds.append([accession_locus, translation])
    return (all_cds)

# %%
full_build = True
if full_build == True:
    parallel_output = Parallel(n_jobs=-1)(delayed(generate_protein_dataset)(num_cores, core_number, mycobacteria_dirs, mycobacteria_seq_dir) for core_number in core_numbers)
    protein_dict = {}
    for x in parallel_output:
        for temp in x[0]:
            protein_dict[temp[0]] = temp[1]

# %%
concatenated_alignment_dict = {}
for ref in tqdm(full_ortholog_refs):
    temp_seq = []
    temp = tb_mycobacteria_rbh[tb_mycobacteria_rbh['query_ref'] == ref]
    for i, r in temp.iterrows():
        temp_seq.append([r['target_species_name'].replace(' ','_'),protein_dict[r['target_ref']]])
    util.produce_fasta_file(temp_seq, project_dir +'/temp_seq.fasta')    
    cline = MuscleCommandline(muscle_exe, input= project_dir +'/temp_seq.fasta', out=project_dir +'/temp_seq_alignment.fasta')
    result = cline();    
    alignment = util.read_fasta_to_array(project_dir +'/temp_seq_alignment.fasta')    
    for (name, sequence) in zip(alignment[0], alignment[1]):
        if name in concatenated_alignment_dict:
            temp2 = concatenated_alignment_dict[name]
            concatenated_alignment_dict[name] = temp2 + sequence
        else:
            concatenated_alignment_dict[name] = sequence
temp  = []
for k, v in concatenated_alignment_dict.items():
    temp.append([k, v])
util.produce_fasta_file(temp, project_dir + '/concatenated_alignment.fasta')

# %% [markdown]
# ####  Actinobacteria hits

# %%
actinobacteria_names_dict = {}
for dirname in tqdm(actinobacteria_dirs):
    for genome_record in (SeqIO.parse(actinobacteria_seq_dir + '/' + dirname + '/genomic.gbff', "genbank")):
        accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
        actinobacteria_names_dict[accession_ver] = genome_record.annotations['organism']
# Out:
# 100%|██████████| 645/645 [05:23<00:00,  1.99it/s]

# %%
hit_dict = {}
temp_fimo_hits = pd.read_csv(project_dir + '/All_Actinobacteria_Species_Second_FIMO_Upstream_Output/fimo.tsv', sep='\t')
for i, r in temp_fimo_hits.iterrows():
    if '#' in r['motif_id']:
        continue
    organism = actinobacteria_names_dict[r['sequence_name']]
    motif_id = r['motif_alt_id']
    q_val = float(r['q-value'])
    if q_val < 1e-3 and motif_id == 'MEME-1' and not('Myco' in organism):
        print(organism, motif_id, q_val)
# Out:
# Corynebacterium singulare MEME-1 0.000512
# Gordonia iterans MEME-1 0.000793
# Gordonia amicalis MEME-1 0.000835
# Salinispora tropica CNB-440 MEME-1 0.000835
# Streptomyces tirandamycinicus MEME-1 0.000869
# Corynebacterium epidermidicanis MEME-1 0.000873
# Rathayibacter rathayi MEME-1 0.00094
# Rhodococcus opacus PD630 MEME-1 0.000946
# Streptomyces genisteinicus MEME-1 0.000993

# %%
actinobacteria_names_dict
# Out:
# {'LR134406.1': 'Arachnia propionica',
#  'LR134442.1': 'Propionibacterium australiense',
#  'LR134476.1': 'Trueperella bialowiezensis',
#  'LR134477.1': 'Actinomyces viscosus',
#  'LR134479.1': 'Rothia aeria',
#  'LR134501.1': 'Nocardiopsis dassonvillei',
#  'LS483427.1': 'Arcanobacterium haemolyticum',
#  'LS483464.1': 'Corynebacterium renale',
#  'LS483460.1': 'Corynebacterium minutissimum',
#  'LS483468.1': 'Rhodococcus coprophilus',
#  'LR026975.1': 'Mycolicibacterium hassiacum DSM 44199',
#  'LR134350.1': 'Actinomyces howellii',
#  'LR134352.1': 'Nocardia asteroides',
#  'LR134356.1': 'Mycolicibacterium aurum',
#  'LT906441.1': 'Cutibacterium granulosum',
#  'LT906453.1': 'Dermatophilus congolensis',
#  'LT906483.1': 'Mycolicibacterium thermoresistibile',
#  'LT906469.1': 'Mycolicibacter terrae',
#  'LT906467.1': 'Corynebacterium imitans',
#  'LT906481.1': 'Corynebacterium urealyticum',
#  'LT906473.1': 'Corynebacterium cystitidis',
#  'LT985188.1': 'Micropruina glycogenica',
#  'LR130759.1': 'Mycobacterium basiliense',
#  'LS483423.1': 'Jonesia denitrificans',
#  'CP116355.1': 'Streptomyces xanthophaeus',
#  'CP116356.1': 'Streptomyces xanthophaeus',
#  'CP116357.1': 'Streptomyces xanthophaeus',
#  'CP063191.1': 'Corynebacterium heidelbergense',
#  'CP063192.1': 'Corynebacterium heidelbergense',
#  'CP063194.1': 'Corynebacterium jeddahense',
#  'CP117869.1': 'Arthrobacter agilis',
#  'CP117870.1': 'Arthrobacter agilis',
#  'CP117872.1': 'Arthrobacter agilis',
#  'CP117871.1': 'Arthrobacter agilis',
#  'CP118233.1': 'Micromonospora chalcea',
#  'LT593929.1': 'Propionibacterium freudenreichii',
#  'CP113264.1': 'Streptomonospora nanhaiensis',
#  'CP113265.1': 'Streptomonospora nanhaiensis',
#  'CP114413.1': 'Streptomyces cinnabarinus',
#  'CP114203.1': 'Streptomyces nigrescens',
#  'CP114204.1': 'Streptomyces nigrescens',
#  'CP073767.1': 'Dactylosporangium aurantiacum',
#  'CP107020.1': 'Brachybacterium huguangmaarense',
#  'CP107021.1': 'Brachybacterium huguangmaarense',
#  'CP107222.1': 'Microbacterium terricola',
#  'CP084204.1': 'Streptomyces tanashiensis',
#  'CP103060.1': 'Streptomyces albus',
#  'CP103061.1': 'Streptomyces albus',
#  'CP073720.1': 'Dactylosporangium fulvum',
#  'CP104302.1': 'Mycolicibacterium brumae',
#  'CP073721.1': 'Dactylosporangium roseum',
#  'CP101471.1': 'Microbacterium liquefaciens',
#  'CP072934.1': 'Corynebacterium pseudogenitalium',
#  'CP102415.1': 'Amycolatopsis roodepoortensis',
#  'CP102514.1': 'Streptomyces yangpuensis',
#  'CP102517.1': 'Streptomyces yangpuensis',
#  'CP102515.1': 'Streptomyces yangpuensis',
#  'CP102516.1': 'Streptomyces yangpuensis',
#  'CP102850.1': 'Gordonia mangrovi',
#  'CP099837.1': 'Nocardiopsis exhalans',
#  'CP099838.1': 'Nocardiopsis exhalans',
#  'CP046605.1': 'Corynebacterium accolens',
#  'CP097650.1': 'Micrococcus yunnanensis',
#  'CP099468.1': 'Streptomyces phaeoluteigriseus',
#  'CP099469.1': 'Streptomyces phaeoluteigriseus',
#  'CP099470.1': 'Streptomyces phaeoluteigriseus',
#  'CP099547.1': 'Arcanobacterium pinnipediorum',
#  'CP051627.1': 'Thermobifida alba',
#  'CP097218.1': 'Brachybacterium kimchii',
#  'CP097219.1': 'Brachybacterium kimchii',
#  'CP097289.1': 'Streptomyces durmitorensis',
#  'CP097290.1': 'Streptomyces durmitorensis',
#  'CP097320.1': 'Candidatus Mycobacterium methanotrophicum',
#  'CP097321.1': 'Candidatus Mycobacterium methanotrophicum',
#  'CP097332.1': 'Jatrophihabitans telluris',
#  'CP093326.1': 'Arthrobacter sulfonylureivorans',
#  'CP093327.1': 'Arthrobacter sulfonylureivorans',
#  'CP071872.1': 'Streptomyces formicae',
#  'CP071873.1': 'Streptomyces formicae',
#  'CP093846.1': 'Streptomyces tubbatahanensis',
#  'CP094533.1': 'Agromyces soli',
#  'CP095552.1': 'Gordonia hongkongensis',
#  'CP095553.1': 'Gordonia hongkongensis',
#  'CP092427.2': 'Mycobacterium rufum',
#  'CP092428.2': 'Mycobacterium rufum',
#  'CP103313.1': 'Mycobacterium rufum',
#  'CP092430.2': 'Mycolicibacter virginiensis',
#  'CP092431.1': 'Streptomyces deccanensis',
#  'CP092488.2': 'Mycobacterium paraterrae',
#  'CP092364.2': 'Mycobacterium goodii',
#  'CP092365.1': 'Mycolicibacillus parakoreensis',
#  'CP092366.2': 'Mycolicibacillus parakoreensis',
#  'CP040786.1': 'Clavibacter phaseoli',
#  'CP040787.1': 'Clavibacter phaseoli',
#  'CP040792.1': 'Clavibacter californiensis',
#  'CP040793.1': 'Clavibacter californiensis',
#  'CP091855.1': 'Gordonia amicalis',
#  'CP018019.1': 'Mycobacterium avium subsp. hominissuis',
#  'CP084681.1': 'Streptomyces inhibens',
#  'CP092362.2': 'Mycolicibacterium crocinum',
#  'CP092363.2': 'Mycolicibacterium crocinum',
#  'CP103314.1': 'Mycolicibacterium crocinum',
#  'CP090063.1': 'Amycolatopsis acidiphila',
#  'CP071516.1': 'Arthrobacter polaris',
#  'CP090347.1': 'Microbacterium binotii',
#  'CP087879.1': 'Agromyces marinus',
#  'CP062221.1': 'Cellulomonas palmilytica',
#  'CP089293.1': 'Paenarthrobacter nicotinovorans',
#  'CP089294.1': 'Paenarthrobacter nicotinovorans',
#  'CP089224.1': 'Mycobacterium ostraviense',
#  'CP086120.1': 'Streptomyces gobiensis',
#  'CP088017.1': 'Ruania halotolerans',
#  'CP088969.1': 'Rhodococcus aetherivorans',
#  'CP082781.1': 'Microbacterium resistens',
#  'CP089226.1': 'Nocardia yamanashiensis',
#  'CP089225.1': 'Nocardia gipuzkoensis',
#  'CP085945.1': 'Mycobacterium intracellulare',
#  'CP085946.1': 'Mycobacterium intracellulare',
#  'CP086254.1': 'Brachybacterium halotolerans subsp. kimchii',
#  'CP086255.1': 'Brachybacterium halotolerans subsp. kimchii',
#  'AP024525.1': 'Corynebacterium cyclohexanicum',
#  'CP087710.1': 'Nocardioides okcheonensis',
#  'CP086119.1': 'Streptomyces huasconensis',
#  'CP088018.1': 'Ruania suaedae',
#  'CP084585.1': 'Cellulomonas iranensis',
#  'CP080203.1': 'Mycetocola spongiae',
#  'CP079233.1': 'Bifidobacterium pseudocatenulatum',
#  'CP079234.1': 'Bifidobacterium pseudocatenulatum',
#  'CP080954.1': 'Rhodococcus opacus PD630',
#  'CP080955.1': 'Rhodococcus opacus PD630',
#  'CP080956.1': 'Rhodococcus opacus PD630',
#  'CP080957.1': 'Rhodococcus opacus PD630',
#  'CP085051.1': 'Corynebacterium uberis',
#  'CP085200.1': 'Mycobacterium ulcerans',
#  'CP085201.1': 'Mycobacterium ulcerans',
#  'CP085974.1': 'Gordonia otitidis',
#  'CP083647.1': 'Corynebacterium falsenii',
#  'CP083590.1': 'Streptomyces mobaraensis',
#  'CP083591.1': 'Streptomyces mobaraensis',
#  'CP084058.1': 'Nonomuraea gerenzanensis',
#  'CP084059.1': 'Nonomuraea gerenzanensis',
#  'CP084060.1': 'Nonomuraea gerenzanensis',
#  'CP082273.1': 'Nocardioides coralli',
#  'CP082331.1': 'Micrococcus luteus',
#  'CP082332.1': 'Micrococcus luteus',
#  'CP061913.1': 'Dactylosporangium vinaceum',
#  'CP082922.1': 'Nocardioides rotundus',
#  'CP082945.1': 'Streptomyces angustmyceticus',
#  'CP080998.1': 'Mycolicibacterium holsaticum DSM 44478 = JCM 12374',
#  'CP080999.1': 'Mycobacterium malmoense',
#  'CP081000.1': 'Mycolicibacterium senegalense',
#  'CP081673.1': 'Mycolicibacterium farcinogenes',
#  'CP081674.1': 'Mycolicibacterium farcinogenes',
#  'CP081675.1': 'Mycolicibacterium farcinogenes',
#  'CP081676.1': 'Mycolicibacterium farcinogenes',
#  'CP082301.1': 'Streptomyces decoyicus',
#  'CP080332.1': 'Mycolicibacterium diernhoferi',
#  'CP080333.1': 'Mycolicibacterium pallens',
#  'CP080334.1': 'Mycolicibacterium pallens',
#  'CP080335.1': 'Mycolicibacterium pallens',
#  'CP080647.1': 'Streptomyces akebiae',
#  'CP080648.1': 'Streptomyces akebiae',
#  'CP080997.1': 'Mycolicibacter heraklionensis',
#  'CP079105.1': 'Skermania piniformis',
#  'CP079216.1': 'Tessaracoccus palaemonis',
#  'CP079698.1': 'Rhodococcus globerulus',
#  'CP068985.1': 'Nonomuraea coxensis DSM 45129',
#  'CP080409.1': 'Nocardioides panacisoli',
#  'CP077258.1': 'Corynebacterium freneyi',
#  'CP059572.1': 'Actinomadura graeca',
#  'CP059573.1': 'Actinomadura graeca',
#  'CP059574.1': 'Actinomadura graeca',
#  'CP078145.1': 'Nocardia iowensis',
#  'CP076456.1': 'Arthrobacter sunyaminii',
#  'CP077062.1': 'Nocardioides panacis',
#  'CP072467.1': 'Spiractinospora alimapuensis',
#  'CP075371.1': 'Nocardioides aquaticus',
#  'CP076022.1': 'Arthrobacter jiangjiafuii',
#  'CP076023.1': 'Cellulomonas dongxiuzhuiae',
#  'CP074371.1': 'Nocardia tengchongensis',
#  'CP074376.1': 'Mycolicibacterium neoaurum',
#  'CP074405.1': 'Cellulomonas wangleii',
#  'CP074404.1': 'Cellulomonas fengjieae',
#  'CP074132.1': 'Nocardiopsis akebiae',
#  'AP023356.1': 'Actinoplanes ianthinogenes',
#  'AP023359.1': 'Polymorphospora rubra',
#  'AP023354.1': 'Actinocatenispora sera',
#  'CP060742.1': 'Streptomyces alfalfae',
#  'CP060743.1': 'Streptomyces alfalfae',
#  'CP073778.1': 'Streptomyces lavendulae subsp. lavendulae',
#  'CP046600.1': 'Mycobacterium spongiae',
#  'CP074133.1': 'Nocardiopsis changdeensis',
#  'CP074134.1': 'Nocardiopsis changdeensis',
#  'CP074135.1': 'Nocardiopsis changdeensis',
#  'CP074136.1': 'Nocardiopsis changdeensis',
#  'CP071974.1': 'Trueperella pecoris',
#  'CP071139.1': 'Streptomyces nojiriensis',
#  'CP071883.1': 'Curtobacterium flaccumfaciens pv. flaccumfaciens',
#  'CP071884.1': 'Curtobacterium flaccumfaciens pv. flaccumfaciens',
#  'CP071696.1': 'Agromyces archimandritae',
#  'CP072387.1': 'Cellulosimicrobium cellulans',
#  'CP072388.1': 'Cellulosimicrobium cellulans',
#  'CP072384.1': 'Arachnia rubra',
#  'CP039124.1': 'Thermobispora bispora',
#  'CP039125.1': 'Thermobispora bispora',
#  'CP022295.1': 'Nocardioides aromaticivorans',
#  'CP014574.1': 'Paenarthrobacter ureafaciens',
#  'CP014575.1': 'Paenarthrobacter ureafaciens',
#  'CP014576.1': 'Paenarthrobacter ureafaciens',
#  'CP071839.1': 'Streptomyces cyanogenus',
#  'CP071868.1': 'Pengzhenrongella sicca',
#  'CP070609.1': 'Rhodococcus koreensis',
#  'CP070610.1': 'Rhodococcus koreensis',
#  'CP070611.1': 'Rhodococcus koreensis',
#  'CP070612.1': 'Rhodococcus koreensis',
#  'CP070613.1': 'Rhodococcus koreensis',
#  'CP070619.1': 'Rhodococcus pseudokoreensis',
#  'CP070618.1': 'Rhodococcus pseudokoreensis',
#  'CP070617.1': 'Rhodococcus pseudokoreensis',
#  'CP070616.1': 'Rhodococcus pseudokoreensis',
#  'CP070615.1': 'Rhodococcus pseudokoreensis',
#  'CP070614.1': 'Rhodococcus pseudokoreensis',
#  'CP070496.1': 'Natronoglycomyces albus',
#  'CP070498.1': 'Natronoglycomyces albus',
#  'CP070497.1': 'Natronoglycomyces albus',
#  'CP070499.1': 'Natronosporangium hydrolyticum',
#  'AP024310.1': 'Mycobacterium heckeshornense',
#  'AP023355.1': 'Actinocatenispora thailandica',
#  'CP069806.1': 'Glutamicibacter protophormiae',
#  'CP069807.1': 'Glutamicibacter protophormiae',
#  'CP069808.1': 'Glutamicibacter protophormiae',
#  'CP070228.1': 'Arcanobacterium phocisimile',
#  'CP070242.1': 'Streptomyces californicus',
#  'CP070241.1': 'Streptomyces californicus',
#  'CP070243.1': 'Streptomyces californicus',
#  'CP070326.1': 'Streptomyces noursei',
#  'CP068156.1': 'Corynebacterium tuberculostearicum',
#  'CP068162.1': 'Corynebacterium glucuronolyticum',
#  'CP068163.1': 'Corynebacterium glucuronolyticum',
#  'CP068161.1': 'Corynebacterium propinquum',
#  'CP068168.1': 'Corynebacterium amycolatum',
#  'AP024251.1': 'Mycobacterium paraintracellulare',
#  'AP024252.1': 'Mycobacterium paraintracellulare',
#  'CP049945.1': 'Streptomyces koyangensis',
#  'CP049946.1': 'Streptomyces koyangensis',
#  'CP044211.1': 'Rhodococcus ruber',
#  'CP044212.1': 'Rhodococcus ruber',
#  'CP044213.1': 'Rhodococcus ruber',
#  'CP066802.1': 'Actinomyces weissii',
#  'CP067012.1': 'Corynebacterium kefirresidentii',
#  'CP067011.1': 'Corynebacterium kefirresidentii',
#  'CP068292.1': 'Corynebacterium macginleyi',
#  'CP068158.1': 'Corynebacterium striatum',
#  'CP048882.1': 'Streptomyces bathyalis',
#  'CP065682.1': 'Brevibacterium casei',
#  'CP066049.1': 'Actinomyces naeslundii',
#  'CP066060.1': 'Actinomyces oris',
#  'CP066061.1': 'Actinomyces oris',
#  'CP066065.1': 'Schaalia meyeri',
#  'CP066831.1': 'Streptomyces liliifuscus',
#  'CP066832.1': 'Streptomyces liliifuscus',
#  'CP064760.1': 'Microbacterium schleiferi',
#  'CP065050.1': 'Streptomyces solisilvae',
#  'CP059991.1': 'Streptomyces gardneri',
#  'CP065253.1': 'Streptomyces clavuligerus',
#  'CP065254.1': 'Streptomyces clavuligerus',
#  'CP063232.1': 'Thermobifida fusca',
#  'AP023172.1': 'Rhodococcus qingshengii',
#  'AP023173.1': 'Rhodococcus qingshengii',
#  'CP063373.1': 'Streptomyces ferrugineus',
#  'CP063374.1': 'Streptomyces chromofuscus',
#  'CP061274.1': 'Clavibacter zhangzhiyongii',
#  'CP119182.1': 'Streptomyces caniscabiei',
#  'CP062938.1': 'Bifidobacterium eulemuris',
#  'CP062948.1': 'Bifidobacterium lemurum',
#  'CP062939.1': 'Bifidobacterium subtile',
#  'CP063169.1': 'Ruania alkalisoli',
#  'CP061344.1': 'Microbacterium hominis',
#  'CP061725.1': 'Micromonospora craniellae',
#  'AP023439.1': 'Streptomyces tuirus',
#  'AP023440.1': 'Streptomyces aurantiacus',
#  'CP061539.1': 'Rothia terrae',
#  'CP062960.1': 'Rothia terrae',
#  'CP062961.1': 'Rothia terrae',
#  'CP062962.1': 'Rothia terrae',
#  'CP062963.1': 'Rothia terrae',
#  'CP061538.1': 'Rothia amarae',
#  'CP062957.1': 'Rothia amarae',
#  'CP062958.1': 'Rothia amarae',
#  'CP062959.1': 'Rothia amarae',
#  'CP060828.1': 'Streptomyces roseirectus',
#  'CP061032.1': 'Corynebacterium lujinxingii',
#  'CP061033.1': 'Corynebacterium zhongnanshanii',
#  'CP046884.1': 'Corynebacterium poyangense',
#  'CP063989.1': 'Actinomyces respiraculi',
#  'CP061281.1': 'Streptomyces xanthii',
#  'CP061282.1': 'Streptomyces xanthii',
#  'CP061283.1': 'Streptomyces xanthii',
#  'CP051006.1': 'Streptomyces griseofuscus',
#  'CP051007.1': 'Streptomyces griseofuscus',
#  'CP051008.1': 'Streptomyces griseofuscus',
#  'CP051009.1': 'Streptomyces griseofuscus',
#  'CP060789.1': 'Tessaracoccus defluvii',
#  'CP060825.1': 'Streptomyces genisteinicus',
#  'CP060826.1': 'Streptomyces genisteinicus',
#  'CP060827.1': 'Streptomyces genisteinicus',
#  'CP060713.1': 'Nocardioides mesophilus',
#  'CP060716.1': 'Leucobacter denitrificans',
#  'AP023396.1': 'Nocardia wallacei',
#  'AP023397.1': 'Nocardia wallacei',
#  'CP046883.1': 'Corynebacterium anserum',
#  'CP060404.1': 'Streptomyces buecherae',
#  'CP059694.1': 'Gordonia rubripertincta',
#  'CP059695.1': 'Gordonia rubripertincta',
#  'CP045704.1': 'Streptomyces rutgersensis',
#  'CP045705.1': 'Streptomyces rutgersensis',
#  'CP043661.1': 'Kribbella qitaiheensis',
#  'CP048813.1': 'Rhodococcus triatomae',
#  'CP060131.1': 'Pseudonocardia petroleophila',
#  'CP058322.1': 'Micromonospora carbonacea',
#  'CP040752.1': 'Streptomyces rectiverticillatus',
#  'CP059165.1': 'Mycobacterium vicinigordonae',
#  'CP059399.1': 'Nocardia huaxiensis',
#  'CP059491.1': 'Gordonia jinghuaiqii',
#  'CP050804.1': 'Arcanobacterium buesumense',
#  'CP053564.1': 'Pseudonocardia broussonetiae',
#  'CP053565.1': 'Pseudonocardia broussonetiae',
#  'CP053566.1': 'Pseudonocardia broussonetiae',
#  'CP053567.1': 'Pseudonocardia broussonetiae',
#  'CP053642.1': 'Actinomyces marmotae',
#  'CP054056.1': 'Aquiluna borgnonia',
#  'CP054938.1': 'Streptomyces harbinensis',
#  'CP054926.1': 'Streptomyces microflavus',
#  'CP054927.1': 'Streptomyces microflavus',
#  'CP054928.1': 'Streptomyces microflavus',
#  'CP035810.1': 'Brevibacterium luteolum',
#  'CP050177.1': 'Streptomyces liangshanensis',
#  'CP061169.1': 'Microbacterium chengjingii',
#  'AP022870.1': 'Phytohabitans flavus',
#  'AP022871.1': 'Phytohabitans suffuscus',
#  'CP064955.1': 'Corynebacterium qintianiae',
#  'CP064956.1': 'Corynebacterium qintianiae',
#  'CP064954.1': 'Corynebacterium lizhenjunii',
#  'CP049257.1': 'Nocardioides anomalus',
#  'CP049863.1': 'Leucobacter viscericola',
#  'CP049866.1': 'Nocardioides piscis',
#  'CP049934.1': 'Leucobacter insecticola',
#  'CP049933.1': 'Leucobacter coleopterorum',
#  'CP049865.1': 'Propioniciclava coleopterorum',
#  'AP022593.1': 'Mycolicibacterium arabiense',
#  'AP022592.1': 'Mycolicibacterium arabiense',
#  'AP022594.1': 'Mycolicibacillus koreensis',
#  'AP022620.1': 'Mycolicibacterium anyangense',
#  'AP022595.1': 'Mycolicibacterium sarraceniae',
#  'AP022596.1': 'Mycolicibacterium helvum',
#  'AP022590.1': 'Mycobacterium mantenii',
#  'AP022591.1': 'Mycolicibacterium celeriflavum',
#  'AP022588.1': 'Mycolicibacterium sediminis',
#  'AP022589.1': 'Mycolicibacter minnesotensis',
#  'AP022582.1': 'Mycobacterium seoulense',
#  'AP022618.1': 'Mycolicibacterium insubricum',
#  'AP022583.1': 'Mycobacterium noviomagense',
#  'AP022619.1': 'Mycobacterium paraseoulense',
#  'AP022586.1': 'Mycolicibacterium litorale',
#  'AP022587.1': 'Mycobacterium stomatepiae',
#  'AP022615.1': 'Mycobacterium heidelbergense',
#  'AP022616.1': 'Mycolicibacterium phocaicum',
#  'AP022579.1': 'Mycolicibacterium boenickei',
#  'AP022580.1': 'Mycolicibacterium boenickei',
#  'AP022581.1': 'Mycobacterium lacus',
#  'AP022617.1': 'Mycolicibacterium monacense',
#  'AP022613.1': 'Mycobacterium conspicuum',
#  'AP022576.1': 'Mycobacterium florentinum',
#  'AP022614.1': 'Mycobacterium parmense',
#  'AP022610.1': 'Mycolicibacterium madagascariense',
#  'AP022611.1': 'Mycolicibacterium madagascariense',
#  'AP022612.1': 'Mycolicibacterium confluentis',
#  'AP022575.1': 'Mycobacterium shinjukuense',
#  'AP022606.1': 'Mycobacterium branderi',
#  'AP022607.1': 'Mycobacterium branderi',
#  'AP022608.1': 'Mycolicibacterium gadium',
#  'AP022573.1': 'Mycobacterium saskatchewanense',
#  'AP022574.1': 'Mycolicibacterium psychrotolerans',
#  'AP022609.1': 'Mycolicibacter hiberniae',
#  'AP022569.1': 'Mycobacterium cookii',
#  'AP022605.1': 'Mycobacterium doricum',
#  'AP022570.1': 'Mycolicibacterium poriferae',
#  'AP022571.1': 'Mycolicibacterium poriferae',
#  'AP022572.1': 'Mycobacterium shottsii',
#  'AP022562.1': 'Mycobacterium novum',
#  'AP022563.1': 'Mycolicibacterium duvalii',
#  'AP022603.1': 'Mycolicibacterium fallax',
#  'AP022565.1': 'Mycolicibacterium alvei',
#  'AP022566.1': 'Mycolicibacterium alvei',
#  'AP022567.1': 'Mycolicibacterium mageritense',
#  'AP022568.1': 'Mycobacterium simiae',
#  'CP017146.1': 'Marisediminicola antarctica',
#  'AP022598.1': 'Mycolicibacterium parafortuitum',
#  'AP022599.1': 'Mycolicibacterium pulveris',
#  'AP022600.1': 'Mycolicibacterium tokaiense',
#  'AP022560.1': 'Mycolicibacterium moriokaense',
#  'AP022561.1': 'Mycolicibacterium aichiense',
#  'CP047156.1': 'Epidermidibacterium keratini',
#  'CP047186.1': 'Rathayibacter tanaceti',
#  'CP047180.1': 'Rathayibacter festucae',
#  'CP047181.1': 'Rathayibacter festucae',
#  'CP047182.1': 'Rathayibacter festucae',
#  'CP047898.1': 'Pseudarthrobacter psychrotolerans',
#  'CP047899.1': 'Pseudarthrobacter psychrotolerans',
#  'CP047900.1': 'Pseudarthrobacter psychrotolerans',
#  'CP045805.1': 'Gordonia amarae',
#  'CP045806.1': 'Gordonia pseudamarae',
#  'CP045807.1': 'Gordonia pseudamarae',
#  'CP046452.1': 'Corynebacterium kalinowskii',
#  'CP046453.1': 'Corynebacterium comes',
#  'CP046454.1': 'Corynebacterium comes',
#  'CP046455.1': 'Corynebacterium occultum',
#  'CP046456.1': 'Corynebacterium occultum',
#  'CP033724.1': 'Clavibacter michiganensis subsp. michiganensis',
#  'CP033725.1': 'Clavibacter michiganensis subsp. michiganensis',
#  'CP033726.1': 'Clavibacter michiganensis subsp. michiganensis',
#  'CP034279.1': 'Streptomyces ficellus',
#  'CP047020.1': 'Streptomyces broussonetiae',
#  'CP045725.1': 'Raineyella fluvialis',
#  'CP045737.1': 'Aeromicrobium yanjiei',
#  'CP045736.1': 'Aeromicrobium yanjiei',
#  'CP045929.1': 'Allosaccharopolyspora coralli',
#  'CP045309.1': 'Micromonospora terminaliae',
#  'CP045310.1': 'Micromonospora terminaliae',
#  'CP052757.1': 'Cellulosimicrobium protaetiae',
#  'CP052758.1': 'Cellulosimicrobium protaetiae',
#  'CP034550.1': 'Saccharothrix syringae',
#  'CP045643.1': 'Streptomyces fagopyri',
#  'CP045032.1': 'Corynebacterium urogenitale',
#  'CP045096.1': 'Streptomyces phaeolivaceus',
#  'CP045095.1': 'Streptomyces phaeolivaceus',
#  'CP023693.1': 'Streptomyces cinereoruber',
#  'CP045529.1': 'Luteimicrobium xylanilyticum',
#  'CP045572.1': 'Nonomuraea phyllanthi',
#  'CP023692.1': 'Streptomyces vinaceus',
#  'CP023694.1': 'Streptomyces coeruleorubidus',
#  'CP044231.1': 'Microbacterium caowuchunii',
#  'CP044232.1': 'Microbacterium lushaniae',
#  'CP044427.1': 'Ornithinimicrobium pratense',
#  'CP023703.1': 'Streptomyces galilaeus',
#  'CP023689.1': 'Streptomyces chartreusis',
#  'CP023690.1': 'Streptomyces spectabilis',
#  'CP023691.1': 'Streptomyces platensis',
#  'CP023699.1': 'Streptomyces kanamyceticus',
#  'CP023700.1': 'Streptomyces viridosporus T7A',
#  'CP023701.1': 'Streptomyces subrutilus',
#  'CP023702.1': 'Streptomyces nitrosporeus',
#  'CP043474.1': 'Mycobacterium grossiae',
#  'CP043475.1': 'Mycobacterium grossiae',
#  'CP043504.1': 'Protaetiibacter larvae',
#  'CP023695.1': 'Streptomyces alboniger',
#  'CP023696.1': 'Streptomyces fradiae ATCC 10745 = DSM 40063',
#  'CP023697.1': 'Streptomyces prasinus',
#  'CP042305.1': 'Humibacter ginsenosidimutans',
#  'CP041692.1': 'Microlunatus elymi',
#  'CP041765.1': 'Tomitella fengzijianii',
#  'CP041766.1': 'Tomitella fengzijianii',
#  'CP038157.1': 'Corynebacterium sanguinis',
#  'CP042266.1': 'Streptomyces qinzhouensis',
#  'CP040635.1': 'Acidipropionibacterium jensenii',
#  'CP034412.1': 'Glutamicibacter creatinolyticus',
#  'CP040899.1': 'Georgenia wutianyii',
#  'CP040915.1': 'Georgenia yuyongxinii',
#  'CP022310.1': 'Streptomyces calvus',
#  'CP041616.1': 'Ornithinimicrobium ciconiae',
#  'CP041695.1': 'Nocardia otitidiscaviarum',
#  'CP039247.1': 'Corynebacterium endometrii',
#  'CP039291.1': 'Cellulomonas shaoxiangyii',
#  'CP021978.1': 'Streptomyces hawaiiensis',
#  'CP024633.1': 'Mycobacteroides salmoniphilum',
#  'CP062008.1': 'Mycolicibacterium mucogenicum DSM 44124',
#  'CP038266.1': 'Microbacterium wangchenii',
#  'CP038267.1': 'Nocardioides euryhalodurans',
#  'CP038436.1': 'Nocardioides seonyuensis',
#  'CP035493.1': 'Xylanimonas protaetiae',
#  'CP035491.1': 'Agromyces protaetiae',
#  'CP035806.1': 'Leucobacter triazinivorans',
#  'CP036455.1': 'Streptomonospora litoralis',
#  'CP036456.1': 'Streptomonospora litoralis',
#  'CP035504.1': 'Kocuria indica',
#  'CP035505.1': 'Kocuria indica',
#  'CP032229.1': 'Streptomyces seoulensis',
#  'CP032230.1': 'Streptomyces seoulensis',
#  'CP038256.1': 'Microbacterium sediminis',
#  'CP038257.1': 'Microbacterium sediminis',
#  'CP027114.1': 'Gordonia alkanivorans',
#  'CP027115.1': 'Gordonia alkanivorans',
#  'CP034181.1': 'Mycobacteroides abscessus',
#  'CP034180.1': 'Mycobacteroides abscessus',
#  'CP035037.1': 'Leucobacter muris',
#  'CP035299.1': 'Corynebacterium pelargi',
#  'CP035494.1': 'Microbacterium protaetiae',
#  'CP035495.1': 'Xylanimonas allomyrinae',
#  'CP035496.1': 'Xylanimonas allomyrinae',
#  'CP034593.1': 'Flaviflexus ciconiae',
#  'CP031423.1': 'Microbacterium lemovicicum',
#  'CP034687.1': 'Streptomyces griseoviridis',
#  'CP026734.1': 'Brevibacterium linens',
#  'CP026735.1': 'Brevibacterium linens',
#  'CP028129.1': 'Rathayibacter rathayi',
#  'CP028130.1': 'Rathayibacter iranicus',
#  'AP018920.1': 'Pseudonocardia autotrophica',
#  'AP018921.1': 'Pseudonocardia autotrophica',
#  'CP034438.1': 'Flaviflexus salsibiostraticola',
#  'CP034463.1': 'Streptomyces aquilus',
#  'CP034539.1': 'Streptomyces cyaneochromogenes',
#  'CP025333.1': 'Brevibacterium aurantiacum',
#  'AP019307.1': 'Nocardioides baekrokdamisoli',
#  'CP044548.2': 'Janibacter melonis',
#  'CP046475.1': 'Janibacter melonis',
#  'CP033719.1': 'Propionibacterium acidifaciens',
#  'CP033896.1': 'Corynebacterium choanae',
#  'CP033897.1': 'Corynebacterium gerontici',
#  'CP033898.1': 'Corynebacterium pseudopelargi',
#  'CP033899.1': 'Corynebacterium pseudopelargi',
#  'CP033972.1': 'Gordonia insulae',
#  'CP034170.1': 'Nakamurella antarctica',
#  'CP020700.1': 'Streptomyces tsukubensis',
#  'CP020701.1': 'Streptomyces tsukubensis',
#  'CP020702.1': 'Streptomyces tsukubensis',
#  'CP025546.1': 'Mycobacterium paragordonae',
#  'CP025547.1': 'Mycobacterium paragordonae',
#  'CP025548.1': 'Mycobacterium paragordonae',
#  'CP025549.1': 'Mycobacterium paragordonae',
#  'CP025550.1': 'Mycobacterium paragordonae',
#  'CP032624.1': 'Gryllotalpicola protaetiae',
#  'CP032625.1': 'Gryllotalpicola protaetiae',
#  'CP032630.1': 'Protaetiibacter intestinalis',
#  'CP032698.1': 'Streptomyces hundungensis',
#  'CP032788.1': 'Corynebacterium xerosis',
#  'CP023407.1': 'Streptomyces fungicidicus',
#  'CP023408.1': 'Streptomyces fungicidicus',
#  'CP033073.1': 'Streptomyces dangxiongensis',
#  'CP033072.1': 'Streptomyces dangxiongensis',
#  'CP031425.1': 'Microbacterium foliorum',
#  'CP063196.1': 'Thermobifida halotolerans',
#  'CP063197.1': 'Thermobifida halotolerans',
#  'AP018410.1': 'Mycobacterium pseudoshottsii JCM 15466',
#  'CP032427.1': 'Streptomyces griseorubiginosus',
#  'CP024087.1': 'Micromonospora tulbaghiae',
#  'CP022744.1': 'Streptomyces lincolnensis',
#  'CP031194.1': 'Streptomyces paludis',
#  'CP031229.1': 'Ornithinimicrobium avium',
#  'CP031356.1': 'Brachybacterium saurashtrense',
#  'CP015163.1': 'Amycolatopsis albispora',
#  'CP030862.1': 'Streptomyces globosus',
#  'CP030863.1': 'Streptomyces globosus',
#  'CP030864.1': 'Streptomyces globosus',
#  'CP025198.1': 'Acidipropionibacterium virtanenii',
#  'CP027306.1': 'Streptomyces atratus',
#  'CP021354.1': 'Rhodococcus oxybenzonivorans',
#  'CP021357.1': 'Rhodococcus oxybenzonivorans',
#  'CP021356.1': 'Rhodococcus oxybenzonivorans',
#  'CP021355.1': 'Rhodococcus oxybenzonivorans',
#  'CP023994.1': 'Aurantimicrobium photophilum',
#  'CP029543.1': 'Mycobacterium leprae',
#  'CP031264.1': 'Peterkaempfera bronchialis',
#  'CP030073.1': 'Streptomyces cadmiisoli',
#  'CP030074.1': 'Streptomyces cadmiisoli',
#  'CP026948.1': 'Corynebacterium liangguodongii',
#  'CP028913.1': 'Agromyces badenianii',
#  'CP029043.1': 'Streptomyces nigra',
#  'CP015449.1': 'Dietzia lutea',
#  'CP015450.1': 'Dietzia lutea',
#  'CP015451.1': 'Dietzia lutea',
#  'CP015452.1': 'Dietzia lutea',
#  'CP015453.1': 'Dietzia psychralcaliphila',
#  'CP015454.1': 'Dietzia psychralcaliphila',
#  'CP029188.1': 'Streptomyces tirandamycinicus',
#  'CP029254.1': 'Streptomyces spongiicola',
#  'CP028341.1': 'Bifidobacterium adolescentis',
#  'CP026304.1': 'Streptomyces lunaelactis',
#  'CP026305.1': 'Streptomyces lunaelactis',
#  'CP026306.1': 'Streptomyces lunaelactis',
#  'CP026947.1': 'Corynebacterium yudongzhengii',
#  'CP026949.1': 'Mycetocola zhujimingii',
#  'CP026950.1': 'Mycetocola zhujimingii',
#  'CP026952.1': 'Aeromicrobium chenweiae',
#  'CP026923.1': 'Pontimonas salivibrio',
#  'CP027433.1': 'Gordonia iterans',
#  'CP028426.1': 'Gulosibacter molinativorax',
#  'CP028427.1': 'Gulosibacter molinativorax',
#  'CP027793.1': 'Prescottella equi',
#  'CP027794.1': 'Prescottella equi',
#  'CP027795.1': 'Prescottella equi',
#  'CP026746.1': 'Nocardia cyriacigeorgica',
#  'CP026745.1': 'Nocardia cyriacigeorgica',
#  'CP023564.1': 'Brachybacterium ginsengisoli',
#  'CP023563.1': 'Brachybacterium vulturis',
#  'CP023778.1': 'Nocardia terpenica',
#  'CP023779.1': 'Nocardia terpenica',
#  'CP018044.1': 'Bifidobacterium choerinum',
#  'CP018045.1': 'Bifidobacterium choerinum',
#  'CP024957.1': 'Streptomyces cavourensis',
#  'CP018863.1': 'Arthrobacter crystallopoietes',
#  'CP018864.1': 'Arthrobacter crystallopoietes',
#  'CP018865.1': 'Arthrobacter crystallopoietes',
#  'CP026652.1': 'Streptomyces dengpaensis',
#  'CP026653.1': 'Streptomyces dengpaensis',
#  'CP026654.1': 'Streptomyces dengpaensis',
#  'CP016780.1': 'Candidatus Planktophila lacus',
#  'CP016782.1': 'Candidatus Planktophila limnetica',
#  'CP023445.1': 'Actinosynnema pretiosum',
#  'AP017369.1': 'Corynebacterium suranareeae',
#  'AP017457.1': 'Aurantimicrobium minutum',
#  'AP017900.1': 'Nocardia seriolae',
#  'AP018164.1': 'Mycobacterium shigaense',
#  'AP018165.1': '[Mycobacterium] stephanolepidis',
#  'CP022544.1': 'Bifidobacterium pseudolongum',
#  'CP023147.1': 'Mycobacterium marseillense',
#  'CP023148.1': 'Mycobacterium marseillense',
#  'CP019688.1': 'Corynebacterium glaucum',
#  'CP016768.2': 'Candidatus Nanopelagicus limnes',
#  'CP016770.1': 'Candidatus Planktophila dulcis',
#  'CP016771.1': 'Candidatus Nanopelagicus hibericus',
#  'CP016773.1': 'Candidatus Planktophila sulfonica',
#  'CP016775.1': 'Candidatus Planktophila versatilis',
#  'CP016776.1': 'Candidatus Planktophila vernalis',
#  'CP016779.1': 'Candidatus Nanopelagicus abundans',
#  'CP021417.2': 'Corynebacterium silvaticum',
#  'CP022088.2': 'Nocardia brasiliensis',
#  'CP022316.1': 'Brachybacterium avium',
#  'CP022317.1': 'Brachybacterium avium',
#  'CP022318.1': 'Brachybacterium avium',
#  'CP022521.1': 'Actinoalloteichus hoggarensis',
#  'CP016353.1': 'Prauserella marina',
#  'CP016354.1': 'Prauserella marina',
#  'CP022753.1': 'Nocardiopsis gilva YIM 90087',
#  'CP022752.1': 'Actinopolyspora erythraea',
#  'CP020569.1': 'Streptomyces gilvosporeus',
#  'CP020567.1': 'Kitasatospora aureofaciens',
#  'CP020568.1': 'Kitasatospora aureofaciens',
#  'CP020715.1': 'Cnuibacter physcomitrellae',
#  'CP020716.1': 'Cnuibacter physcomitrellae',
#  'CP020717.1': 'Cnuibacter physcomitrellae',
#  'CP021121.1': 'Streptomyces marincola',
#  'CP020809.1': 'Mycobacterium dioxanotrophicus',
#  'CP020810.1': 'Mycobacterium dioxanotrophicus',
#  'CP020811.1': 'Mycobacterium dioxanotrophicus',
#  'CP020812.1': 'Mycobacterium dioxanotrophicus',
#  'CP020813.1': 'Mycobacterium dioxanotrophicus',
#  'CP009249.1': 'Corynebacterium phocae',
#  'CP009250.1': 'Corynebacterium phocae',
#  'CP016076.1': 'Actinoalloteichus fjordicus',
#  'CP018762.1': 'Microbacterium aurum',
#  'CP031421.1': 'Microbacterium oleivorans',
#  'CP019605.1': 'Tessaracoccus flavus',
#  'CP019606.1': 'Tessaracoccus aquimaris',
#  'CP019607.1': 'Tessaracoccus flavescens',
#  'CP019608.1': 'Tessaracoccus flavescens',
#  'CP020468.1': 'Actinomyces gaoshouyii',
#  'CP020570.1': 'Streptomyces violaceoruber',
#  'CP018082.1': 'Nocardia mangyaensis',
#  'CP018135.1': 'Neomicrococcus aestuarii',
#  'CP018134.1': 'Microbacterium paludicola',
#  'CP013290.1': 'Janibacter indicus',
#  'CP009251.1': 'Corynebacterium stationis',
#  'CP009252.1': 'Corynebacterium stationis',
#  'CP009245.1': 'Corynebacterium aquilae DSM 44791',
#  'CP009246.1': 'Corynebacterium flavescens',
#  'CP009247.1': 'Corynebacterium frankenforstense DSM 45800',
#  'CP009248.1': 'Corynebacterium sphenisci DSM 44792',
#  'CP017040.1': 'Cutibacterium modestum',
#  'CP017041.1': 'Cutibacterium modestum',
#  'CP017248.1': 'Streptomyces fodineus',
#  'CP014859.1': 'Actinoalloteichus hymeniacidonis',
#  'CP015208.1': 'Candidatus Rhodoluna planktonica',
#  'CP017812.1': 'Boudabousia tangfeifanii',
#  'CP016826.1': 'Corynebacterium pseudotuberculosis',
#  'CP018074.1': 'Streptomyces venezuelae',
#  'CP018075.1': 'Streptomyces venezuelae',
#  'CP015961.1': 'Dietzia timorensis',
#  'CP015866.1': 'Streptomyces parvulus',
#  'CP015867.1': 'Streptomyces parvulus',
#  'CP013979.1': 'Agromyces aureus',
#  'CP012117.1': 'Dermabacter vaginalis',
#  'CP014989.1': 'Serinicoccus hydrothermalis',
#  'CP016793.1': 'Lentzea guizhouensis',
#  'CP015235.1': 'Rhodococcus fascians D188',
#  'CP015237.1': 'Rhodococcus fascians D188',
#  'CP015236.1': 'Rhodococcus fascians D188',
#  'CP007220.1': 'Mycobacteroides chelonae CCUG 47445',
#  'CP014209.1': 'Isoptericola dokdonensis DS-3',
#  'CP015515.1': 'Rathayibacter tritici',
#  'CP015622.1': 'Corynebacterium crudilactis',
#  'CP015623.1': 'Corynebacterium crudilactis',
#  'CP015624.1': 'Corynebacterium crudilactis',
#  'CP015079.1': 'Nocardioides dokdonensis FR1436',
#  'CP011491.1': 'Mycolicibacterium vaccae 95051',
#  'CP011502.1': 'Aeromicrobium erythreum',
#  'CP016279.1': 'Streptomyces griseochromogenes',
#  'CP014228.1': 'Actinomyces radicidentis',
#  'CP014635.1': 'Corynebacterium simulans',
#  'CP011530.1': 'Mycobacteroides immunogenum',
#  'CP015098.1': 'Streptomyces qaidamensis',
#  'CP011853.1': 'Gordonia phthalatica',
#  'CP011269.1': 'Mycolicibacterium fortuitum',
#  'CP013126.1': 'Acidipropionibacterium acidipropionici',
#  'CP010271.1': 'Mycobacteroides saopaulense',
#  'CP013254.1': 'Kocuria flava',
#  'CP013255.1': 'Kocuria flava',
#  'CP013256.1': 'Kocuria flava',
#  'CP013257.1': 'Kocuria flava',
#  'CP013258.1': 'Kocuria flava',
#  'CP006841.1': 'Corynebacterium lactis RW2-5',
#  'CP012507.1': 'Kocuria palustris',
#  'CP009220.1': 'Corynebacterium deserti GIMN1.010',
#  'CP009221.1': 'Corynebacterium deserti GIMN1.010',
#  'CP009222.1': 'Corynebacterium deserti GIMN1.010',
#  'CP011340.1': 'Streptomyces pristinaespiralis',
#  'CP010413.1': 'Bifidobacterium breve',
#  'CP010414.1': 'Bifidobacterium breve',
#  'CP009312.1': 'Lawsonella clevelandensis',
#  'CP012750.1': 'Glutamicibacter halophytocola',
#  'CP012751.1': 'Glutamicibacter halophytocola',
#  'CP012752.1': 'Kibdelosporangium phytohabitans',
#  'AP012331.1': 'Bifidobacterium scardovii JCM 12489 = DSM 13734',
#  'AP012333.1': 'Parascardovia denticolens DSM 10105 = JCM 12538',
#  'AP012334.1': 'Scardovia inopinata JCM 12537',
#  'CP011112.1': 'Luteipulveratus mongoliensis',
#  'CP011786.1': 'Bifidobacterium actinocoloniiforme DSM 22766',
#  'CP012382.1': 'Streptomyces ambofaciens ATCC 23877',
#  'CP012383.1': 'Streptomyces ambofaciens ATCC 23877',
#  'LN831790.1': 'Streptomyces leeuwenhoekii',
#  'LN831788.1': 'Streptomyces leeuwenhoekii',
#  'LN831789.1': 'Streptomyces leeuwenhoekii',
#  'CP011542.1': 'Corynebacterium mustelae',
#  'CP011543.1': 'Corynebacterium mustelae',
#  'CP011544.1': 'Corynebacterium mustelae',
#  'CP011541.1': 'Corynebacterium epidermidicanis',
#  'CP011545.1': 'Corynebacterium testudinoris',
#  'CP011546.1': 'Corynebacterium uterequi',
#  'AP012322.1': 'Bifidobacterium angulatum DSM 20098 = JCM 7096',
#  'AP012325.1': 'Bifidobacterium catenulatum DSM 16992 = JCM 1194 = LMG 11043',
#  'CP016174.1': 'Amycolatopsis orientalis',
#  'CP011005.1': 'Psychromicrobium lacuslunae',
#  'CP011006.1': 'Psychromicrobium lacuslunae',
#  'CP083405.1': 'Mycobacterium lepromatosis',
#  'CP011311.1': 'Corynebacterium camporealensis',
#  'CP011312.1': 'Corynebacterium kutscheri',
#  'CP009922.3': 'Streptomyces xiamenensis',
#  'CP006764.1': 'Corynebacterium doosanense CAU 212 = DSM 45436',
#  'CP006765.1': 'Corynebacterium doosanense CAU 212 = DSM 45436',
#  'CP009896.1': 'Pimelobacter simplex',
#  'CP021080.1': 'Streptomyces pluripotens',
#  'CP010407.1': 'Streptomyces vietnamensis',
#  'CP010408.1': 'Streptomyces vietnamensis',
#  'CP010827.1': 'Corynebacterium singulare',
#  'CP007790.1': 'Corynebacterium marinum DSM 44953',
#  'CP007792.1': 'Corynebacterium marinum DSM 44953',
#  'CP007791.1': 'Corynebacterium marinum DSM 44953',
#  'HG917972.2': 'Mycobacterium marinum E11',
#  'HG917973.1': 'Mycobacterium marinum E11',
#  'CP008802.1': 'Actinotignum schaalii',
#  'CP008889.1': 'Dermacoccus nishinomiyaensis',
#  'CP008890.1': 'Dermacoccus nishinomiyaensis',
#  'CP008953.1': 'Amycolatopsis japonica',
#  'CP008954.1': 'Amycolatopsis japonica',
#  'CP008944.1': 'Corynebacterium atypicum',
#  'CP008945.1': 'Corynebacterium atypicum',
#  'CP007287.1': 'Bifidobacterium coryneforme',
#  'CP009215.1': 'Corynebacterium ureicelerivorans',
#  'CP009216.1': 'Corynebacterium ureicelerivorans',
#  'CP013745.1': 'Arthrobacter alpinus',
#  'CP013746.1': 'Arthrobacter alpinus',
#  'CP004353.1': 'Corynebacterium vitaeruminis DSM 20294',
#  'CP006365.1': 'Corynebacterium argentoratense DSM 44202',
#  'CP007519.1': 'Trueperella pyogenes',
#  'CP006842.1': 'Corynebacterium glyciniphilum AJ 3170',
#  'CP006843.1': 'Corynebacterium glyciniphilum AJ 3170',
#  'CP007255.1': 'Rhodococcus erythropolis R138',
#  'CP007256.1': 'Rhodococcus erythropolis R138',
#  'CP007257.1': 'Rhodococcus erythropolis R138',
#  'CP007490.1': 'Rhodoluna lacicola',
#  'CP006018.1': 'Bifidobacterium indicum LMG 11587 = DSM 20214',
#  'CP006734.1': 'Leifsonia xyli subsp. cynodontis DSM 46306',
#  'CP006272.1': 'Actinoplanes friuliensis DSM 7358',
#  'CP006996.1': 'Rhodococcus pyridinivorans SB3094',
#  'CP006997.1': 'Rhodococcus pyridinivorans SB3094',
#  'CP006998.1': 'Rhodococcus pyridinivorans SB3094',
#  'CP007155.1': 'Kutzneria albida DSM 43870',
#  'CP004350.1': 'Corynebacterium casei LMG S-19264',
#  'CP004351.1': 'Corynebacterium casei LMG S-19264',
#  'CP004352.1': 'Corynebacterium casei LMG S-19264',
#  'CP003410.1': 'Amycolatopsis keratiniphila',
#  'CP003411.1': 'Amycolatopsis keratiniphila',
#  'CP004048.1': 'Corynebacterium glutamicum SCgG2',
#  'CP003696.1': 'Corynebacterium terpenotabidum Y-11',
#  'CP003924.1': 'Corynebacterium maris DSM 45190',
#  'CP003925.1': 'Corynebacterium maris DSM 45190',
#  'CP006259.1': 'Streptomyces collinus Tu 365',
#  'CP006260.1': 'Streptomyces collinus Tu 365',
#  'CP006261.1': 'Streptomyces collinus Tu 365',
#  'CP003777.1': 'Amycolatopsis mediterranei RB',
#  'CP048261.1': 'Streptomyces rimosus subsp. rimosus ATCC 10970',
#  'CP048262.1': 'Streptomyces rimosus subsp. rimosus ATCC 10970',
#  'CP011883.2': 'Mycobacterium haemophilum DSM 44634',
#  'CP003697.1': 'Corynebacterium halotolerans YIM 70093 = DSM 44683',
#  'CP003698.1': 'Corynebacterium halotolerans YIM 70093 = DSM 44683',
#  'CP004354.1': 'Corynebacterium callunae DSM 20147',
#  'CP004355.1': 'Corynebacterium callunae DSM 20147',
#  'CP004356.1': 'Corynebacterium callunae DSM 20147',
#  'CP004370.1': 'Streptomyces albidoflavus',
#  'CP005287.1': 'Cutibacterium avidum 44067',
#  'CP003293.1': 'Cutibacterium acnes HL096PA1',
#  'CP003294.1': 'Cutibacterium acnes HL096PA1',
#  'AP012204.1': 'Microlunatus phosphovorus NM-1',
#  'CP072931.1': 'Streptomyces auratus AGR0001',
#  'AP012319.1': 'Actinoplanes missouriensis 431',
#  'CP003325.1': 'Bifidobacterium asteroides PRL2011',
#  'HE804045.1': 'Saccharothrix espanaensis DSM 44229',
#  'CP003039.2': 'Bifidobacterium animalis subsp. lactis BLC1',
#  'FQ859185.1': 'Streptantibioticus cattleyicolor NRRL 8057 = DSM 46488',
#  'FQ859184.1': 'Streptantibioticus cattleyicolor NRRL 8057 = DSM 46488',
#  'CP003119.1': 'Gordonia polyisoprenivorans VH2',
#  'CP003120.1': 'Gordonia polyisoprenivorans VH2',
#  'HE572590.1': 'Mycobacterium canettii CIPT 140010059',
#  'AP010968.1': 'Kitasatospora setae KM-6054',
#  'CP002638.1': 'Micromonospora maris AB-18-032',
#  'CP002639.1': 'Micromonospora maris AB-18-032',
#  'CP002666.1': 'Cellulomonas fimi ATCC 484',
#  'CP002329.1': 'Mycolicibacter sinensis',
#  'CP002786.1': 'Hoyosella subflava DQS3-9A1',
#  'CP002787.1': 'Hoyosella subflava DQS3-9A1',
#  'CP002788.1': 'Hoyosella subflava DQS3-9A1',
#  'CP002810.1': 'Isoptericola variabilis 225',
#  'CP002790.1': 'Corynebacterium ulcerans 809',
#  'CP002665.1': 'Cellulomonas gilvus ATCC 13127',
#  'CP002857.1': 'Corynebacterium resistens DSM 45100',
#  'CP002385.1': 'Mycolicibacterium gilvum Spyr1',
#  'CP002386.1': 'Mycolicibacterium gilvum Spyr1',
#  'CP002387.1': 'Mycolicibacterium gilvum Spyr1',
#  'CP002343.1': 'Intrasporangium calvum DSM 43043',
#  'AL123456.3': 'Mycobacterium tuberculosis H37Rv',
#  'BX072543.1': 'Tropheryma whipplei TW08/27',
#  'CP001992.1': 'Mobiluncus curtisii ATCC 43063',
#  'AP010888.1': 'Bifidobacterium longum subsp. longum JCM 1217',
#  'CP001958.1': 'Segniliparus rotundus DSM 44985',
#  'CP001964.1': 'Cellulomonas flavigena DSM 20109',
#  'CP002162.1': 'Micromonospora aurantiaca ATCC 27029',
#  'CP006835.1': 'Mycobacterium kansasii ATCC 12478',
#  'CP006836.1': 'Mycobacterium kansasii ATCC 12478',
#  'CP002280.1': 'Rothia dentocariosa ATCC 17931',
#  'CP002299.1': 'Frankia inefficax',
#  'AM420293.1': 'Saccharopolyspora erythraea NRRL 2338',
#  'FN554889.1': 'Streptomyces scabiei 87.22',
#  'CP001966.1': 'Tsukamurella paurometabola DSM 20162',
#  'CP001967.1': 'Tsukamurella paurometabola DSM 20162',
#  'CP001802.1': 'Gordonia bronchialis DSM 43247',
#  'CP001803.1': 'Gordonia bronchialis DSM 43247',
#  'CP001814.1': 'Streptosporangium roseum DSM 43021',
#  'CP001815.1': 'Streptosporangium roseum DSM 43021',
#  'CP001819.1': 'Sanguibacter keddieii DSM 10542',
#  'CP001821.1': 'Xylanimonas cellulosilytica DSM 15894',
#  'CP001822.1': 'Xylanimonas cellulosilytica DSM 15894',
#  'CP001867.1': 'Geodermatophilus obscurus DSM 43160',
#  'CT573213.2': 'Frankia alni ACN14a',
#  'CP001736.1': 'Kribbella flavida DSM 17836',
#  'CP001737.1': 'Nakamurella multipartita DSM 44233',
#  'CP001738.1': 'Thermomonospora curvata DSM 43183',
#  'CP001778.1': 'Stackebrandtia nassauensis DSM 44728',
#  'CP001601.1': 'Corynebacterium aurimucosum ATCC 700975',
#  'FM164414.1': 'Corynebacterium aurimucosum ATCC 700975',
#  'CP001618.1': 'Beutenbergia cavernae DSM 12333',
#  'CP001620.1': 'Corynebacterium kroppenstedtii DSM 44385',
#  'CP001630.1': 'Actinosynnema mirum DSM 43827',
#  'CP001643.1': 'Brachybacterium faecium DSM 4810',
#  'CP001683.1': 'Saccharomonospora viridis DSM 43017',
#  'CP001700.1': 'Catenulispora acidiphila DSM 44928',
#  'CP000481.1': 'Acidothermus cellulolyticus 11B',
#  'CP000511.1': 'Mycolicibacterium vanbaalenii PYR-1',
#  'CP000667.1': 'Salinispora tropica CNB-440',
#  'CP000750.2': 'Kineococcus radiotolerans SRS30216 = ATCC BAA-149',
#  'CP000751.1': 'Kineococcus radiotolerans SRS30216 = ATCC BAA-149',
#  'CP000752.1': 'Kineococcus radiotolerans SRS30216 = ATCC BAA-149',
#  'CP000910.1': 'Renibacterium salmoninarum ATCC 33209',
#  'CP001341.1': 'Pseudarthrobacter chlorophenolicus A6',
#  'CP001342.1': 'Pseudarthrobacter chlorophenolicus A6',
#  'CP001343.1': 'Pseudarthrobacter chlorophenolicus A6',
#  'CR931997.1': 'Corynebacterium jeikeium K411',
#  'AF401314.1': 'Corynebacterium jeikeium K411',
#  'BA000030.4': 'Streptomyces avermitilis MA-4680 = NBRC 14893',
#  'AP005645.1': 'Streptomyces avermitilis MA-4680 = NBRC 14893',
#  'AP006618.1': 'Nocardia farcinica IFM 10152',
#  'AP006619.1': 'Nocardia farcinica IFM 10152',
#  'AP006620.1': 'Nocardia farcinica IFM 10152',
#  'AP009493.1': 'Streptomyces griseus subsp. griseus NBRC 13350',
#  'BA000035.2': 'Corynebacterium efficiens YS-314',
#  'AP005225.1': 'Corynebacterium efficiens YS-314',
#  'AP005226.1': 'Corynebacterium efficiens YS-314',
#  'CP000249.1': 'Frankia casuarinae',
#  'LR214441.1': 'Tessaracoccus lapidicaptus',
#  'LR738855.1': 'Corynebacterium rouxii',
#  'LR134355.1': 'Mycolicibacterium chitae',
#  'LR134363.1': 'Actinomyces slackii'}
