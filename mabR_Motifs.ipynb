# %% [markdown]
# #### Import packages, set directories and parameters

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from Bio import Entrez, SeqIO, AlignIO, pairwise2, Align, Seq, motifs
from Bio.Seq import Seq
from Bio.SeqFeature import SeqFeature, FeatureLocation
import math
from tqdm import tqdm
from Comparative_Analysis import Utilities as util
from joblib import Parallel, delayed
from Comparative_Analysis import Blast_Functions as blastfn
import time
import os
import copy
from scipy.stats import chi2, binom
from Comparative_Analysis import Alignment as alignfn
from Bio.Align.Applications import MuscleCommandline
import subprocess
pd.options.mode.chained_assignment = None  # default='warn'

# %%
project_dir = 'F:/Project_Data/mabR_Project'
mycobacteria_seq_dir = 'F:/Datasets/NCBI_Refseq_Mycobacteriaceae_Complete_Annot_20230511/data'
tb_species = 'AL123456.3' 
tb_annotation_dirname = 'GCA_000195955.2'
min_region_length = 7 
full_build = False
num_cores = 16
core_numbers = list(range(1, num_cores+1))
muscle_exe = 'C:/Users/nicho/Muscle/muscle3.8.31_i86win32.exe'
full_run = False

# %%
mycobacteria_dirs = []
for dir in util.list_dirs(mycobacteria_seq_dir):
    if os.path.exists(mycobacteria_seq_dir + '/' + dir + '/genomic.gbff'):
        mycobacteria_dirs.append(dir)

# %%
tb_mycobacteria_rbh = pd.read_csv(project_dir + '/tb_mycobacteria_reciprocal_best_hits.csv')

# %% [markdown]
# #### Produce reference FASTA files (a) TB and (b) all mycobacteria for searching against motifs

# %%
genome_record = next(SeqIO.parse(mycobacteria_seq_dir + '/' + tb_annotation_dirname + '/genomic.gbff', "genbank"))
full_sequence = str(genome_record.seq)
accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
util.produce_fasta_file([[accession_ver, full_sequence]], project_dir + '/mtb_seq')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 11.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.98it/s]

# %%
if full_run == True:
    temp = []
    for dir in util.list_dirs(mycobacteria_seq_dir): 
        if os.path.exists(mycobacteria_seq_dir + '/' + dir + '/genomic.gbff'):
            for genome_record in (SeqIO.parse(mycobacteria_seq_dir + '/' + dir + '/genomic.gbff', "genbank")):
                accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
                full_sequence = str(genome_record.seq)
                temp.append([accession_ver, full_sequence])
    util.produce_fasta_file(temp, project_dir + '/all_seq')

# %% [markdown]
# #### Functions to locate arbitrary region in organism

# %%
def annotated_regions_dataset(num_subsets, subset_num, dir_list, seqdir): 
    output = []
    sequence_dirs = util.chunk_list(dir_list, num_subsets, subset_num)
    for dirname in sequence_dirs:
        annotated_regions = []
        intergenic_regions = []
        for record in (SeqIO.parse(seqdir + '/'+dirname+'/genomic.gbff', "genbank")):
            accession_ver = record.annotations['accessions'][0] + '.' + str(record.annotations['sequence_version'])
            for feature in record.features:
                a = feature.qualifiers
                if feature.type not in ['source','gene'] and (int(feature.location.start) < int(feature.location.end)) and (int(feature.location.end) - int(feature.location.start)) < 1000000:
                    if not(a.get("product") == None):
                           product = a.get("product")[0]
                    if not(a.get("locus_tag")==None):
                        locus_tag = a.get("locus_tag")[0]
                    else:
                        locus_tag = feature.type
                    annotated_regions.append((locus_tag, product, feature.type, int(feature.location.start), int(feature.location.end), str(feature.location.strand)))
            annotated_regions.sort(key = lambda x: x[4])
            prev_strand = 0
            prev_locus = ''
            prev_product = ''
            max_stop = 0
            for n, (locus, product, feature_type, start, stop, strand) in enumerate(annotated_regions):
                if start > max_stop:
                    intergenic_regions.append([prev_locus+':'+locus, prev_product + ':' + product, 'Inter-feature',max_stop, start, str(prev_strand)+':'+str(strand)])
                if stop > max_stop:
                    prev_locus = locus
                    prev_product = product
                    prev_strand = strand
                max_stop = max(max_stop, stop)    
            for x in intergenic_regions:
                annotated_regions.append(x)
            annotated_regions.sort(key = lambda x : x[4])
            output.append([accession_ver, annotated_regions])
    return output

# %%
parallel_output = Parallel(n_jobs=-1)(delayed(annotated_regions_dataset)(num_cores, core_number, mycobacteria_dirs, mycobacteria_seq_dir) for core_number in core_numbers)
annotated_regions_dict = {}
for x in parallel_output:
    for y in x:
        annotated_regions_dict[y[0]] = y[1]

# %%
def location(accession_ver, start1, end1):
    feature_matches = []
    for (locus, product, feature, start, stop, strand) in annotated_regions_dict[accession_ver]:
            if start< end1 and stop > start1:
                overlap = str(int(100*(min(end1, stop) - max(start1, start))/ (end1-start1)))+'%'
                feature_matches.append([locus, product, feature, overlap, strand])
    return feature_matches

# %% [markdown]
# #### Functions to run MEME and FIMO

# %%
def run_meme(search_regions_loc, output_dir, min_width, min_sites):
    subprocess.run('wsl export PATH=$HOME/meme/bin:$HOME/meme/libexec/meme-5.4.1:usr/bin:$PATH ; meme '+ util.wslname(search_regions_loc) + ' -oc '+ util.wslname(output_dir) +' -dna -evt 0.01 -revcomp -mod anr -brief 4000 -minw ' + str(min_width) +' -maxw 200 -minsites ' + str(min_sites)
               , shell=True)

# %%
def run_fimo(motif_file, sequence_to_search_file, output_dir):
    subprocess.run('wsl export PATH=$HOME/meme/bin:$HOME/meme/libexec/meme-5.4.1:usr/bin:$PATH ; fimo -oc ' + util.wslname(output_dir) + ' ' + util.wslname(motif_file) + ' ' + util.wslname(sequence_to_search_file)
               , shell=True)

# %% [markdown]
# #### Produce dictionary with upstream and downstream sequences relative to CDS locus id

# %%
tb_upstream_dict = {}
tb_downstream_dict = {}
all_features = []
genome_record =  next(SeqIO.parse(mycobacteria_seq_dir + '/'+tb_annotation_dirname+'/genomic.gbff', "genbank"))
full_sequence = str(genome_record.seq)
len_full_sequence = len(full_sequence)
for feature in genome_record.features:
    if feature.type in ['gene', 'source']:
        continue
    a = feature.qualifiers
    feature_type = feature.type
    if a.get("locus_tag") != None:
        locus_tag = a.get("locus_tag")[0]
    else:
        locus_tag  = ''
    (start, stop, strand) = (int(feature.location.start), int(feature.location.end), int(feature.location.strand))
    all_features.append([locus_tag, feature_type, start, stop, strand])

# Positive strand upstream 
all_features.sort(key = lambda x: x[2])
max_stop = 0
for (locus, feature_type, start, stop, strand) in all_features:
    if max_stop < start and feature_type == 'CDS' and strand == 1 and start - max_stop < 100000:    #Avoid joins where biopython interprets inconsistently 
        tb_upstream_dict[locus] = full_sequence[max_stop: start+3]
    max_stop = max(max_stop, stop)
# Negative strand upstream
all_features.sort(key = lambda x: x[3], reverse = True)
min_start = len(full_sequence)-1
for (locus, feature_type, start, stop, strand) in all_features:
    if stop < min_start and feature_type == 'CDS' and strand == -1 and min_start - stop < 100000:
        tb_upstream_dict[locus] = util.reverse_complement(full_sequence[stop-3: min_start])
    min_start = min(min_start, start)
    
# Positive strand downstream
all_features.sort(key = lambda x: x[3], reverse = True)
min_start = len(full_sequence)-1
for (locus, feature_type, start, stop, strand) in all_features:
    if stop < min_start and feature_type == 'CDS' and strand == 1 and min_start - stop < 100000:
        tb_downstream_dict[locus] = full_sequence[stop-3: min_start]
    min_start = min(min_start, start)
# Negative strand downstream 
all_features.sort(key = lambda x: x[2])
max_stop = 0
for (locus, feature_type, start, stop, strand) in all_features:
    if max_stop < start and feature_type == 'CDS' and strand == -1 and start - max_stop < 100000:    #Avoid joins where biopython interprets inconsistently 
        tb_downstream_dict[locus] = util.reverse_complement(full_sequence[max_stop: start+3])
    max_stop = max(max_stop, stop)

# %% [markdown]
# #### Import list of significantly up/downregulated genes and produce fasta file of upstream sequences

# %%
regulation_type_dict = {}
p_val_dict = {}
downreg_genes = pd.read_excel(project_dir + '/2022-10-02_data_NU_NAs_renamed.xlsx', sheet_name = 'significant genes downregulated')
upreg_genes = pd.read_excel(project_dir + '/2022-10-02_data.xlsx', sheet_name = 'significant genes upregulated')
all_genes = pd.read_excel(project_dir + '/2022-10-02_data.xlsx', sheet_name = 'all genes')
gene_list = []
for i, r in downreg_genes.iterrows():
    gene_list.append(r['Locus'])
    regulation_type_dict[r['Locus']] = 'Downregulated'
for i, r in upreg_genes.iterrows():
    gene_list.append(r['Locus'])
    regulation_type_dict[r['Locus']] = 'Upregulated'
for i, r in all_genes.iterrows():
    if r['padj'] == 'NA':
        p_val_dict[r['Locus']] = 999
    else:    
        p_val_dict[r['Locus']] = r['padj']

# %%
significant_upstream_tb_regions = []
significant_downstream_tb_regions = []
for gene in gene_list:
    locus = str(gene)
    if locus in tb_upstream_dict:
        upstream_region = tb_upstream_dict[locus][:-3]  # Remove start codon of downstream gene
        if len(upstream_region) >= min_region_length:
            significant_upstream_tb_regions.append([locus, upstream_region])
    if locus in tb_downstream_dict:
        downstream_region = tb_downstream_dict[locus][:-3]  # Remove start codon of downstream gene
        if len(downstream_region) >= min_region_length:
            significant_downstream_tb_regions.append([locus, downstream_region])
util.produce_fasta_file(significant_upstream_tb_regions, project_dir + '/significant_upstream_tb_regions.faa')
util.produce_fasta_file(significant_downstream_tb_regions, project_dir + '/significant_downstream_tb_regions.faa')
# Out:
# 100%|██████████| 177/177 [00:00<00:00, 177055.05it/s]
# 100%|██████████| 145/145 [00:00<00:00, 144975.94it/s]

# %% [markdown]
# #### Run MEME, search against tb using FIMO

# %%
run_meme(project_dir + '/significant_upstream_tb_regions.faa',project_dir + '/MEME_Upstream_Output',3,5)
run_meme(project_dir + '/significant_downstream_tb_regions.faa',project_dir + '/MEME_Downstream_Output',3,5)

# %%
run_fimo(project_dir + '/MEME_Upstream_Output/meme.txt', project_dir + '/mtb_seq' , project_dir + '/FIMO_Upstream_Output')
run_fimo(project_dir + '/MEME_Downstream_Output/meme.txt', project_dir + '/mtb_seq' , project_dir + '/FIMO_Downstream_Output')

# %%
fimo_upstream_hits = pd.read_csv(project_dir + '/FIMO_Upstream_Output/fimo.tsv', sep='\t')
fimo_downstream_hits = pd.read_csv(project_dir + '/FIMO_Downstream_Output/fimo.tsv', sep='\t')

# %%
run_meme('F:/Project_Data/Intergenic_Region_Comparative_Analysis/Rv2248/intergenic_regions_1.fasta',project_dir + '/Temp_MEME_Output',3,5)

# %%
run_fimo(project_dir + '/Temp_MEME_Output/meme.txt', project_dir + '/all_seq' , project_dir + '/Temp_FIMO_Output')

# %%
def produce_matched_sequence_file(hit_df, output_file):
    matched_sequences = []
    for i, r in hit_df.iterrows():
        if '#' in r['motif_id']:
            continue
        if float(r['q-value']) < 1e-3:
            matched_sequences.append([str(r['start'])+'_'+str(r['stop']), r['matched_sequence']])
    util.produce_fasta_file(matched_sequences, output_file)

# %%
produce_matched_sequence_file(fimo_upstream_hits, project_dir + '/fimo_upstream_hit_sequences.faa')
produce_matched_sequence_file(fimo_downstream_hits, project_dir + '/fimo_downstream_hit_sequences.faa')
# Out:
# 100%|██████████| 162/162 [00:00<?, ?it/s]
# 100%|██████████| 150/150 [00:00<?, ?it/s]

# %%
run_meme(project_dir + '/fimo_upstream_hit_sequences.faa', project_dir + '/Second_MEME_Upstream_Output',3,5)
run_meme(project_dir + '/fimo_downstream_hit_sequences.faa', project_dir + '/Second_MEME_Downstream_Output',3,5)

# %%
run_fimo(project_dir + '/Second_MEME_Upstream_Output/meme.txt', project_dir + '/all_seq' , project_dir + '/Second_FIMO_Upstream_Output')
run_fimo(project_dir + '/Second_MEME_Downstream_Output/meme.txt', project_dir + '/all_seq' , project_dir + '/Second_FIMO_Downstream_Output')

# %% [markdown]
# #### Final motif and searches

# %%
temp_fimo_hits = pd.read_csv(project_dir + '/Temp_FIMO_Output/fimo.tsv', sep='\t')
hit_dict = {}
for i, r in temp_fimo_hits.iterrows():
    if '#' in r['motif_id']:
        continue
    organism = r['sequence_name']
    motif_id = r['motif_alt_id']
    if float(r['q-value']) < 1e-4 and motif_id == 'MEME-1':
        temp = location(r['sequence_name'],int(r['start']), int(r['stop']))
        if len(temp) > 0:
            temp.sort(key = lambda x: float(x[3].strip('%')), reverse = True)
            main_location = temp[0]
        else:
            main_location = ''
 

        info = [int(r['start']), int(r['stop']), r['strand'], float(r['q-value']), main_location, r['matched_sequence']]
        if organism in hit_dict:
            hit_dict[organism].append(info)
        else:
            hit_dict[organism] = [info]

for k, v in hit_dict.items():
    v.sort(key = lambda x: x[0])

# %%
genes = []
v = hit_dict[tb_species]
for n, (start, stop, strand, q, loc, matched_seq) in enumerate(v):
    for x in loc[0].split(':'):
        genes.append(x)
b = set(genes)
inters = b.intersection(set(gene_list))

# %%
print(len(b), len(inters), len(gene_list))
# Out:
# 134 17 236

# %%
names_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13828/1466361219.py in <module>
# ----> 1 names_dict
#
# NameError: name 'names_dict' is not defined

# %%
b.intersection(set(gene_list))
# Out:
# {'Rv0154c',
#  'Rv0211',
#  'Rv0467',
#  'Rv0468',
#  'Rv0711',
#  'Rv0860',
#  'Rv0896',
#  'Rv1058',
#  'Rv1180',
#  'Rv2845c',
#  'Rv2846c',
#  'Rv3140',
#  'Rv3319',
#  'Rv3383c',
#  'Rv3416',
#  'Rv3792',
#  'Rv3795'}

# %%
1- binom.cdf(len(inters), len(b),(len(gene_list))/3900)
# Out:
# 0.0012562765454423586

# %%
pd.DataFrame(hit_info, columns = ['name', 'variable', 'value']).to_csv(project_dir + '/Hit_Counts.csv')

# %%
for k, v in hit_dict.items():
    print(k, v)
# Out:
# AL123456.3 [[183270, 183291, '+', 4.64e-05, ['Rv0154c:Rv0155', 'Probable acyl-CoA dehydrogenase FadE2:Probable NAD(P) transhydrogenase (subunit alpha) PntAa [first part; catalytic part] (pyridine nucleotide transhydrogenase subunit alpha) (nicotinamide nucleotide transhydrogenase subunit alpha)', 'Inter-feature', '100%', '-1:1'], 'AGGGGGTTTTGCGTCTGCTCGC'], [234447, 234468, '-', 9.96e-07, ['Rv0197', 'Possible oxidoreductase', 'CDS', '100%', '1'], 'GGGCGATTCTGCGTCTGCTCGG'], [253604, 253625, '-', 2.3e-05, ['Rv0211:Rv0212c', 'Probable iron-regulated phosphoenolpyruvate carboxykinase [GTP] PckA (phosphoenolpyruvate carboxylase) (PEPCK)(pep carboxykinase):Possible transcriptional regulatory protein NadR (probably AsnC-family)', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTATGCGTCTGCTCGC'], [279535, 279556, '-', 2.89e-07, ['Rv0233:Rv0234c', 'Ribonucleoside-diphosphate reductase (beta chain) NrdB (ribonucleotide reductase small chain):Succinate-semialdehyde dehydrogenase [NADP+] dependent (SSDH) GabD1', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTTTGCGTCTGCTCGC'], [279573, 279594, '+', 2.89e-07, ['Rv0233:Rv0234c', 'Ribonucleoside-diphosphate reductase (beta chain) NrdB (ribonucleotide reductase small chain):Succinate-semialdehyde dehydrogenase [NADP+] dependent (SSDH) GabD1', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTTTGCGTCTGCTCGC'], [456202, 456223, '-', 2.69e-07, ['Rv0379:Rv0380c', 'Possible protein transport protein SecE2:Possible RNA methyltransferase (RNA methylase)', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], [456240, 456261, '+', 7.47e-07, ['Rv0379:Rv0380c', 'Possible protein transport protein SecE2:Possible RNA methyltransferase (RNA methylase)', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGTGTCTGCTCGC'], [459426, 459447, '+', 3.93e-05, ['Rv0383c:Rv0384c', 'Possible conserved secreted protein:Probable endopeptidase ATP binding protein (chain B) ClpB (ClpB protein) (heat shock protein F84.1)', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTCCGCGTCTGCTCGT'], [558818, 558839, '-', 4.05e-05, ['Rv0467:Rv0468', 'Isocitrate lyase Icl (isocitrase) (isocitratase):3-hydroxybutyryl-CoA dehydrogenase FadB2 (beta-hydroxybutyryl-CoA dehydrogenase) (BHBD)', 'Inter-feature', '100%', '1:1'], 'GGGTGCTTTTGCGTCTGCTCGG'], [558856, 558877, '+', 6.58e-05, ['Rv0467:Rv0468', 'Isocitrate lyase Icl (isocitrase) (isocitratase):3-hydroxybutyryl-CoA dehydrogenase FadB2 (beta-hydroxybutyryl-CoA dehydrogenase) (BHBD)', 'Inter-feature', '100%', '1:1'], 'TGGCGCTTTTGCGTCTGCTCGC'], [663390, 663411, '-', 2.69e-07, ['Rv0570:Rv0571c', 'Probable ribonucleoside-diphosphate reductase (large subunit) NrdZ (ribonucleotide reductase):Conserved protein', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGCGTCTGCTCGC'], [663428, 663449, '+', 9.35e-07, ['Rv0570:Rv0571c', 'Probable ribonucleoside-diphosphate reductase (large subunit) NrdZ (ribonucleotide reductase):Conserved protein', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGCGTCTGCTCGC'], [736233, 736254, '-', 2.3e-05, ['Rv0641:Rv0642c', '50S ribosomal protein L1 RplA:Methoxy mycolic acid synthase 4 MmaA4 (methyl mycolic acid synthase 4) (MMA4) (hydroxy mycolic acid synthase)', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTATGCGTCTGCTCGC'], [736271, 736292, '+', 2.3e-05, ['Rv0641:Rv0642c', '50S ribosomal protein L1 RplA:Methoxy mycolic acid synthase 4 MmaA4 (methyl mycolic acid synthase 4) (MMA4) (hydroxy mycolic acid synthase)', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTATGCGTCTGCTCGC'], [755266, 755287, '-', 2.3e-05, ['Rv0660c:Rv0661c', 'Possible antitoxin MazE2:Possible toxin VapC7', 'Inter-feature', '100%', '-1:-1'], 'GGGGGCTTATGCGTCTGCTCGC'], [767325, 767346, '-', 2.69e-07, ['Rv0668:Rv0669c', "DNA-directed RNA polymerase (beta' chain) RpoC (transcriptase beta' chain) (RNA polymerase beta' subunit).:Possible hydrolase", 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGCGTCTGCTCGC'], [767363, 767384, '+', 9.35e-07, ['Rv0668:Rv0669c', "DNA-directed RNA polymerase (beta' chain) RpoC (transcriptase beta' chain) (R ...
# HE572590.1 [[189938, 189959, '+', 4.64e-05, ['MCAN_01591:MCAN_01601', 'putative acyl-CoA dehydrogenase FADE2:putative NAD(P) transhydrogenase (subunit alpha) PNTAA [first part; catalytic part] (pyridine nucleotide transhydrogenase subunit alpha) (nicotinamide nucleotide transhydrogenase subunit alpha)', 'Inter-feature', '100%', '-1:1'], 'AGGGGGTTTTGCGTCTGCTCGC'], [241174, 241195, '-', 9.96e-07, ['MCAN_02031', 'putative oxidoreductase', 'CDS', '100%', '1'], 'GGGCGATTCTGCGTCTGCTCGG'], [241212, 241233, '+', 3.24e-07, ['MCAN_02031:MCAN_02041', 'putative oxidoreductase:putative zinc metalloprotease', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTCTGCGTCTGCTCGC'], [260333, 260354, '-', 2.3e-05, ['MCAN_02171:MCAN_02181', 'putative iron-regulated phosphoenolpyruvate carboxykinase [GTP] PCKA (phosphoenolpyruvate carboxylase) (PEPCK)(PEP carboxykinase):putative transcriptional regulatory protein NADR (probably ASNC-family)', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTATGCGTCTGCTCGC'], [286293, 286314, '-', 2.89e-07, ['MCAN_02391:MCAN_02401', 'putative ribonucleoside-diphosphate reductase (beta chain) NRDB (ribonucleotide reductase small chain):putative succinate-semialdehyde dehydrogenase [NADP+] dependent (SSDH) GABD1', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTTTGCGTCTGCTCGC'], [286331, 286352, '+', 2.89e-07, ['MCAN_02391:MCAN_02401', 'putative ribonucleoside-diphosphate reductase (beta chain) NRDB (ribonucleotide reductase small chain):putative succinate-semialdehyde dehydrogenase [NADP+] dependent (SSDH) GABD1', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTTTGCGTCTGCTCGC'], [465575, 465596, '-', 2.69e-07, ['MCAN_03811:MCAN_03821', 'putative protein transport protein SECE2:putative RNA methyltransferase (RNA methylase)', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], [465613, 465634, '+', 7.47e-07, ['MCAN_03811:MCAN_03821', 'putative protein transport protein SECE2:putative RNA methyltransferase (RNA methylase)', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGTGTCTGCTCGC'], [468761, 468782, '-', 2.49e-06, ['MCAN_03851:MCAN_03861', 'putative conserved secreted protein:putative endopeptidase ATP binding protein (chain B) CLPB (CLPB protein) (heat shock protein F84.1)', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTCCGCGTCTGCTCGG'], [468799, 468820, '+', 3.93e-05, ['MCAN_03851:MCAN_03861', 'putative conserved secreted protein:putative endopeptidase ATP binding protein (chain B) CLPB (CLPB protein) (heat shock protein F84.1)', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTCCGCGTCTGCTCGT'], [569098, 569119, '-', 4.05e-05, ['MCAN_04661:MCAN_04671', 'isocitrate lyase ICL (isocitrase) (isocitratase):putative 3-hydroxybutyryl-CoA dehydrogenase FADB2 (beta-hydroxybutyryl-CoA dehydrogenase) (BHBD)', 'Inter-feature', '100%', '1:1'], 'GGGTGCTTTTGCGTCTGCTCGG'], [569136, 569157, '+', 6.58e-05, ['MCAN_04661:MCAN_04671', 'isocitrate lyase ICL (isocitrase) (isocitratase):putative 3-hydroxybutyryl-CoA dehydrogenase FADB2 (beta-hydroxybutyryl-CoA dehydrogenase) (BHBD)', 'Inter-feature', '100%', '1:1'], 'TGGCGCTTTTGCGTCTGCTCGC'], [676865, 676886, '-', 2.69e-07, ['MCAN_05731:MCAN_05741', 'putative ribonucleoside-diphosphate reductase (large subunit) NRDZ (ribonucleotide reductase):conserved hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGCGTCTGCTCGC'], [676903, 676924, '+', 9.35e-07, ['MCAN_05731:MCAN_05741', 'putative ribonucleoside-diphosphate reductase (large subunit) NRDZ (ribonucleotide reductase):conserved hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGCGTCTGCTCGC'], [745767, 745788, '-', 2.3e-05, ['MCAN_06401:MCAN_06411', 'putative 50S ribosomal protein L1 RPLA:methoxy mycolic acid synthase 4 MMAA4 (methyl mycolic acid synthase 4) (MMA4) (hydroxy mycolic acid synthase)', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTATGCGTCTGCTCGC'], [745805, 745826, '+', 2.3e-05, ['MCAN_06401:MCAN_06411', 'putative 50S ribosomal protein L1 RPLA:methoxy mycolic acid synthase 4 MMAA4 (methyl mycolic acid synthase 4) (MMA4 ...
# CP085200.1 [[224784, 224805, '-', 8.84e-07, ['LH162_01090:LH162_01095', 'PE family protein:PE family protein', 'Inter-feature', '100%', '1:1'], 'GGGCGATTTTGTGTCTGCTCGC'], [224822, 224843, '+', 2.36e-06, ['LH162_01090:LH162_01095', 'PE family protein:PE family protein', 'Inter-feature', '100%', '1:1'], 'ATGCGATTTTGTGTCTGCTCGC'], [226152, 226173, '-', 2.89e-07, ['LH162_01095:LH162_01100', 'PE family protein:glucose-1-phosphate adenylyltransferase', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTTTGCGTCTGCTCGC'], [226190, 226211, '+', 1.93e-06, ['LH162_01095:LH162_01100', 'PE family protein:glucose-1-phosphate adenylyltransferase', 'Inter-feature', '100%', '1:-1'], 'GCGCGATTTTGTGTCTGCTCGC'], [542517, 542538, '-', 2.9e-06, ['LH162_02595:LH162_02600', 'acyl-CoA dehydrogenase family protein:cytochrome P450', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTTCGCGTCTGCTCGC'], [542555, 542576, '+', 2.36e-06, ['LH162_02595:LH162_02600', 'acyl-CoA dehydrogenase family protein:cytochrome P450', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTTTGTGTCTGCTCGC'], [563720, 563741, '-', 1.06e-05, ['LH162_02720:LH162_02725', 'enoyl-CoA hydratase/isomerase family protein:FAD-dependent monooxygenase', 'Inter-feature', '100%', '1:-1'], 'ACGCGATTCCGCGTCTGCTCGC'], [567807, 567828, '-', 2.69e-07, ['LH162_02740:LH162_02745', 'hypothetical protein:DEAD/DEAH box helicase', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], [567846, 567867, '+', 2.69e-07, ['LH162_02740:LH162_02745', 'hypothetical protein:DEAD/DEAH box helicase', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], [610159, 610180, '-', 3.7e-05, ['LH162_02960:LH162_02965', 'two-component system response regulator PrrA:FAD-binding dehydrogenase', 'Inter-feature', '100%', '-1:-1'], 'ATGCGATTCCACGTCTGCTCGC'], [610197, 610218, '+', 1.12e-05, ['LH162_02960:LH162_02965', 'two-component system response regulator PrrA:FAD-binding dehydrogenase', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTCCACGTCTGCTCGC'], [631512, 631533, '-', 2.32e-05, ['LH162_03035:LH162_03040', 'fatty acid--CoA ligase:dihydrodipicolinate reductase', 'Inter-feature', '100%', '1:1'], 'ATGCAAGTCTGTGTCTGCTCGC'], [631550, 631571, '+', 7.6e-07, ['LH162_03035:LH162_03040', 'fatty acid--CoA ligase:dihydrodipicolinate reductase', 'Inter-feature', '100%', '1:1'], 'GTGCGATTCTGTGTCTGCTCGC'], [662711, 662732, '-', 7.6e-07, ['LH162_03170:LH162_03175', 'cystathionine gamma-synthase:transcription elongation factor GreA', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGTGTCTGCTCGC'], [662749, 662770, '+', 3.24e-05, ['LH162_03170:LH162_03175', 'cystathionine gamma-synthase:transcription elongation factor GreA', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGTGTCTGCTCGT'], [1346774, 1346795, '-', 2.32e-06, ['LH162_06475:LH162_06480', 'acyl-CoA synthetase:PaaI family thioesterase', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTTCGCGTCTGCTCGG'], [1346812, 1346833, '+', 8.38e-07, ['LH162_06475:LH162_06480', 'acyl-CoA synthetase:PaaI family thioesterase', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTCCGCGTCTGCTCGC'], [1414744, 1414765, '-', 4.85e-05, ['LH162_06760:LH162_06765', 'holo-ACP synthase:DUF2339 domain-containing protein', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTTCGCGTCTGTTCGC'], [1414782, 1414803, '+', 5.28e-05, ['LH162_06760:LH162_06765', 'holo-ACP synthase:DUF2339 domain-containing protein', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTCGCGCCTGCTCGC'], [3160147, 3160168, '-', 2.69e-07, ['LH162_14675:LH162_14680', 'aspartate aminotransferase family protein:LLM class F420-dependent oxidoreductase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], [3160185, 3160206, '+', 8.38e-07, ['LH162_14675:LH162_14680', 'aspartate aminotransferase family protein:LLM class F420-dependent oxidoreductase', 'Inter-feature', '100%', '1:-1'], 'GCGCGATTTTGCGTCTGCTCGC'], [3323887, 3323908, '-', 2.69e-07, ['LH162_15460:LH162_15465', 'alpha/beta hydrolase:type I methionyl aminopeptidase', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], ...
# AP022620.1 [[295624, 295645, '-', 2.8e-06, ['MANY_02830:MANY_02840', 'hydrogenase expression/formation protein HypE:putative amino-acid permease', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTATGCGTCTGCTCGC'], [295662, 295683, '+', 8.15e-07, ['MANY_02830:MANY_02840', 'hydrogenase expression/formation protein HypE:putative amino-acid permease', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGCGTCTGCTCGG'], [342898, 342919, '-', 7.15e-05, ['MANY_03310:MANY_03320', 'acetyltransferase:membrane protein', 'Inter-feature', '100%', '1:1'], 'ATGCGACTTTGCGTCTGTTCGC'], [342936, 342957, '+', 4.93e-05, ['MANY_03310:MANY_03320', 'acetyltransferase:membrane protein', 'Inter-feature', '100%', '1:1'], 'GTGCGATTTTGCGCCTGCTCGG'], [570107, 570128, '+', 1.63e-05, ['MANY_05440:MANY_05450', 'iron ABC transporter substrate-binding protein:1-deoxy-D-xylulose 5-phosphate reductoisomerase', 'Inter-feature', '100%', '-1:1'], 'GTGCGAGTTCGCGTCTGCTCAC'], [611587, 611608, '-', 2.69e-07, ['MANY_05880:MANY_05890', 'cobalt ABC transporter ATP-binding protein:mycothione reductase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], [611625, 611646, '+', 2.69e-07, ['MANY_05880:MANY_05890', 'cobalt ABC transporter ATP-binding protein:mycothione reductase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], [697335, 697356, '-', 8.15e-07, ['MANY_06670:MANY_06680', 'ribonuclease J:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGCGTCTGCTCGG'], [697373, 697394, '+', 8.15e-07, ['MANY_06680', 'hypothetical protein', 'CDS', '100%', '-1'], 'GTGCGATTTTGCGTCTGCTCGG'], [941612, 941633, '-', 8.38e-07, ['MANY_09070:MANY_09080', 'hypothetical protein:gamma-aminobutyraldehyde dehydrogenase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTCGCGTCTGCTCGC'], [941650, 941671, '+', 2.69e-07, ['MANY_09070:MANY_09080', 'hypothetical protein:gamma-aminobutyraldehyde dehydrogenase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTTTGCGTCTGCTCGC'], [1005849, 1005870, '+', 3.84e-07, ['MANY_09710', 'hypothetical protein', 'CDS', '100%', '-1'], 'GTGCGAGTTTGCGTCTGCTCGC'], [2933912, 2933933, '-', 3.53e-05, ['MANY_27620:MANY_27630', 'hypothetical protein:lipid-transfer protein', 'Inter-feature', '100%', '-1:1'], 'GTGCGAGTCTGCGCCTGCTCGC'], [3029610, 3029631, '+', 1.25e-05, ['MANY_28520:MANY_28530', 'RNA polymerase sigma24 factor:aminodeoxychorismate synthase component I', 'Inter-feature', '100%', '1:1'], 'GCGCGACTTTGCGTCTGCTCGG'], [4783747, 4783768, '-', 6e-05, ['MANY_45530:MANY_45540', 'chaperone protein ClpB:TetR family transcriptional regulator', 'Inter-feature', '100%', '1:-1'], 'GTGCGACTTTGCGTCTGTTCGG'], [4984124, 4984145, '-', 4.44e-06, ['MANY_47640', 'cytochrome c biogenesis protein', 'CDS', '100%', '1'], 'GTGCGATTGTGCGTCTGCTCGC'], [5037637, 5037658, '-', 2.69e-07, ['MANY_48230:MANY_48240', 'mechanosensitive ion channel protein MscS:hypothetical protein', 'Inter-feature', '100%', '-1:1'], 'GTGCGATTTTGCGTCTGCTCGC'], [5037675, 5037696, '+', 5.43e
# LR130759.1 [[361043, 361064, '-', 2.96e-06, ['MB901379_00347', 'Assimilatory nitrate reductase catalytic subunit', 'CDS', '100%', '1'], 'ATGCGATTCTGCGTCTGCTCGG'], [361081, 361102, '+', 2.12e-06, ['MB901379_00347:MB901379_00348', 'Assimilatory nitrate reductase catalytic subunit:Neutral endopeptidase', 'Inter-feature', '100%', '1:-1'], 'GCGCGATTCTGTGTCTGCTCGC'], [467310, 467331, '-', 8.18e-06, ['MB901379_00438:MB901379_00439', 'Long-chain-fatty-acid--CoA ligase:Acyl-CoA dehydrogenase, short-chain specific', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGTGTCTGCTCGG'], [467348, 467369, '+', 2.54e-06, ['MB901379_00438:MB901379_00439', 'Long-chain-fatty-acid--CoA ligase:Acyl-CoA dehydrogenase, short-chain specific', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGTGTCTGCTCGC'], [766530, 766551, '-', 8.38e-07, ['MB901379_00676:MB901379_00677', 'Isocitrate lyase:3-hydroxybutyryl-CoA dehydrogenase', 'Inter-feature', '100%', '1:1'], 'GTGCGATTCTGCGTCTGCTCGG'], [766568, 766589, '+', 1.85e-06, ['MB901379_00676:MB901379_00677', 'Isocitrate lyase:3-hydroxybutyryl-CoA dehydrogenase', 'Inter-feature', '100%', '1:1'], 'ATGCGAGTCTGCGTCTGCTCGC'], [835068, 835089, '-', 1.11e-06, ['MB901379_00743', 'ResB-like family protein', 'CDS', '100%', '1'], 'GGGCGATTCCGCGTCTGCTCGC'], [835106, 835127, '+', 8.38e-07, ['MB901379_00743', 'ResB-like family protein', 'CDS', '100%', '1'], 'GTGCGATTCCGCGTCTGCTCGC'], [926499, 926520, '-', 7.1e-05, ['MB901379_00834:MB901379_00835', '50S ribosomal protein L1:Hydroxymycolate synthase MmaA4', 'Inter-feature', '100%', '1:-1'], 'TGGCGATTCTGTGTCTGCTCGC'], [926537, 926558, '+', 6.89e-05, ['MB901379_00834:MB901379_00835', '50S ribosomal protein L1:Hydroxymycolate synthase MmaA4', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGTGTCTGCTGGG'], [956379, 956400, '-', 8.38e-07, ['MB901379_00853:MB901379_00854', "DNA-directed RNA polymerase subunit beta':Neutral ceramidase", 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGCGTCTGCTCGG'], [956417, 956438, '+', 9.35e-07, ['MB901379_00853:MB901379_00854', "DNA-directed RNA polymerase subunit beta':Neutral ceramidase", 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGCGTCTGCTCGC'], [1007940, 1007961, '-', 8.38e-07, ['MB901379_00915:MB901379_00916', '50S ribosomal protein L15:Alkanesulfonate monooxygenase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCCGCGTCTGCTCGC'], [1007978, 1007999, '+', 8.38e-07, ['MB901379_00915:MB901379_00916', '50S ribosomal protein L15:Alkanesulfonate monooxygenase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCCGCGTCTGCTCGC'], [1613054, 1613075, '-', 2.54e-06, ['MB901379_01430:MB901379_01431', 'Acyl-CoA dehydrogenase:putative nucleic-acid-binding protein containing a Zn-ribbon', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGTGTCTGCTCGC'], [1613092, 1613113, '+', 2.54e-06, ['MB901379_01430:MB901379_01431', 'Acyl-CoA dehydrogenase:putative nucleic-acid-binding protein containing a Zn-ribbon', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGTGTCTGCTCGC'], [1649305, 1649326, '-', 2.96e-06, ['MB901379_01469', 'hypothetical protein', 'CDS', '100%', '-1'], 'ATGCGATTCTGCGTCTGCTCGG'], [1649343, 1649364, '+', 2.69e-07, ['MB901379_01469', 'hypothetical protein', 'CDS', '100%', '-1'], 'GTGCGATTCTGCGTCTGCTCGC'], [1656823, 1656844, '-', 8.38e-07, ['MB901379_01476:MB901379_01477', 'Hydrogenase-4 component G:putative ABC transporter ATP-binding protein YlmA', 'Inter-feature', '100%', '1:1'], 'GTGCGATTCTGCGTCTGCTCGG'], [1656861, 1656882, '+', 1.12e-05, ['MB901379_01477', 'putative ABC transporter ATP-binding protein YlmA', 'CDS', '100%', '1'], 'ATGCGATTCTGCGTCTGCTGGC'], [1699496, 1699517, '-', 2.69e-07, ['MB901379_01513:MB901379_01514', 'Glutamyl-tRNA(Gln) amidotransferase subunit A:6-phosphofructokinase', 'Inter-feature', '100%', '1:1'], 'GTGCGATTTTGCGTCTGCTCGC'], [1699534, 1699555, '+', 9.28e-07, ['MB901379_01513:MB901379_01514', 'Glutamyl-tRNA(Gln) amidotransferase subunit A:6-phosphofructokinase', 'Inter-feature', '100%', '1:1'], 'ATGCGATTTTGCGTCTGCTCGC'], [2005023, 2005044, '+', 3.24e- ...
# AP022615.1 [[77682, 77703, '-', 2.54e-06, ['MHEI_00760:MHEI_00770', 'monoxygenase:S-adenosylmethionine synthase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGCGACTGCTCGC'], [77720, 77741, '+', 2.54e-06, ['MHEI_00760:MHEI_00770', 'monoxygenase:S-adenosylmethionine synthase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGCGACTGCTCGC'], [267234, 267255, '-', 4.97e-06, ['MHEI_02720:MHEI_02730', 'amino-acid acetyltransferase:DNA translocase FtsK', 'Inter-feature', '100%', '1:-1'], 'ATGCGAGTCTGTGTCTGCTCGC'], [267272, 267293, '+', 2.54e-06, ['MHEI_02720:MHEI_02730', 'amino-acid acetyltransferase:DNA translocase FtsK', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCTGTGTCTGCTCGC'], [282964, 282985, '-', 2.53e-05, ['MHEI_02890:MHEI_02900', 'hypothetical protein:acyl-CoA dehydrogenase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTATGTCTGCTCGG'], [283002, 283023, '+', 3.2e-06, ['MHEI_02890:MHEI_02900', 'hypothetical protein:acyl-CoA dehydrogenase', 'Inter-feature', '100%', '1:-1'], 'ATGCGATTCCGCGTCTGCTCGC'], [364168, 364189, '-', 9.35e-07, ['MHEI_03710:MHEI_03720', 'cobyric acid synthase:methionine aminopeptidase', 'Inter-feature', '100%', '-1:-1'], 'ATGCGATTCTGCGTCTGCTCGC'], [364206, 364227, '+', 7.6e-07, ['MHEI_03710:MHEI_03720', 'cobyric acid synthase:methionine aminopeptidase', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTCTGTGTCTGCTCGC'], [386021, 386042, '-', 1.36e-06, ['MHEI_03970:MHEI_03980', 'hypothetical protein:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GTGCGAGTCTGCGTCTGCTCGG'], [400075, 400096, '+', 8.38e-07, ['MHEI_04140:MHEI_04150', 'IS110 family transposase:tRNA (guanine-N(1)-)-methyltransferase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGCGTCTGCTCGG'], [518885, 518906, '-', 9.35e-07, ['MHEI_04940:MHEI_t00050', 'PPOX class F420-dependent enzyme:tRNA-Glu', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTTTGCGTCTGCTCGG'], [518923, 518944, '+', 8.38e-07, ['MHEI_04940:MHEI_t00050', 'PPOX class F420-dependent enzyme:tRNA-Glu', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCCGCGTCTGCTCGC'], [539413, 539434, '-', 4.14e-07, ['MHEI_05120:MHEI_05130', 'ATP-dependent 6-phosphofructokinase:glutamyl-tRNA(Gln) amidotransferase subunit A', 'Inter-feature', '100%', '-1:-1'], 'GTGCGAGTCTGCGTCTGCTCGC'], [539451, 539472, '+', 4.14e-07, ['MHEI_05120:MHEI_05130', 'ATP-dependent 6-phosphofructokinase:glutamyl-tRNA(Gln) amidotransferase subunit A', 'Inter-feature', '100%', '-1:-1'], 'GTGCGAGTCTGCGTCTGCTCGC'], [566419, 566440, '-', 8.38e-07, ['MHEI_05390', 'ABC transporter ATP-binding protein', 'CDS', '100%', '-1'], 'GTGCGATTCCGCGTCTGCTCGC'], [566457, 566478, '+', 8.38e-07, ['MHEI_05390:MHEI_05400', 'ABC transporter ATP-binding protein:phosphoserine phosphatase SerB', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTCCGCGTCTGCTCGC'], [593860, 593881, '+', 4.14e-07, ['MHEI_05690:MHEI_05700', 'IS110 family transposase:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GTGCGAGTCTGCGTCTGCTCGC'], [883343, 883364, '-', 4.22e-06, ['MHEI_08520:MHEI_08530', 'hypothetical protein:chromosome partitioning protein ParA', 'Inter-feature', '100%', '1:-1'], 'GTGCGACTCTGCGTCTGCTCGG'], [883381, 883402, '+', 1.25e-06, ['MHEI_08520:MHEI_08530', 'hypothetical protein:chromosome partitioning protein ParA', 'Inter-feature', '100%', '1:-1'], 'GTGCGACTCTGCGTCTGCTCGC'], [1011392, 1011413, '-', 2.06e-05, ['MHEI_09740:MHEI_09750', 'amidase:purine nucleoside phosphorylase', 'Inter-feature', '100%', '-1:1'], 'GTGCGATTCTGCGGCTGCTCGC'], [1011430, 1011451, '+', 
TCGC'], [4156457, 4156478, '+', 2.32e-06, ['MYVA_3991:MYVA_3992', 'hypothetical protein:TetR family transcriptional regulator', 'Inter-feature', '100%', '-1:-1'], 'GTGCGATTTCGCGTCTGCTCGG'], [4391943, 4391964, '-', 2.69e-07, ['MYVA_4213:MYVA_4214', 'peptide ABC transporter ATP-binding protein:hypothetical protein', 'Inter-feature', '100%', '1:1'], 'GTGCGATTTTGCGTCTGCTCGC'], [4391981, 4392002, '+', 2.04e-05, ['MYVA_4213:MYVA_4214', 'peptide ABC transporter ATP-binding protein:hypothetical protein', 'Inter-feature', '100%', '1:1'], 'GGGCGATTTCGCGTCTGTTCGC'], [4550144, 4550165, '-', 8.84e-07, ['MYVA_4364:MYVA_4365', 'fasciclin:acyl-CoA dehydrogenase', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTTTGTGTCTGCTCGC'], [4550182, 4550203, '+', 2.54e-06, ['MYVA_4364:MYVA_4365', 'fasciclin:acyl-CoA dehydrogenase', 'Inter-feature', '100%', '1:-1'], 'GGGCGATTTTGTGTCTGCTCGG'], [4556131, 4556152, '-', 4.05e-05, ['MYVA_4369:MYVA_4370', 'membrane protein:DoxX family protein', 'Inter-feature', '100%', '-1:-1'], 'ATGCGATTTTGTGTCTGTTCGC'], [4556169, 4556190, '+', 3.84e-07, ['MYVA_4369:MYVA_4370', 'membrane protein:DoxX family protein', 'Inter-feature', '100%', '-1:-1'], 'GTGCGAGTTTGCGTCTGCTCGC'], [5112327, 5112348, '-', 3.84e-07, ['MYVA_4895:MYVA_4897', 'acetyl-CoA acetyltransferase:1,2-oxophytodienoate reductase', 'Inter-feature', '100%', '-1:-1'], 'GTGCGAGTTTGCGTCTGCTCGC'], [5497850, 5497871, '-', 1.29e-06, ['MYVA_5272:MYVA_5273', 'inorganic pyrophosphatase:OHCU decarboxylase', 'Inter-feature', '100%', '1:1'], 'GTGCGAGTTCGCGTCTGCTCGC'], [5497888, 5497909, '+', 1.05e-06, ['MYVA_5272:MYVA_5273', 'inorganic pyrophosphatase:OHCU decarboxylase', 'Inter-feature', '100%', '1:1'], 'GTGCGAGTTTGTGTCTGCTCGC'], [5581711, 5581732, '-', 3.84e-07, ['MYVA_5353:MYVA_5354', 'hypothetical protein:hypothetical protein', 'Inter-feature', '100%', '1:1'], 'GTGCGAGTTTGCGTCTGCTCGC'], [5581749, 5581770, '+', 1.05e-06, ['MYVA_5353:MYVA_5354', 'hypothetical protein:hypothetical protein', 'Inter-feature', '100%', '1:1'], 'GTGCGAGTTTGTGTCTGCTCGC'], [5582762, 5582783, '-', 3.84e-07, ['MYVA_5354:MYVA_5355', 'hypothetical protein:membrane protein ...
], [481635, 481656, '+', 3.97e-06, ['SAMEA4434518_00452:SAMEA4434518_00453', 'isocitrate lyase:3-hydroxybutyryl-CoA dehydrogenase', 'Inter-feature', '100%', '1:1'], 'GTGCGAATTTGTGTCTGCTCGC'], [556748, 556769, '-', 8.38e-07, ['SAMEA4434518_00518', 'ResB-family protein', 'CDS', '100%', '1'], 'GTGCGATTCCGCGTCTGCTCGC'], [556786, 556807, '+', 8.38e-07, ['SAMEA4434518_00518', 'ResB-family protein', 'CDS', '100%', '1'], 'GTGCGATTCCGCGTCTGCTCGC'], [716315, 716336, '-', 5.5e-05, ['SAMEA4434518_00669:SAMEA4434518_00670', "DNA-directed RNA polymerase subunit beta':CBS domain-containing protein", 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTCGCGACTGCTCGC'], [913862, 913883, '-', 2.69e-07, ['SAMEA4434518_00862:SAMEA4434518_00863', 'succinyl-CoA synthetase SucD:thiolase', 'Inter-feature', '100%', '1:1'], 'GTGCGATTCTGCGTCTGCTCGC'], [913900, 913921, '+', 8.38e-07, ['SAMEA4434518_00862:SAMEA4434518_00863', 'succinyl-CoA synthetase SucD:thiolase', 'Inter-feature', '100%', '1:1'], 'GCGCGATTCTGCGTCTGCTCGC'], [991392, 991413, '-', 8.57e-06, ['SAMEA4434518_00941:SAMEA4434518_00942', 'polyketide synthase:peptidyl-tRNA hydrolase Pth', 'Inter-feature', '100%', '1:-1'], 'ACGCGATTCTGTGTCTGCTCGC'], [991430, 991451, '+', 1.2e-06, ['SAMEA4434518_00941:SAMEA4434518_00942', 'polyketide synthase:peptidyl-tRNA hydrolase Pth', 'Inter-feature', '100%', '1:-1'], 'GTGCGAGTCTGTGTCTGCTCGC'], [1126488, 1126509, '-', 2.69e-07, ['SAMEA4434518_01071:SAMEA4434518_01072', 'Uncharacterised protein:5-methyltetrahydropteroyltriglutamate-- homocysteine S-methyltransferase', 'Inter-feature', '100%', '1:-1'], 'GTGCGATTCTGCGTCTGCTCGC'], [1126526, 1126547, '+', 2.86e-06, ['SAMEA4434518_01071:SAMEA4434518_01072', 'Uncharacterised protein:5-methyltetrahydropteroyltriglutamate-- homocysteine S-methyltransfera ...
# ...
# AP022562.1 [[113183, 113204, '-', 1.72e-05, ['MNVM_01140:MNVM_01150', 'dihydroorotate dehydrogenase (quinone):UPF0098 protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGTGTCTGCTCGC'], [113221, 113242, '+', 5.95e-05, ['MNVM_01140:MNVM_01150', 'dihydroorotate dehydrogenase (quinone):UPF0098 protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTGGC'], [415281, 415302, '-', 5.5e-05, ['MNVM_03890:MNVM_03900', '30S ribosomal protein S20:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [579421, 579442, '-', 6.68e-06, ['MNVM_05250:MNVM_05260', 'peptidase:glycogen phosphorylase', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [579459, 579480, '+', 6.09e-05, ['MNVM_05250:MNVM_05260', 'peptidase:glycogen phosphorylase', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTCAC'], [586781, 586802, '+', 5.5e-05, ['MNVM_05290:MNVM_05300', 'hypothetical protein:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [695538, 695559, '+', 6.68e-06, ['MNVM_06220:MNVM_06230', 'magnesium transport protein CorA:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [728426, 728447, '-', 6.7e-05, ['MNVM_06550', 'succinyl-diaminopimelate desuccinylase', 'CDS', '100%', '-1'], 'GGGGGCTTTCACGTCTGCTCGC'], [823499, 823520, '-', 9.04e-05, ['MNVM_07480:MNVM_07490', '5-methyltetrahydropteroyltriglutamate-- homocysteine methyltransferase:enoyl-CoA hydratase', 'Inter-feature', '100%', '1:1'], 'GGGGGCGTTCGCGACTGCTCGC'], [1017529, 1017550, '-', 6.68e-06, ['MNVM_09420:MNVM_09430', 'acetyl-CoA acetyltransferase:succinate--CoA ligase [ADP-forming] subunit alpha', 'Inter-feature', '100%', '-1:-1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [1136117, 1136138, '-', 6.68e-06, ['MNVM_10570:MNVM_10580', 'hypothetical protein:fatty oxidation protein FadB', 'Inter-feature', '100%', '-1:-1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [1268057, 1268078, '-', 5.23e-05, ['MNVM_11660:MNVM_11670', 'hydroxymycolate synthase MmaA4:50S ribosomal protein L1', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTTGCGACTGCTCGG'], [1404404, 1404425, '+', 8.04e-05, ['MNVM_12970', 'cytochrome c biogenesis protein', 'CDS', '100%', '-1'], 'GGGGGCTTTGGTGTCTGCTCGC'], [1719044, 1719065, '-', 6.7e-05, ['MNVM_15930:MNVM_15940', 'acyl-CoA dehydrogenase:putative transcriptional regulator, AraC family protein', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTCACGTCTGCTCGC'], [2282376, 2282397, '-', 6.22e-06, ['MNVM_21110', 'membrane protein', 'CDS', '100%', '-1'], 'GGGGGCTTTTGCGTCTGCTCGG'], [2408057, 2408078, '+', 5.5e-05, ['MNVM_22260:MNVM_22270', 'membrane protein:membrane protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [2425908, 2425929, '+', 6.16e-05, ['MNVM_22440:MNVM_22450', 'MBL fold metallo-hydrolase:Crp/Fnr family transcriptional regulator', 'Inter-feature', '100%', '1:-1'], 'AGGGGCTTTCGCGTCTGCTCGG'], [2607820, 2607841, '+', 5.95e-05, ['MNVM_24060:MNVM_24070', 'sulfotransferase family protein:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTGGC'], [2774022, 2774043, '+', 9e-05, ['MNVM_25710:MNVM_25720', 'acyl-CoA dehydrogenase:acyl-CoA dehydrogenase', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTGGCGTCTGCTCGG'], [2868221, 2868242, '-', 6.7e-05, ['MNVM_26670:MNVM_26680', '3-oxoacyl-[acyl-carrier-protein] reductase:acetyl-CoA acetyltransferase', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTCACGTCTGCTCGC'], [2903415, 2903436, '-', 5.5e-05, ['MNVM_27030:MNVM_27040', 'amidohydrolase:acetyl-CoA acetyltransferase', 'Inter-feature', '100%', '-1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [3360408, 3360429, '-', 4.02e-05, ['MNVM_31520:MNVM_31530', 'NADH pyrophosphatase:NrdH-redoxin', 'Inter-feature', '100%', '1:-1'], 'GGGCGCTTTGGTGTCTGCTCGC'], [3360446, 3360467, '+', 8.04e-05, ['MNVM_31520:MNVM_31530', 'NADH pyrophosphatase:NrdH-redoxin', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTGGTGTCTGCTCGC'], [3518126, 3518147, '+', 1.98e-05, ['MNVM_33010', 'putative transcriptional regulator,  ...
# CP002329.1 [[238813, 238834, '+', 6.7e-05, ['JDM601_0228:JDM601_0229', 'AraC family transcriptional regulatory protein:acyl-CoA dehydrogenase FadE5', 'Inter-feature', '100%', '-1:-1'], 'GGGGGCTTTCACGTCTGCTCGC'], [445883, 445904, '-', 5.5e-05, ['JDM601_0425:JDM601_0426', 'hypothetical protein:conserved hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [552980, 553001, '-', 8.04e-05, ['JDM601_0525:JDM601_0526', 'cytochrome C-type biogenesis protein CcsA:ResB-family protein', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTGGTGTCTGCTCGC'], [850281, 850302, '+', 6.68e-06, ['JDM601_0785:JDM601_0786', 'fatty oxidation protein FadB:hypothetical protein', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [969031, 969052, '+', 6.68e-06, ['JDM601_0898:JDM601_0899', 'succinyl-CoA synthetase (alpha chain) SucD:thiolase', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [1160891, 1160912, '+', 9.04e-05, ['JDM601_1086:JDM601_1087', 'enoyl-CoA hydratase:5-methyltetrahydropteroyltriglutamate-- homocysteine methyltransferase MetE', 'Inter-feature', '100%', '-1:-1'], 'GGGGGCGTTCGCGACTGCTCGC'], [1254515, 1254536, '+', 6.7e-05, ['JDM601_1177:JDM601_1178', 'transferase:succinyl-diaminopimelate desuccinylase DapE', 'Inter-feature', '100%', '-1:1'], 'GGGGGCTTTCACGTCTGCTCGC'], [1287406, 1287427, '-', 6.68e-06, ['JDM601_1210:JDM601_1211', 'conserved hypothetical protein:magnesium and cobalt transport transmembrane protein CorA', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [1418882, 1418903, '-', 5.5e-05, ['JDM601_1327:JDM601_1328', 'thioredoxin:14-alpha-glucan branching enzyme GlgB', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [1426128, 1426149, '-', 6.09e-05, ['JDM601_1330:JDM601_1331', 'glycogen phosphorylase GlgP:lipoprotein peptidase LpqM', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTCAC'], [1426166, 1426187, '+', 6.68e-06, ['JDM601_1330:JDM601_1331', 'glycogen phosphorylase GlgP:lipoprotein peptidase LpqM', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [1624797, 1624818, '+', 5.5e-05, ['JDM601_1502:JDM601_1503', 'DNA polymerase III delta subunit HolA:30S ribosomal protein S20 RpsT', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [1913965, 1913986, '-', 5.95e-05, ['JDM601_1755:JDM601_1756', 'conserved hypothetical protein:dihydroorotate dehydrogenase PyrD', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTGGC'], [1914003, 1914024, '+', 1.72e-05, ['JDM601_1755:JDM601_1756', 'conserved hypothetical protein:dihydroorotate dehydrogenase PyrD', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGTGTCTGCTCGC'], [2096271, 2096292, '+', 9.29e-05, ['JDM601_1925:JDM601_1926', 'regulatory protein:glycine dehydrogenase GcvB', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTCGCGTCTGTTCGC'], [2429124, 2429145, '-', 5.5e-05, ['JDM601_2233:JDM601_2234', 'membrane protein:conserved hypothetical protein', 'Inter-feature', '100%', '-1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [2573108, 2573129, '-', 5.5e-05, ['JDM601_2369:JDM601_2370', 'peptidyl-prolyl cis-trans isomerase B PpiB:GTP pyrophosphokinase RelA', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGACTGCTCGC'], [2593330, 2593351, '-', 6.68e-06, ['JDM601_2390:JDM601_2391', 'conserved hypothetical protein:NADP-dependent alcohol dehydrogenase AdhC', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTCGC'], [2630257, 2630278, '+', 2.41e-05, ['JDM601_2430:JDM601_2431', 'arsenic-transport integral membrane protein ArsB1:SAM-dependent methyltransferase', 'Inter-feature', '100%', '1:-1'], 'AGGGGCTTTCGCGTCTGCTCGC'], [2886059, 2886080, '-', 1.98e-05, ['JDM601_2701:JDM601_2702', 'conserved hypothetical protein:amidase', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTCGCGTCTGCTCGG'], [2930884, 2930905, '-', 1.98e-05, ['JDM601_2747', 'transcriptional regulatory protein', 'CDS', '100%', '-1'], 'GGGGGCTTTCGCGTCTGCTCGG'], [3117071, 3117092, '-', 8.04e-05, ['JDM601_2913:JDM601_2914', 'glutaredoxin protein:NADH pyrophosph ...
# CP034181.1 [[2686868, 2686889, '+', 1.53e-05, ['EFV83_13565', 'hypothetical protein', 'CDS', '95%', '1'], 'GGGTGCTTTTGCGTCTGCTCGC']]
# AP022610.1 [[1725261, 1725282, '+', 1.63e-05, ['MMAD_16390:MMAD_16400', 'diacylglycerol O-acyltransferase:amidohydrolase', 'Inter-feature', '100%', '1:-1'], 'CGGCGCTTTTGCGTCTGCTCGC'], [2132653, 2132674, '+', 6.54e-05, ['MMAD_20360:MMAD_20370', 'phosphoserine phosphatase SerB:GntR family transcriptional regulator', 'Inter-feature', '100%', '1:-1'], 'GCGCATGTTTGCGTCTGCTCGC'], [4341409, 4341430, '-', 9.35e-05, ['MMAD_41230:MMAD_41240', 'putative transcriptional regulator, TetR family protein:cytochrome P450 130', 'Inter-feature', '100%', '1:1'], 'GCGCAGGTTTGCGTCTGCTCGC'], [5005192, 5005213, '-', 5.75e-05, ['MMAD_47760:MMAD_47770', 'enoyl-CoA hydratase:MFS transporter', 'Inter-feature', '100%', '1:1'], 'GGGGAGTTTTGCGTCTGCTCGC'], [5596152, 5596173, '-', 7e-05, ['MMAD_53540:MMAD_53550', 'phosphoenolpyruvate-protein phosphotransferase:short-chain dehydrogenase', 'Inter-feature', '100%', '1:1'], 'GGGCACATTCGCGTCTGCTCGC']]
# AP022600.1 [[1138507, 1138528, '-', 4.61e-05, ['MTOK_10820:MTOK_10830', 'peptidase M13:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GCCCGAGTTCGCGTCTGCTCGC'], [1410897, 1410918, '-', 1.68e-05, ['MTOK_13510:MTOK_13520', 'UPF0061 protein:hypothetical protein', 'Inter-feature', '100%', '1:-1'], 'GTCCGAGTTCGCGTCTGCTCGC'], [2398629, 2398650, '-', 1.94e-05, ['MTOK_23110:MTOK_23120', 'hypothetical protein:enoyl-CoA hydratase', 'Inter-feature', '100%', '1:-1'], 'ATCCGAGTTTGCGTCTGCTCGC'], [4536502, 4536523, '-', 4.41e-05, ['MTOK_44450:MTOK_44460', 'hypothetical protein:multidrug ABC transporter permease', 'Inter-feature', '100%', '1:-1'], 'GTCCGAGTTCGCGTCTGCTCGG'], [4536540, 4536561, '+', 2.25e-05, ['MTOK_44450:MTOK_44460', 'hypothetical protein:multidrug ABC transporter permease', 'Inter-feature', '100%', '1:-1'], 'GGCCGAGTTCGCGTCTGCTCGC'], [5275565, 5275586, '+', 5.75e-05, ['MTOK_51270:MTOK_51280', 'N-acetyl-gamma-glutamyl-phosphate reductase:phenylalanine--tRNA ligase beta subunit', 'Inter-feature', '100%', '-1:-1'], 'GGCCGAGTTCGCGTCTGCTCGG']]
# CP010271.1 [[1100542, 1100563, '-', 6.32e-05, ['MYCSP_05445:MYCSP_05450', 'serine hydroxymethyltransferase:acyl-ACP desaturase', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTTACGTCTGCTCGG'], [1393559, 1393580, '-', 2.45e-05, ['MYCSP_06855:MYCSP_06860', 'ErfK/YbiS/YcfS/YnhG family protein:coiled-coil structural protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTTACGTCTGCTCGC'], [1393597, 1393618, '+', 2.45e-05, ['MYCSP_06855:MYCSP_06860', 'ErfK/YbiS/YcfS/YnhG family protein:coiled-coil structural protein', 'Inter-feature', '100%', '1:-1'], 'GGGGGCTTTTACGTCTGCTCGC'], [1946343, 1946364, '-', 2.45e-05, ['MYCSP_09525:MYCSP_09530', 'hypothetical protein:ABC transporter permease', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTTACGTCTGCTCGC'], [1946381, 1946402, '+', 2.45e-05, ['MYCSP_09525:MYCSP_09530', 'hypothetical protein:ABC transporter permease', 'Inter-feature', '100%', '1:1'], 'GGGGGCTTTTACGTCTGCTCGC'], [2182456, 2182477, '+', 9.35e-05, ['MYCSP_10725:MYCSP_10730', 'glyoxalase:hypothetical protein', 'Inter-feature', '100%', '-1:-1'], 'GGGGACTTTTACGTCTGCTCGC']]
# AP022590.1 [[4302441, 4302462, '-', 3.16e-05, ['MMAN_39530:MMAN_39540', 'hypothetical protein:hypothetical protein', 'Inter-feature', '100%', '-1:1'], 'GTGGGAGTTTATGTCTGCTCGC']]
# AP022582.1 [[4940397, 4940418, '+', 5e-05, ['MSEO_46030:MSEO_46040', 'isocitrate lyase:3-hydroxybutyryl-CoA dehydrogenase', 'Inter-feature', '100%', '1:1'], 'GTGCGAGTCTGCGTCTACTCGC']]
# AP022605.1 [[602203, 602224, '-', 5.36e-05, ['MDOR_06070:MDOR_06080', "DNA-directed RNA polymerase subunit beta':hypothetical protein", 'Inter-feature', '100%', '1:1'], 'GGGGACATTTGCGTCTGCTCGC'], [603268, 603289, '+', 5.36e-05, ['MDOR_06080:MDOR_06090', 'hypothetical protein:deoxyribonuclease IV', 'Inter-feature', '100%', '1:1'], 'GGGGACATTTGCGTCTGCTCGC']]
# AP022591.1 [[2376388, 2376409, '+', 5.36e-05, ['MCEL_23470:MCEL_23480', "hypothetical protein:DNA-directed RNA polymerase subunit beta'", 'Inter-feature', '100%', '-1:-1'], 'GGGGACATTTGCGTCTGCTCGC']]
# CP062008.1 [[5194077, 5194098, '+', 5.36e-05, ['C1S78_025320:C1S78_025325', 'DUF2339 domain-containing protein:lipid-transfer protein', 'Inter-feature', '100%', '-1:-1'], 'GGGGACATTTGCGTCTGCTCGC']]

# %% [markdown]
# #### Buiild phylo tree

# %%
max_len = len(tb_mycobacteria_rbh['target_species_name'].unique())

# %%
full_ortholog_refs = []
temp = tb_mycobacteria_rbh.groupby('query_ref').agg({'target_ref': "count", 'percent_identical_matches': "min"}).reset_index()
temp = temp.query('target_ref == @max_len and percent_identical_matches > 85')
for i, r in temp.iterrows():
    full_ortholog_refs.append(r['query_ref'])

# %%
def generate_protein_dataset(num_subsets, subset_num, dir_list, seqdir): 
    sequence_dirs = util.chunk_list(dir_list, num_subsets, subset_num)
    all_cds = []
    all_tb_cds = []
    names = []
    sequences = []
    locations = []
    all_cds_nt = []
    all_cds_200_up_nt = []
    for dirname in (sequence_dirs):
        for genome_record in SeqIO.parse(seqdir + '/' + dirname + '/genomic.gbff', "genbank"):
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            names.append([accession_ver, genome_record.annotations['organism']])
            full_sequence = str(genome_record.seq)
            sequences.append([accession_ver, full_sequence])
            for feature in genome_record.features:
                a = feature.qualifiers
                if feature.type == 'CDS' and a.get("translation") != None and a.get("locus_tag") != None:
                    locus_tag = a.get("locus_tag")[0]
                    accession_locus = accession_ver + '@' + locus_tag
                    translation = a.get("translation")[0]
                    (start, stop, strand) = (int(feature.location.start), int(feature.location.end), int(feature.location.strand))
                    if strand == 1:
                        nt_sequence = full_sequence[start: stop]
                        nt_sequence_200_up = full_sequence[start-200: start]
                    else:
                        nt_sequence = util.reverse_complement(full_sequence[start:stop])
                        nt_sequence_200_up = util.reverse_complement(full_sequence[stop:stop+200])
                    locations.append([accession_locus, (start, stop, strand)])
                    all_cds.append([accession_locus, translation])
                    all_cds_nt.append([accession_locus, nt_sequence])
                    all_cds_200_up_nt.append([accession_locus, nt_sequence_200_up])
    return (all_cds, names, locations, sequences, all_cds_nt, all_cds_200_up_nt)

# %%
full_build = True
if full_build == True:
    parallel_output = Parallel(n_jobs=-1)(delayed(generate_protein_dataset)(num_cores, core_number, mycobacteria_dirs, mycobacteria_seq_dir) for core_number in core_numbers)
    protein_dict = {}
    for x in parallel_output:
        for temp in x[0]:
            protein_dict[temp[0]] = temp[1]

# %%
concatenated_alignment_dict = {}
for ref in tqdm(full_ortholog_refs):
    temp_seq = []
    temp = tb_mycobacteria_rbh[tb_mycobacteria_rbh['query_ref'] == ref]
    for i, r in temp.iterrows():
        temp_seq.append([r['target_species_name'].replace(' ','_'),protein_dict[r['target_ref']]])
    util.produce_fasta_file(temp_seq, project_dir +'/temp_seq.fasta')    
    cline = MuscleCommandline(muscle_exe, input= project_dir +'/temp_seq.fasta', out=project_dir +'/temp_seq_alignment.fasta')
    result = cline();    
    alignment = util.read_fasta_to_array(project_dir +'/temp_seq_alignment.fasta')    
    for (name, sequence) in zip(alignment[0], alignment[1]):
        if name in concatenated_alignment_dict:
            temp2 = concatenated_alignment_dict[name]
            concatenated_alignment_dict[name] = temp2 + sequence
        else:
            concatenated_alignment_dict[name] = sequence
temp  = []
for k, v in concatenated_alignment_dict.items():
    temp.append([k, v])
util.produce_fasta_file(temp, project_dir + '/concatenated_alignment.fasta')

# %% [markdown]
# #### Number of motif hits in different species and output so can be merged with R to display info against phylo tree

# %%
names_dict = {}
for dirname in (mycobacteria_dirs):
        for genome_record in SeqIO.parse(mycobacteria_seq_dir + '/' + dirname + '/genomic.gbff', "genbank"):
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            names_dict[accession_ver] = genome_record.annotations['organism']

# %%
hit_info = []
for k, v in hit_dict.items():
    print(names_dict[k], len(v))
    
    
