# %% [markdown]
# ##### Generate files containing all genic and intergenic regions in reference organism

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from Bio import Entrez, SeqIO, AlignIO, pairwise2, Align, Seq, motifs
from Bio.Seq import Seq
from Bio.SeqFeature import SeqFeature, FeatureLocation
from scipy.stats import binom
import math
import time
from tqdm.auto import tqdm
import random
import copy
from joblib import Parallel, delayed
import os
import shutil
import subprocess
from Bio.Blast import NCBIWWW, NCBIXML
from Bio.Align.Applications import MuscleCommandline
import re
import shutil
from Comparative_Analysis import Sequence_Analysis_Routines as sar
from Comparative_Analysis import Utilities as util
from Comparative_Analysis import Alignment as align
from Comparative_Analysis import Blast_Functions as blastfn
from scipy.stats import chi2
project_dir = 'D:/Project_Data/Project_8'
output_dir = project_dir + '/R_Scape_Results_RProtein_Leprae'
datasets_dir = project_dir + '/Datasets'
seq_dir = datasets_dir + '/Actinobacteria_Ref_Rep_Lev_Complete'
num_cores = 16
core_numbers = list(range(1, num_cores+1))
#reference_species = 'NC_000962.3'
reference_species = 'NZ_CP029543.1'
produce_data = False
use_near_regions_only = True
search_region = 'U'

# %%
class Translator:
    def __init__(self):
        self.codon_dict = {}
        with open(datasets_dir + '/Standard_Code.txt', 'r') as f:
       	    for l in f:
                self.codon_dict[str(l[1:4])] = l[5]
    
    def reverse_complement(self, seq_string):
        complement_dict = {'A':'T','C':'G','G':'C','T':'A','N':'N'}
        temp = []
        for char in reversed(seq_string):
            if char in complement_dict:
                temp.append(complement_dict[char])
        else:
                temp.append('A')
        return ''.join(temp)
    
    def translate_sequence(self, input_seq, strand, rf, separate_start_symbol = False, separate_stop_symbol = False):
        output_seq = ''
        if strand == 1:
            seq = input_seq[rf:]
        else:
            seq = self.reverse_complement(input_seq)[rf:]
        for i in range(0,len(seq)-2,3):
            if separate_start_symbol == True and seq[i:(i+3)] in ['ATG','GTG','TTG']:
                output_seq += 'Z'
            elif separate_stop_symbol == True and seq[i:(i+3)] in ['TAG','TGA','TAA']:
                output_seq += 'J'
            else:
                if seq[i:(i+3)] in self.codon_dict:
                    output_seq += self.codon_dict[seq[i:(i+3)]]
                else:
                    output_seq += 'X'
        return output_seq

def list_files(dir):
    r = []
    s = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            if name == '.ipynb_checkpoints':
                pass
            else:
                s.append(name)
    return s

def produce_fasta_file(record_list, output_filename):
    with open(output_filename, 'w',  newline='') as outfile:
        line_length = 60
        for record in tqdm(record_list):
            sequence = record[1]
            lines = []
            sequence_length = len(sequence)
            number_of_lines = math.ceil(sequence_length / line_length)
            lines.append(">" +record[0]+ "\n")
            for i in range(number_of_lines):
                subsequence = sequence[i*line_length:(i+1)*line_length]
                lines.append(subsequence + "\n")
            outfile.write(''.join(lines))

def chunk_list(id_list, num_subsets, subset_num):
    len_ids = len(id_list)
    subset_size = int(len_ids / num_subsets)
    remainder = len_ids % num_subsets
    if subset_num <= remainder:
        ids = id_list[(subset_num - 1) * (subset_size + 1): subset_num * (subset_size + 1)]
    else:
        ids = id_list[len_ids - (num_subsets - (subset_num -1))*subset_size : len_ids - (num_subsets - subset_num)*subset_size]
    return ids


def parse_genome(num_subsets, subset_num, id_list):
    translator = Translator()
    ids = chunk_list(id_list, num_subsets, subset_num)
    temp = []
    for id in ids:
        temp_1 = []
        for genome_record in SeqIO.parse(seq_dir + '/' + id, "genbank"):
            organism_name = genome_record.annotations['organism']
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            organism_accession = organism_name.replace(' ', '_') + '_' + accession_ver
            full_sequence = str(genome_record.seq)            
            if id == filename_dict[reference_species]:
                output = []
                features = []
                genome_record = next(SeqIO.parse(seq_dir + '/' + id, "genbank"))
                organism_name = genome_record.annotations['organism']
                accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
                organism_accession = organism_name.replace(' ', '_') + '_' + accession_ver
                full_sequence = str(genome_record.seq)
                mycobrowser_df = pd.read_csv(datasets_dir+'/Mycobrowser_Release_4.csv')
                for i, r in mycobrowser_df.iterrows():
                    #if r['Feature'] == 'CDS':
                    if 1==1:
                        locus_tag = r['Locus']
                        accession_locus = accession_ver + '@' + locus_tag
                        start = int(r['Start'])-1
                        stop = int(r['Stop'])
                        if r['Strand'] == '+':
                            strand = 1
                        else:
                            strand = -1
                        product = r['Product']
                        translation = translator.translate_sequence(full_sequence[start:stop],strand, 0)[:-1]    #Remove stop codon from translation       
                        temp_1.append([organism_name, accession_ver, accession_locus, start, stop, strand, translation, locus_tag, product])     #Mycobrowser is 1-indexed
            else:
                for feature in genome_record.features:
                    a = feature.qualifiers
                    #if feature.type == 'CDS':
                    if feature.type not in ['source','gene']:
                        if a.get("locus_tag")!= None:
                            locus_tag = a.get("locus_tag")[0]
                            accession_locus = accession_ver + '@' + locus_tag
                            translation =  translator.translate_sequence(full_sequence[int(feature.location.start):int(feature.location.end)],int(feature.location.strand), 0)[:-1] 
                            if a.get("product")!= None:
                                product = a.get("product")[0]
                            else:
                                product = 'Product not in annotation'
                            temp_1.append([organism_name, accession_ver, accession_locus, int(feature.location.start), int(feature.location.end), int(feature.location.strand), translation, locus_tag, product])
            temp.append(temp_1)
    return temp

def generate_full_sequence_file(num_subsets, subset_num, id_list):
    ids = chunk_list(id_list, num_subsets, subset_num)
    reference_list = []
    for species in ids:
        for genome_record in SeqIO.parse(seq_dir + '/' + species, "genbank"):
        	feature_info = []
        	accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
        	reference_list.append([accession_ver, str(genome_record.seq)])
    return reference_list

def create_filename_dict(num_subsets, subset_num, id_list):
    ids = chunk_list(id_list, num_subsets, subset_num)
    temp = []
    for id in (ids):
        for genome_record in SeqIO.parse(seq_dir + '/' + id, "genbank"):
            organism_name = genome_record.annotations['organism']
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            temp.append((accession_ver, id))
    return temp

def create_search_regions(num_subsets, subset_num, data_list, search_region):
    data_subset = chunk_list(data_list, num_subsets, subset_num)
    temp = []
    translator = Translator()
    for (accession, filename, start, stop, strand, e_value) in (data_subset):
        for genome_record in SeqIO.parse(seq_dir + '/' + filename, "genbank"):
            full_sequence = str(genome_record.seq)
            if search_region == 'D':
                if strand == 1:
                    search_sequence = full_sequence[stop: min(len(full_sequence) - 1, stop + 500)]
                else:
                    search_sequence = translator.reverse_complement(full_sequence[max(start-500, 0):start])
            else:
                if strand == 1:
                    search_sequence = full_sequence[max(0, start - 500): start]
                else:
                    search_sequence = translator.reverse_complement(full_sequence[stop: (stop + 500)])
            temp.append((accession+'/'+str(start)+'-'+str(stop), search_sequence))
    return temp

def align_keep_top_hit_per_species(files_dir, hit_file, alignment_file, output_alignment_file, package, evalue = 1e-5): 
    wsl_files_loc = util.wslname(files_dir)
    dict = {}
    if package == 'INFERNAL':
        with open(files_dir + '/' + hit_file, 'r') as f:
            for l in f:
                if not(l[0] == '#'): 
                    a = l.split()
                    accession_id = a[0].split('/')[0]
                    if a[16] == '!':
                        if accession_id in dict:
                            if float(a[15]) < dict[accession_id][1]:
                                dict[accession_id] = (a[0]+'/'+a[7]+'-'+a[8],float(a[15]))
                        else:
                            dict[accession_id] = (a[0]+'/'+a[7]+'-'+a[8],float(a[15]))
    elif package == 'HMMER':
        with open(files_dir + '/' + hit_file, 'r') as f:
            for l in f:
                if not(l[0] == '#'): 
                    a = l.split()
                    accession_id = a[0].split('/')[0]
                    if float(a[12]) < evalue:
                        if a[0] in dict:
                            if float(a[12]) < dict[accession_id][1]:
                                dict[accession_id] = (a[0]+'/'+a[6]+'-'+a[7],float(a[12]))
                        else:
                            dict[accession_id] = (a[0]+'/'+a[6]+'-'+a[7],float(a[12]))
    else:
        pass
    with open(files_dir + '/keep_list.txt', 'w') as f:
        lines = []
        for k, v in dict.items():
            lines.append(v[0] + "\n")
        f.write(''.join(lines))
    subprocess.run('wsl cd ' + wsl_files_loc + ' ; esl-alimanip -o '+output_alignment_file + ' --seq-k keep_list.txt '+ alignment_file, shell=True)
    

def find_features(accession, stop, start):
    output_values = []
    for feature_info in gene_info_dict[accession]:
        start_f = int(feature_info[1])
        stop_f = int(feature_info[2])
        if stop_f - start_f  > 100000:   #Something wrong!
            continue
        start_1 = min(stop, start)
        stop_1 = max(stop, start)
        if stop_1 > start_f and start_1 < stop_f:
            overlap = (min(stop_f, stop_1) - max(start_f, start_1)) / (stop_1 - start_1)
            output_values.append((feature_info, overlap))
    return output_values

# %%
if produce_data == True:
    species_list = list_files(seq_dir)
    species_list = [x for x in species_list if '.gbff' in x]    # Exclude other files generated in directory
    parallel_output = Parallel(n_jobs=-1)(delayed(parse_genome)(num_cores, core_number, species_list) for core_number in core_numbers)
    temp = [item for sublist in parallel_output for item in sublist]
    gene_records = [item for sublist in temp for item in sublist]
    reference_gene_records = [x for x in gene_records if x[1] == reference_species]
    gene_records.sort(key=lambda x: (x[1],x[3]))
    gene_info_dict = {}
    for i, record in enumerate(gene_records):
        if record[1] in gene_info_dict:
            gene_info_dict[record[1]].append((record[7],record[3], record[4], (record[7], record[5]), (record[7], record[5]), (record[8], record[8])))
        else:
            gene_info_dict[record[1]] = [(record[7],record[3], record[4], (record[7], record[5]), (record[7], record[5]), (record[8],record[8]))]
        if (i + 1) < len(gene_records):
            next_feature = gene_records[i+1]
            if next_feature[1] == record[1] and next_feature[3] > record[4]:
                gene_info_dict[record[1]].append((record[7] + '_IG', record[4], next_feature[3], (record[7], record[5]), (next_feature[7], next_feature[5]), (record[8], next_feature[8])))
    with open(output_dir + '/gene_info_dict.pkl', 'wb') as f:
        pickle.dump(gene_info_dict, f)   
    print("Gene info generated")

# %%
if produce_data == True:
    species_list = list_files(seq_dir)
    species_list = [x for x in species_list if '.gbff' in x]    # Exclude other files generated in directory
    parallel_output = Parallel(n_jobs=-1)(delayed(parse_genome)(num_cores, core_number, species_list) for core_number in core_numbers)
    temp = [item for sublist in parallel_output for item in sublist]
    gene_records = [item for sublist in temp for item in sublist]
    reference_gene_records = [x for x in gene_records if x[1] == reference_species]
    gene_records.sort(key=lambda x: (x[1],x[3]))
    
    filename_dict = {}
    parallel_output = Parallel(n_jobs=-1)(delayed(create_filename_dict)(num_cores, core_number, species_list) for core_number in core_numbers)
    temp = [item for sublist in parallel_output for item in sublist]
    for (accession_ver, filename) in temp:
        filename_dict[accession_ver] = filename
    with open(output_dir + '/filename_dict.pkl', 'wb') as f:
        pickle.dump(filename_dict, f)   
    print("Filenames dictionary generated")
    
    
    gene_info_dict = {}
    for i, record in enumerate(gene_records):
        if record[1] in gene_info_dict:
            gene_info_dict[record[1]].append((record[7],record[3], record[4], (record[7], record[5]), (record[7], record[5]), (record[8], record[8])))
        else:
            gene_info_dict[record[1]] = [(record[7],record[3], record[4], (record[7], record[5]), (record[7], record[5]), (record[8],record[8]))]
        if (i + 1) < len(gene_records):
            next_feature = gene_records[i+1]
            if next_feature[1] == record[1] and next_feature[3] > record[4]:
                gene_info_dict[record[1]].append((record[7] + '_IG', record[4], next_feature[3], (record[7], record[5]), (next_feature[7], next_feature[5]), (record[8], next_feature[8])))
    with open(output_dir + '/gene_info_dict.pkl', 'wb') as f:
        pickle.dump(gene_info_dict, f)   
    print("Gene info generated")
    
    names_dict = {}
    for id in tqdm(species_list):
        for genome_record in SeqIO.parse(seq_dir + '/' + id, "genbank"):
            organism_name = genome_record.annotations['organism']
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            if not(accession_ver in names_dict):
                names_dict[accession_ver] = organism_name
    with open(output_dir + '/names_dict.pkl', 'wb') as f:
        pickle.dump(names_dict, f)   
    print("Names dictionary generated")

    parallel_output = Parallel(n_jobs=-1)(delayed(generate_full_sequence_file)(num_cores, core_number, species_list) for core_number in core_numbers)
    temp = [item for sublist in parallel_output for item in sublist]
    gene_records = [[item[0], item[1]] for item in temp]
    produce_fasta_file(gene_records, seq_dir + '/full_sequences.faa') 
    print("Full sequence file generated")

else:
    with open(output_dir + '/gene_info_dict.pkl', 'rb') as f:
        gene_info_dict = pickle.load(f) 
    with open(output_dir + '/names_dict.pkl', 'rb') as f:
        names_dict = pickle.load(f) 
    with open(output_dir + '/filename_dict.pkl', 'rb') as f:
        filename_dict = pickle.load(f) 

genome_record = next(SeqIO.parse(seq_dir + '/' + filename_dict[reference_species], "genbank"))
product_dict = {}
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None and a.get("product")!=None:
            product_dict[a.get("locus_tag")[0]] = a.get("product")[0]

# %%
#  Produce dataset of feature, upstream and downstream info relating to reference    
features = []
translator = Translator()
genome_record = next(SeqIO.parse(seq_dir + '/' + filename_dict[reference_species], "genbank"))
full_sequence = str(genome_record.seq)
mycobrowser_df = pd.read_csv(datasets_dir+'/Mycobrowser_Release_4.csv')

#for i, r in mycobrowser_df.iterrows():
#    if r['Strand'] == '+':
#        strand = 1
#    else:
#        strand = -1
#    features.append([r['Locus'],r['Start']-1, r['Stop'], strand])

for feature in genome_record.features:
    a = feature.qualifiers
    if feature.type not in ['source','gene']:
        if a.get("locus_tag")!= None:
            locus_tag = a.get("locus_tag")[0]
            features.append([locus_tag, int(feature.location.start), int(feature.location.end), int(feature.location.strand)])
features.sort(key=lambda x: x[1])
feature_info = []
for i, feature in enumerate(features):
    if feature[3] == 1:
        feature_sequence = full_sequence[feature[1]: feature[2]]
    else:
        feature_sequence = translator.reverse_complement(full_sequence[feature[1]: feature[2]])
    exception = 1
    #Upstream
    if feature[1] < feature[2]:  
         if feature[3] == 1:
              if i > 0 and feature[1] > features[i-1][2]:
                  exception = 0
                  utr_coords = (features[i-1][2], feature[1])
                  utr_sequence = full_sequence[features[i-1][2]: feature[1]]
                  utr_length = len(utr_sequence)
         else:
              if i + 1 < len(features) and feature[2] < features[i+1][1]:
                  exception = 0
                  utr_coords = (feature[2], features[i+1][1])
                  utr_sequence =  translator.reverse_complement(full_sequence[feature[2]: features[i+1][1]])
                  utr_length = len(utr_sequence)
    if exception == 1:
         utr_coords = (0,0)
         utr_sequence = ''
         utr_length = 0 
    exception = 1    
    #Downstream
    if feature[1] < feature[2]:  
         if feature[3] == 1:
              if i < len(features) - 1 and feature[2] < features[i+1][1]:
                  exception = 0
                  dtr_coords = (feature[2], features[i+1][1])
                  dtr_sequence = full_sequence[feature[2]: features[i+1][1]]
                  dtr_length = len(dtr_sequence)
         else:
              if i > 0 and features[i-1][2] < feature[1]:
                  exception = 0
                  dtr_coords = (features[i-1][2], feature[1])
                  dtr_sequence =  translator.reverse_complement(full_sequence[features[i-1][2]: feature[1]])
                  dtr_length = len(dtr_sequence)
    if exception == 1:
         dtr_coords = (0,0)
         dtr_sequence = ''
         dtr_length = 0

    feature_info.append([feature[0], feature[1], feature[2], feature_sequence, len(feature_sequence), utr_coords[0], utr_coords[1], utr_sequence, utr_length, dtr_coords[0], dtr_coords[1], dtr_sequence, dtr_length])
genic_intergenic_df = pd.DataFrame(feature_info, columns = ['Locus', 'Start' , 'End', 'Sequence', 'Length', 'Upstream_Start' , 'Upstream_End', 'Upstream_Sequence', 'Upstream_Length', 'Downstream_Start' , 'Downstream_End', 'Downstream_Sequence', 'Downstream_Length'])


#RFAM hits 
temp = pd.read_csv(datasets_dir + '/RFAM_Hits_H37Rv_sorted.csv')
temp_out = []
for i, r in temp.iterrows():
    if r['strand'] == '+':
        start = int(r['seq from'])
        end = int(r['seq to'])
        sequ = full_sequence[start: end]
    else:
        start = int(r['seq to'])
        end = int(r['seq from'])
        sequ = translator.reverse_complement(full_sequence[start:end])
    seq_len = len(sequ)
    temp_out.append([str(r['#idx']), 0, 0, '',0,start, end, sequ, seq_len])
rfam_df = pd.DataFrame(temp_out, columns = ['Locus', 'Start' , 'End', 'Sequence', 'Length', 'Upstream_Start' , 'Upstream_End', 'Upstream_Sequence', 'Upstream_Length'])

# %%
ribosomal_proteins = []
for k, v in product_dict.items():
    if 'ibosom' in v:
        ribosomal_proteins.append(k)

# %%
ribosomal_proteins = ['DIJ64_RS06195']

# %%
# Loop 

hmmer_eval =  1e-5
hm_model_file = 'hmm.hmm'
#genic_intergenic_test_df = genic_intergenic_df[genic_intergenic_df['Locus'] == 'Rv0651']
for i, r in genic_intergenic_df.iterrows():
#for i, r in rfam_df.iterrows():
    #if (r['Start'] < 0):  
    if not(r['Locus'] in ribosomal_proteins):
        continue
    if ((search_region == 'D' and r['Downstream_Length'] < 40) or (search_region == 'U' and r['Upstream_Length'] <40)):
        continue
    locus_id = r['Locus']
    print(locus_id)
    results_dir = output_dir + '/' + locus_id
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
 
    if use_near_regions_only == True:
         if r['Length'] < 60:
             continue
         query_file = 'genic_region.faa'
         hmmer_eval =  1e-5
         homolog_hits = []
         sequence_list = [[r['Locus'], r['Sequence']]]
         produce_fasta_file(sequence_list, results_dir + '/' + query_file)
         blastfn.nhmmer_search_sequence(results_dir, query_file, seq_dir, 'full_sequences.faa', 'halign_0.sto', 'houtput.txt', 'hsummary_0.txt', hmmer_eval) 
         if not os.path.exists(results_dir +'/hsummary_0.txt'):
             continue
         align_keep_top_hit_per_species(results_dir, 'hsummary_0.txt', 'halign_0.sto', 'halign_bh_0.sto', 'HMMER', hmmer_eval)
         with open(output_dir + '/' + locus_id + '/hsummary_0.txt', 'r') as f:  
             for l in f:
                 if (not ('#' in l)):
                     a = l.split()
                     accession = a[0]
                     species = names_dict[a[0]]
                     seq_from = int(a[6])
                     seq_to = int(a[7])
                     if a[11] == '+':
                         strand = 1
                     else:
                         strand = -1
                     e_value = float(a[12])
                     start = min(seq_from,seq_to) - 1
                     stop = max(seq_from, seq_to)
                     if e_value < 1e-10:
                         for feature in (find_features(accession, start, stop)):
                             if feature[1] > 0.9 and not (feature[0][0][-2:] == 'IG'):
                                 homolog_hits.append((accession, filename_dict[accession], start, stop, strand, e_value))
                                 break

         parallel_output = Parallel(n_jobs=-1)(delayed(create_search_regions)(num_cores, core_number, homolog_hits, search_region) for core_number in core_numbers)

         temp = [item for sublist in parallel_output for item in sublist]
         if len(temp) < 5:
             continue
         else:
             produce_fasta_file(temp, results_dir + '/search_regions.faa')  

    hmmer_eval =  1e-5
    hmmer_eval_2 = 1e-5
    infernal_eval = 1e-5
    query_file = 'intergenic_region.faa'
    hm_model_file = 'hmm.hmm'
    cm_model_file = 'cm.cm'
    if use_near_regions_only == True:
         comparison_dir = results_dir
         comparison_regions = 'search_regions.faa'
    else:
         comparison_dir = seq_dir
         comparison_regions = 'full_sequences.faa'



    if ((search_region == 'D' and r['Downstream_Length'] >= 40) or (search_region == 'U' and r['Upstream_Length'] >=40)):
        if search_region == 'D':
            sequence_list = [[r['Locus'], r['Downstream_Sequence']]]
        else:
            sequence_list = [[r['Locus'], r['Upstream_Sequence']]]
        produce_fasta_file(sequence_list, results_dir + '/' + query_file)

        blastfn.nhmmer_search_sequence(results_dir, query_file, comparison_dir, comparison_regions, 'align_0.sto', 'output.txt', 'hsummary.txt', hmmer_eval_2) 
        if not os.path.exists(results_dir +'/hsummary.txt'):
            continue
        align_keep_top_hit_per_species(results_dir, 'hsummary.txt', 'align_0.sto', 'align_bh_0.sto', 'HMMER', hmmer_eval)
        for i in range(3):
            blastfn.hmmer_build(results_dir, 'align_bh_'+str(i)+'.sto' ,hm_model_file)
            blastfn.nhmmer_search_model(results_dir, hm_model_file, comparison_dir, comparison_regions, 'align_'+str(i+1)+'.sto', 'output.txt', 'hsummary_'+str(i+1)+'.txt', hmmer_eval_2)      #seq_dir, 'full_sequences.faa'
            if not os.path.exists(results_dir +'/hsummary_'+str(i+1)+'.txt'):
                continue
            align_keep_top_hit_per_species(results_dir, 'hsummary_'+str(i+1)+'.txt', 'align_'+str(i+1)+'.sto', 'align_bh_'+str(i+1)+'.sto', 'HMMER', hmmer_eval_2)
        if not os.path.exists(results_dir +'/align_bh_'+str(i+1)+'.sto'):
                continue
        blastfn.run_rscape(results_dir, 'align_bh_'+str(i+1)+'.sto', 'rscape_1')
    

    e_values = []    
    if os.path.exists(results_dir + '/rscape_1.cov'):
         with open(results_dir +  '/rscape_1.cov', 'r') as f:  
             num_pairs = 0
             for l in f:
                 if (not ('#' in l)):
                     a = l.split()
                     if len(a) > 3 and abs(int(a[2])-int(a[1])) > 3:    # Exclude covarying pairs less than 3 bp apart)
                         e_values.append(float(a[4]))
                         num_pairs +=1
     
    if len(e_values) > 1:

        blastfn.infernal_build_and_calib(results_dir, 'align_bh_3.sto' ,'cm_1.cm', False)
        blastfn.infernal_search(results_dir, 'cm_1.cm', comparison_dir, comparison_regions, 'search_1.sto', 'search_hits_1.txt', 'summary_1.txt', infernal_eval) 
        if os.path.getsize(results_dir + '/search_hits_1.txt') > 1e8:
            continue
        align_keep_top_hit_per_species(results_dir, 'summary_1.txt', 'search_1.sto', 'search_bh_1.sto', 'INFERNAL', infernal_eval)
        blastfn.run_rscape(results_dir, 'search_bh_1.sto', 'rscape_1')
        
       
        #2
        blastfn.infernal_build_and_calib(results_dir, 'rscape_1.cacofold.R2R.sto' ,'cm_2.cm')
        #blastfn.infernal_build_and_calib(results_dir, 'search_bh_1.sto' ,'cm_2.cm')

        blastfn.infernal_search(results_dir, 'cm_2.cm', comparison_dir, comparison_regions, 'search_2.sto', 'search_hits_2.txt', 'summary_2.txt', infernal_eval) 
        if os.path.getsize(results_dir + '/search_hits_2.txt') > 1e8:
            continue
        align_keep_top_hit_per_species(results_dir, 'summary_2.txt', 'search_2.sto', 'search_bh_2.sto', 'INFERNAL', infernal_eval)
        blastfn.run_rscape(results_dir, 'search_bh_2.sto', 'rscape_2')

       #3
    
        blastfn.infernal_build_and_calib(results_dir, 'rscape_2.cacofold.R2R.sto' ,'cm_3.cm')
        #infernal_build_and_calib(results_dir, 'search_bh_2.sto' ,'cm_3.cm')
        blastfn.infernal_search(results_dir, 'cm_3.cm', comparison_dir, comparison_regions, 'search_3.sto', 'search_hits_3.txt', 'summary_3.txt', infernal_eval) 
        if os.path.getsize(results_dir + '/search_hits_3.txt') > 1e8:
            continue
        align_keep_top_hit_per_species(results_dir, 'summary_3.txt', 'search_3.sto', 'search_bh_3.sto', 'INFERNAL', infernal_eval)
        blastfn.run_rscape(results_dir, 'search_bh_3.sto', 'rscape_3')

       #Final

        #blastfn.infernal_build_and_calib(results_dir, 'rscape_3.cacofold.R2R.sto' ,'cm_4.cm')
        #blastfn.infernal_search(results_dir, 'cm_4.cm', comparison_dir, comparison_regions, 'final_search.sto', 'final_search.txt', 'final_summary.txt', infernal_eval)
# Out:
# DIJ64_RS06195
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20404/2090556315.py in <module>
#      45                      stop = max(seq_from, seq_to)
#      46                      if e_value < 1e-10:
# ---> 47                          for feature in (find_features(accession, start, stop)):
#      48                              if feature[1] > 0.9 and not (feature[0][0][-2:] == 'IG'):
#      49                                  homolog_hits.append((accession, filename_dict[accession], start, stop, strand, e_value))
#
# ~\AppData\Local\Temp/ipykernel_20404/821689217.py in find_features(accession, stop, start)
#     200 def find_features(accession, stop, start):
#     201     output_values = []
# --> 202     for feature_info in gene_info_dict[accession]:
#     203         start_f = int(feature_info[1])
#     204         stop_f = int(feature_info[2])
#
# KeyError: 'NZ_CP066061.1'

# %%
gene_info_dict['NZ_CP066060.1']
# Out:
# [('I6I08_RS00005',
#   0,
#   3184721,
#   ('I6I08_RS00005', 1),
#   ('I6I08_RS00005', 1),
#   ('type II toxin-antitoxin system ParD family antitoxin',
#    'type II toxin-antitoxin system ParD family antitoxin')),
#  ('I6I08_RS00005',
#   0,
#   3184721,
#   ('I6I08_RS00005', 1),
#   ('I6I08_RS00005', 1),
#   ('type II toxin-antitoxin system ParD family antitoxin',
#    'type II toxin-antitoxin system ParD family antitoxin')),
#  ('I6I08_RS00010',
#   161,
#   452,
#   ('I6I08_RS00010', 1),
#   ('I6I08_RS00010', 1),
#   ('type II toxin-antitoxin system RelE/ParE family toxin',
#    'type II toxin-antitoxin system RelE/ParE family toxin')),
#  ('I6I08_RS00010',
#   161,
#   452,
#   ('I6I08_RS00010', 1),
#   ('I6I08_RS00010', 1),
#   ('type II toxin-antitoxin system RelE/ParE family toxin',
#    'type II toxin-antitoxin system RelE/ParE family toxin')),
#  ('I6I08_RS00010_IG',
#   452,
#   551,
#   ('I6I08_RS00010', 1),
#   ('I6I08_RS00015', 1),
#   ('type II toxin-antitoxin system RelE/ParE family toxin',
#    'diaminopimelate dehydrogenase')),
#  ('I6I08_RS00015',
#   551,
#   1523,
#   ('I6I08_RS00015', 1),
#   ('I6I08_RS00015', 1),
#   ('diaminopimelate dehydrogenase', 'diaminopimelate dehydrogenase')),
#  ('I6I08_RS00015',
#   551,
#   1523,
#   ('I6I08_RS00015', 1),
#   ('I6I08_RS00015', 1),
#   ('diaminopimelate dehydrogenase', 'diaminopimelate dehydrogenase')),
#  ('I6I08_RS00015_IG',
#   1523,
#   1595,
#   ('I6I08_RS00015', 1),
#   ('I6I08_RS00020', -1),
#   ('diaminopimelate dehydrogenase', 'glycosyltransferase family 2 protein')),
#  ('I6I08_RS00020',
#   1595,
#   2675,
#   ('I6I08_RS00020', -1),
#   ('I6I08_RS00020', -1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS00020',
#   1595,
#   2675,
#   ('I6I08_RS00020', -1),
#   ('I6I08_RS00020', -1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS00020_IG',
#   2675,
#   2818,
#   ('I6I08_RS00020', -1),
#   ('I6I08_RS00025', 1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS00025',
#   2818,
#   3892,
#   ('I6I08_RS00025', 1),
#   ('I6I08_RS00025', 1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS00025',
#   2818,
#   3892,
#   ('I6I08_RS00025', 1),
#   ('I6I08_RS00025', 1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS00030',
#   3888,
#   4941,
#   ('I6I08_RS00030', 1),
#   ('I6I08_RS00030', 1),
#   ('glycosyltransferase', 'glycosyltransferase')),
#  ('I6I08_RS00030',
#   3888,
#   4941,
#   ('I6I08_RS00030', 1),
#   ('I6I08_RS00030', 1),
#   ('glycosyltransferase', 'glycosyltransferase')),
#  ('I6I08_RS00030_IG',
#   4941,
#   5128,
#   ('I6I08_RS00030', 1),
#   ('I6I08_RS00035', -1),
#   ('glycosyltransferase', 'hypothetical protein')),
#  ('I6I08_RS00035',
#   5128,
#   6394,
#   ('I6I08_RS00035', -1),
#   ('I6I08_RS00035', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00035',
#   5128,
#   6394,
#   ('I6I08_RS00035', -1),
#   ('I6I08_RS00035', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00035_IG',
#   6394,
#   6508,
#   ('I6I08_RS00035', -1),
#   ('I6I08_RS00040', -1),
#   ('hypothetical protein', 'chain-length determining protein')),
#  ('I6I08_RS00040',
#   6508,
#   7168,
#   ('I6I08_RS00040', -1),
#   ('I6I08_RS00040', -1),
#   ('chain-length determining protein', 'chain-length determining protein')),
#  ('I6I08_RS00040',
#   6508,
#   7168,
#   ('I6I08_RS00040', -1),
#   ('I6I08_RS00040', -1),
#   ('chain-length determining protein', 'chain-length determining protein')),
#  ('I6I08_RS00040_IG',
#   7168,
#   7410,
#   ('I6I08_RS00040', -1),
#   ('I6I08_RS00045', -1),
#   ('chain-length determining protein',
#    'TetR/AcrR family transcriptional regulator')),
#  ('I6I08_RS00045',
#   7410,
#   8193,
#   ('I6I08_RS00045', -1),
#   ('I6I08_RS00045', -1),
#   ('TetR/AcrR family transcriptional regulator',
#    'TetR/AcrR family transcriptional regulator')),
#  ('I6I08_RS00045',
#   7410,
#   8193,
#   ('I6I08_RS00045', -1),
#   ('I6I08_RS00045', -1),
#   ('TetR/AcrR family transcriptional regulator',
#    'TetR/AcrR family transcriptional regulator')),
#  ('I6I08_RS00045_IG',
#   8193,
#   8197,
#   ('I6I08_RS00045', -1),
#   ('I6I08_RS00050', -1),
#   ('TetR/AcrR family transcriptional regulator', 'acyltransferase')),
#  ('I6I08_RS00050',
#   8197,
#   9418,
#   ('I6I08_RS00050', -1),
#   ('I6I08_RS00050', -1),
#   ('acyltransferase', 'acyltransferase')),
#  ('I6I08_RS00050',
#   8197,
#   9418,
#   ('I6I08_RS00050', -1),
#   ('I6I08_RS00050', -1),
#   ('acyltransferase', 'acyltransferase')),
#  ('I6I08_RS00050_IG',
#   9418,
#   9913,
#   ('I6I08_RS00050', -1),
#   ('I6I08_RS00060', 1),
#   ('acyltransferase', 'NTP transferase domain-containing protein')),
#  ('I6I08_RS00060',
#   9913,
#   10906,
#   ('I6I08_RS00060', 1),
#   ('I6I08_RS00060', 1),
#   ('NTP transferase domain-containing protein',
#    'NTP transferase domain-containing protein')),
#  ('I6I08_RS00060',
#   9913,
#   10906,
#   ('I6I08_RS00060', 1),
#   ('I6I08_RS00060', 1),
#   ('NTP transferase domain-containing protein',
#    'NTP transferase domain-containing protein')),
#  ('I6I08_RS00060_IG',
#   10906,
#   11043,
#   ('I6I08_RS00060', 1),
#   ('I6I08_RS00065', 1),
#   ('NTP transferase domain-containing protein',
#    'ribose-phosphate diphosphokinase')),
#  ('I6I08_RS00065',
#   11043,
#   12036,
#   ('I6I08_RS00065', 1),
#   ('I6I08_RS00065', 1),
#   ('ribose-phosphate diphosphokinase', 'ribose-phosphate diphosphokinase')),
#  ('I6I08_RS00065',
#   11043,
#   12036,
#   ('I6I08_RS00065', 1),
#   ('I6I08_RS00065', 1),
#   ('ribose-phosphate diphosphokinase', 'ribose-phosphate diphosphokinase')),
#  ('I6I08_RS00065_IG',
#   12036,
#   12453,
#   ('I6I08_RS00065', 1),
#   ('I6I08_RS00070', 1),
#   ('ribose-phosphate diphosphokinase', 'hypothetical protein')),
#  ('I6I08_RS00070',
#   12453,
#   14382,
#   ('I6I08_RS00070', 1),
#   ('I6I08_RS00070', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00070',
#   12453,
#   14382,
#   ('I6I08_RS00070', 1),
#   ('I6I08_RS00070', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00070_IG',
#   14382,
#   14499,
#   ('I6I08_RS00070', 1),
#   ('I6I08_RS00075', -1),
#   ('hypothetical protein', 'chain-length determining protein')),
#  ('I6I08_RS00075',
#   14499,
#   16746,
#   ('I6I08_RS00075', -1),
#   ('I6I08_RS00075', -1),
#   ('chain-length determining protein', 'chain-length determining protein')),
#  ('I6I08_RS00075',
#   14499,
#   16746,
#   ('I6I08_RS00075', -1),
#   ('I6I08_RS00075', -1),
#   ('chain-length determining protein', 'chain-length determining protein')),
#  ('I6I08_RS00075_IG',
#   16746,
#   17254,
#   ('I6I08_RS00075', -1),
#   ('I6I08_RS00080', 1),
#   ('chain-length determining protein', 'hypothetical protein')),
#  ('I6I08_RS00080',
#   17254,
#   18607,
#   ('I6I08_RS00080', 1),
#   ('I6I08_RS00080', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00080',
#   17254,
#   18607,
#   ('I6I08_RS00080', 1),
#   ('I6I08_RS00080', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00080_IG',
#   18607,
#   18765,
#   ('I6I08_RS00080', 1),
#   ('I6I08_RS00085', 1),
#   ('hypothetical protein', 'FRG domain-containing protein')),
#  ('I6I08_RS00085',
#   18765,
#   19794,
#   ('I6I08_RS00085', 1),
#   ('I6I08_RS00085', 1),
#   ('FRG domain-containing protein', 'FRG domain-containing protein')),
#  ('I6I08_RS00085',
#   18765,
#   19794,
#   ('I6I08_RS00085', 1),
#   ('I6I08_RS00085', 1),
#   ('FRG domain-containing protein', 'FRG domain-containing protein')),
#  ('I6I08_RS00085_IG',
#   19794,
#   19923,
#   ('I6I08_RS00085', 1),
#   ('I6I08_RS00090', 1),
#   ('FRG domain-containing protein', 'transcription-repair coupling factor')),
#  ('I6I08_RS00090',
#   19923,
#   23673,
#   ('I6I08_RS00090', 1),
#   ('I6I08_RS00090', 1),
#   ('transcription-repair coupling factor',
#    'transcription-repair coupling factor')),
#  ('I6I08_RS00090',
#   19923,
#   23673,
#   ('I6I08_RS00090', 1),
#   ('I6I08_RS00090', 1),
#   ('transcription-repair coupling factor',
#    'transcription-repair coupling factor')),
#  ('I6I08_RS00090_IG',
#   23673,
#   23707,
#   ('I6I08_RS00090', 1),
#   ('I6I08_RS00095', -1),
#   ('transcription-repair coupling factor',
#    'ABC transporter ATP-binding protein')),
#  ('I6I08_RS00095',
#   23707,
#   24385,
#   ('I6I08_RS00095', -1),
#   ('I6I08_RS00095', -1),
#   ('ABC transporter ATP-binding protein',
#    'ABC transporter ATP-binding protein')),
#  ('I6I08_RS00095',
#   23707,
#   24385,
#   ('I6I08_RS00095', -1),
#   ('I6I08_RS00095', -1),
#   ('ABC transporter ATP-binding protein',
#    'ABC transporter ATP-binding protein')),
#  ('I6I08_RS00100',
#   24381,
#   25473,
#   ('I6I08_RS00100', -1),
#   ('I6I08_RS00100', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00100',
#   24381,
#   25473,
#   ('I6I08_RS00100', -1),
#   ('I6I08_RS00100', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00105',
#   25469,
#   25925,
#   ('I6I08_RS00105', -1),
#   ('I6I08_RS00105', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00105',
#   25469,
#   25925,
#   ('I6I08_RS00105', -1),
#   ('I6I08_RS00105', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00105_IG',
#   25925,
#   26904,
#   ('I6I08_RS00105', -1),
#   ('I6I08_RS00110', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00110',
#   26904,
#   27792,
#   ('I6I08_RS00110', 1),
#   ('I6I08_RS00110', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00110',
#   26904,
#   27792,
#   ('I6I08_RS00110', 1),
#   ('I6I08_RS00110', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00110_IG',
#   27792,
#   28001,
#   ('I6I08_RS00110', 1),
#   ('I6I08_RS00115', 1),
#   ('hypothetical protein', 'phosphopyruvate hydratase')),
#  ('I6I08_RS00115',
#   28001,
#   29288,
#   ('I6I08_RS00115', 1),
#   ('I6I08_RS00115', 1),
#   ('phosphopyruvate hydratase', 'phosphopyruvate hydratase')),
#  ('I6I08_RS00115',
#   28001,
#   29288,
#   ('I6I08_RS00115', 1),
#   ('I6I08_RS00115', 1),
#   ('phosphopyruvate hydratase', 'phosphopyruvate hydratase')),
#  ('I6I08_RS00115_IG',
#   29288,
#   29523,
#   ('I6I08_RS00115', 1),
#   ('I6I08_RS00120', 1),
#   ('phosphopyruvate hydratase', 'septum formation initiator family protein')),
#  ('I6I08_RS00120',
#   29523,
#   30216,
#   ('I6I08_RS00120', 1),
#   ('I6I08_RS00120', 1),
#   ('septum formation initiator family protein',
#    'septum formation initiator family protein')),
#  ('I6I08_RS00120',
#   29523,
#   30216,
#   ('I6I08_RS00120', 1),
#   ('I6I08_RS00120', 1),
#   ('septum formation initiator family protein',
#    'septum formation initiator family protein')),
#  ('I6I08_RS00120_IG',
#   30216,
#   30221,
#   ('I6I08_RS00120', 1),
#   ('I6I08_RS00125', 1),
#   ('septum formation initiator family protein',
#    'DUF501 domain-containing protein')),
#  ('I6I08_RS00125',
#   30221,
#   30728,
#   ('I6I08_RS00125', 1),
#   ('I6I08_RS00125', 1),
#   ('DUF501 domain-containing protein', 'DUF501 domain-containing protein')),
#  ('I6I08_RS00125',
#   30221,
#   30728,
#   ('I6I08_RS00125', 1),
#   ('I6I08_RS00125', 1),
#   ('DUF501 domain-containing protein', 'DUF501 domain-containing protein')),
#  ('I6I08_RS00125_IG',
#   30728,
#   30783,
#   ('I6I08_RS00125', 1),
#   ('I6I08_RS00130', 1),
#   ('DUF501 domain-containing protein', 'exopolyphosphatase')),
#  ('I6I08_RS00130',
#   30783,
#   31809,
#   ('I6I08_RS00130', 1),
#   ('I6I08_RS00130', 1),
#   ('exopolyphosphatase', 'exopolyphosphatase')),
#  ('I6I08_RS00130',
#   30783,
#   31809,
#   ('I6I08_RS00130', 1),
#   ('I6I08_RS00130', 1),
#   ('exopolyphosphatase', 'exopolyphosphatase')),
#  ('I6I08_RS00135',
#   31805,
#   32678,
#   ('I6I08_RS00135', 1),
#   ('I6I08_RS00135', 1),
#   ('type I 3-dehydroquinate dehydratase',
#    'type I 3-dehydroquinate dehydratase')),
#  ('I6I08_RS00135',
#   31805,
#   32678,
#   ('I6I08_RS00135', 1),
#   ('I6I08_RS00135', 1),
#   ('type I 3-dehydroquinate dehydratase',
#    'type I 3-dehydroquinate dehydratase')),
#  ('I6I08_RS00135_IG',
#   32678,
#   32779,
#   ('I6I08_RS00135', 1),
#   ('I6I08_RS00140', -1),
#   ('type I 3-dehydroquinate dehydratase', 'NTP pyrophosphohydrolase')),
#  ('I6I08_RS00140',
#   32779,
#   33277,
#   ('I6I08_RS00140', -1),
#   ('I6I08_RS00140', -1),
#   ('NTP pyrophosphohydrolase', 'NTP pyrophosphohydrolase')),
#  ('I6I08_RS00140',
#   32779,
#   33277,
#   ('I6I08_RS00140', -1),
#   ('I6I08_RS00140', -1),
#   ('NTP pyrophosphohydrolase', 'NTP pyrophosphohydrolase')),
#  ('I6I08_RS00140_IG',
#   33277,
#   33529,
#   ('I6I08_RS00140', -1),
#   ('I6I08_RS00145', 1),
#   ('NTP pyrophosphohydrolase', 'hypothetical protein')),
#  ('I6I08_RS00145',
#   33529,
#   34117,
#   ('I6I08_RS00145', 1),
#   ('I6I08_RS00145', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00145',
#   33529,
#   34117,
#   ('I6I08_RS00145', 1),
#   ('I6I08_RS00145', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00145_IG',
#   34117,
#   34500,
#   ('I6I08_RS00145', 1),
#   ('I6I08_RS00150', 1),
#   ('hypothetical protein',
#    '50S ribosomal protein L25/general stress protein Ctc')),
#  ('I6I08_RS00150',
#   34500,
#   35112,
#   ('I6I08_RS00150', 1),
#   ('I6I08_RS00150', 1),
#   ('50S ribosomal protein L25/general stress protein Ctc',
#    '50S ribosomal protein L25/general stress protein Ctc')),
#  ('I6I08_RS00150',
#   34500,
#   35112,
#   ('I6I08_RS00150', 1),
#   ('I6I08_RS00150', 1),
#   ('50S ribosomal protein L25/general stress protein Ctc',
#    '50S ribosomal protein L25/general stress protein Ctc')),
#  ('I6I08_RS00150_IG',
#   35112,
#   35211,
#   ('I6I08_RS00150', 1),
#   ('I6I08_RS00155', 1),
#   ('50S ribosomal protein L25/general stress protein Ctc',
#    'aminoacyl-tRNA hydrolase')),
#  ('I6I08_RS00155',
#   35211,
#   35814,
#   ('I6I08_RS00155', 1),
#   ('I6I08_RS00155', 1),
#   ('aminoacyl-tRNA hydrolase', 'aminoacyl-tRNA hydrolase')),
#  ('I6I08_RS00155',
#   35211,
#   35814,
#   ('I6I08_RS00155', 1),
#   ('I6I08_RS00155', 1),
#   ('aminoacyl-tRNA hydrolase', 'aminoacyl-tRNA hydrolase')),
#  ('I6I08_RS00155_IG',
#   35814,
#   35824,
#   ('I6I08_RS00155', 1),
#   ('I6I08_RS00160', -1),
#   ('aminoacyl-tRNA hydrolase', 'response regulator transcription factor')),
#  ('I6I08_RS00160',
#   35824,
#   36559,
#   ('I6I08_RS00160', -1),
#   ('I6I08_RS00160', -1),
#   ('response regulator transcription factor',
#    'response regulator transcription factor')),
#  ('I6I08_RS00160',
#   35824,
#   36559,
#   ('I6I08_RS00160', -1),
#   ('I6I08_RS00160', -1),
#   ('response regulator transcription factor',
#    'response regulator transcription factor')),
#  ('I6I08_RS00165',
#   36540,
#   38106,
#   ('I6I08_RS00165', -1),
#   ('I6I08_RS00165', -1),
#   ('histidine kinase', 'histidine kinase')),
#  ('I6I08_RS00165',
#   36540,
#   38106,
#   ('I6I08_RS00165', -1),
#   ('I6I08_RS00165', -1),
#   ('histidine kinase', 'histidine kinase')),
#  ('I6I08_RS00165_IG',
#   38106,
#   38474,
#   ('I6I08_RS00165', -1),
#   ('I6I08_RS00170', -1),
#   ('histidine kinase', 'ABC transporter permease subunit')),
#  ('I6I08_RS00170',
#   38474,
#   39377,
#   ('I6I08_RS00170', -1),
#   ('I6I08_RS00170', -1),
#   ('ABC transporter permease subunit', 'ABC transporter permease subunit')),
#  ('I6I08_RS00170',
#   38474,
#   39377,
#   ('I6I08_RS00170', -1),
#   ('I6I08_RS00170', -1),
#   ('ABC transporter permease subunit', 'ABC transporter permease subunit')),
#  ('I6I08_RS00170_IG',
#   39377,
#   39444,
#   ('I6I08_RS00170', -1),
#   ('I6I08_RS00175', -1),
#   ('ABC transporter permease subunit', 'ABC transporter ATP-binding protein')),
#  ('I6I08_RS00175',
#   39444,
#   40413,
#   ('I6I08_RS00175', -1),
#   ('I6I08_RS00175', -1),
#   ('ABC transporter ATP-binding protein',
#    'ABC transporter ATP-binding protein')),
#  ('I6I08_RS00175',
#   39444,
#   40413,
#   ('I6I08_RS00175', -1),
#   ('I6I08_RS00175', -1),
#   ('ABC transporter ATP-binding protein',
#    'ABC transporter ATP-binding protein')),
#  ('I6I08_RS00175_IG',
#   40413,
#   40847,
#   ('I6I08_RS00175', -1),
#   ('I6I08_RS00180', 1),
#   ('ABC transporter ATP-binding protein',
#    'Bax inhibitor-1/YccA family protein')),
#  ('I6I08_RS00180',
#   40847,
#   41843,
#   ('I6I08_RS00180', 1),
#   ('I6I08_RS00180', 1),
#   ('Bax inhibitor-1/YccA family protein',
#    'Bax inhibitor-1/YccA family protein')),
#  ('I6I08_RS00180',
#   40847,
#   41843,
#   ('I6I08_RS00180', 1),
#   ('I6I08_RS00180', 1),
#   ('Bax inhibitor-1/YccA family protein',
#    'Bax inhibitor-1/YccA family protein')),
#  ('I6I08_RS00180_IG',
#   41843,
#   42059,
#   ('I6I08_RS00180', 1),
#   ('I6I08_RS00185', 1),
#   ('Bax inhibitor-1/YccA family protein',
#    'FKBP-type peptidyl-prolyl cis-trans isomerase')),
#  ('I6I08_RS00185',
#   42059,
#   42467,
#   ('I6I08_RS00185', 1),
#   ('I6I08_RS00185', 1),
#   ('FKBP-type peptidyl-prolyl cis-trans isomerase',
#    'FKBP-type peptidyl-prolyl cis-trans isomerase')),
#  ('I6I08_RS00185',
#   42059,
#   42467,
#   ('I6I08_RS00185', 1),
#   ('I6I08_RS00185', 1),
#   ('FKBP-type peptidyl-prolyl cis-trans isomerase',
#    'FKBP-type peptidyl-prolyl cis-trans isomerase')),
#  ('I6I08_RS00185_IG',
#   42467,
#   42835,
#   ('I6I08_RS00185', 1),
#   ('I6I08_RS00190', 1),
#   ('FKBP-type peptidyl-prolyl cis-trans isomerase',
#    'dihydroxy-acid dehydratase')),
#  ('I6I08_RS00190',
#   42835,
#   44722,
#   ('I6I08_RS00190', 1),
#   ('I6I08_RS00190', 1),
#   ('dihydroxy-acid dehydratase', 'dihydroxy-acid dehydratase')),
#  ('I6I08_RS00190',
#   42835,
#   44722,
#   ('I6I08_RS00190', 1),
#   ('I6I08_RS00190', 1),
#   ('dihydroxy-acid dehydratase', 'dihydroxy-acid dehydratase')),
#  ('I6I08_RS00190_IG',
#   44722,
#   44803,
#   ('I6I08_RS00190', 1),
#   ('I6I08_RS00195', 1),
#   ('dihydroxy-acid dehydratase',
#    'ATP-binding cassette domain-containing protein')),
#  ('I6I08_RS00195',
#   44803,
#   45655,
#   ('I6I08_RS00195', 1),
#   ('I6I08_RS00195', 1),
#   ('ATP-binding cassette domain-containing protein',
#    'ATP-binding cassette domain-containing protein')),
#  ('I6I08_RS00195',
#   44803,
#   45655,
#   ('I6I08_RS00195', 1),
#   ('I6I08_RS00195', 1),
#   ('ATP-binding cassette domain-containing protein',
#    'ATP-binding cassette domain-containing protein')),
#  ('I6I08_RS00200',
#   45651,
#   46602,
#   ('I6I08_RS00200', 1),
#   ('I6I08_RS00200', 1),
#   ('ATP-binding cassette domain-containing protein',
#    'ATP-binding cassette domain-containing protein')),
#  ('I6I08_RS00200',
#   45651,
#   46602,
#   ('I6I08_RS00200', 1),
#   ('I6I08_RS00200', 1),
#   ('ATP-binding cassette domain-containing protein',
#    'ATP-binding cassette domain-containing protein')),
#  ('I6I08_RS00200_IG',
#   46602,
#   46665,
#   ('I6I08_RS00200', 1),
#   ('I6I08_RS00205', 1),
#   ('ATP-binding cassette domain-containing protein',
#    'ABC transporter substrate-binding protein')),
#  ('I6I08_RS00205',
#   46665,
#   48222,
#   ('I6I08_RS00205', 1),
#   ('I6I08_RS00205', 1),
#   ('ABC transporter substrate-binding protein',
#    'ABC transporter substrate-binding protein')),
#  ('I6I08_RS00205',
#   46665,
#   48222,
#   ('I6I08_RS00205', 1),
#   ('I6I08_RS00205', 1),
#   ('ABC transporter substrate-binding protein',
#    'ABC transporter substrate-binding protein')),
#  ('I6I08_RS00205_IG',
#   48222,
#   48227,
#   ('I6I08_RS00205', 1),
#   ('I6I08_RS00210', 1),
#   ('ABC transporter substrate-binding protein',
#    'ABC transporter permease subunit')),
#  ('I6I08_RS00210',
#   48227,
#   49964,
#   ('I6I08_RS00210', 1),
#   ('I6I08_RS00210', 1),
#   ('ABC transporter permease subunit', 'ABC transporter permease subunit')),
#  ('I6I08_RS00210',
#   48227,
#   49964,
#   ('I6I08_RS00210', 1),
#   ('I6I08_RS00210', 1),
#   ('ABC transporter permease subunit', 'ABC transporter permease subunit')),
#  ('I6I08_RS00210_IG',
#   49964,
#   50128,
#   ('I6I08_RS00210', 1),
#   ('I6I08_RS00215', -1),
#   ('ABC transporter permease subunit', 'DUF4242 domain-containing protein')),
#  ('I6I08_RS00215',
#   50128,
#   50662,
#   ('I6I08_RS00215', -1),
#   ('I6I08_RS00215', -1),
#   ('DUF4242 domain-containing protein', 'DUF4242 domain-containing protein')),
#  ('I6I08_RS00215',
#   50128,
#   50662,
#   ('I6I08_RS00215', -1),
#   ('I6I08_RS00215', -1),
#   ('DUF4242 domain-containing protein', 'DUF4242 domain-containing protein')),
#  ('I6I08_RS00215_IG',
#   50662,
#   50816,
#   ('I6I08_RS00215', -1),
#   ('I6I08_RS00220', -1),
#   ('DUF4242 domain-containing protein',
#    'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS00220',
#   50816,
#   51140,
#   ('I6I08_RS00220', -1),
#   ('I6I08_RS00220', -1),
#   ('helix-turn-helix domain-containing protein',
#    'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS00220',
#   50816,
#   51140,
#   ('I6I08_RS00220', -1),
#   ('I6I08_RS00220', -1),
#   ('helix-turn-helix domain-containing protein',
#    'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS00225',
#   51136,
#   51490,
#   ('I6I08_RS00225', -1),
#   ('I6I08_RS00225', -1),
#   ('type II toxin-antitoxin system RelE/ParE family toxin',
#    'type II toxin-antitoxin system RelE/ParE family toxin')),
#  ('I6I08_RS00225',
#   51136,
#   51490,
#   ('I6I08_RS00225', -1),
#   ('I6I08_RS00225', -1),
#   ('type II toxin-antitoxin system RelE/ParE family toxin',
#    'type II toxin-antitoxin system RelE/ParE family toxin')),
#  ('I6I08_RS00225_IG',
#   51490,
#   51643,
#   ('I6I08_RS00225', -1),
#   ('I6I08_RS00230', 1),
#   ('type II toxin-antitoxin system RelE/ParE family toxin',
#    'threonine ammonia-lyase, biosynthetic')),
#  ('I6I08_RS00230',
#   51643,
#   53209,
#   ('I6I08_RS00230', 1),
#   ('I6I08_RS00230', 1),
#   ('threonine ammonia-lyase, biosynthetic',
#    'threonine ammonia-lyase, biosynthetic')),
#  ('I6I08_RS00230',
#   51643,
#   53209,
#   ('I6I08_RS00230', 1),
#   ('I6I08_RS00230', 1),
#   ('threonine ammonia-lyase, biosynthetic',
#    'threonine ammonia-lyase, biosynthetic')),
#  ('I6I08_RS00230_IG',
#   53209,
#   53413,
#   ('I6I08_RS00230', 1),
#   ('I6I08_RS00235', 1),
#   ('threonine ammonia-lyase, biosynthetic',
#    'NAD(P)H-dependent oxidoreductase')),
#  ('I6I08_RS00235',
#   53413,
#   53968,
#   ('I6I08_RS00235', 1),
#   ('I6I08_RS00235', 1),
#   ('NAD(P)H-dependent oxidoreductase', 'NAD(P)H-dependent oxidoreductase')),
#  ('I6I08_RS00235',
#   53413,
#   53968,
#   ('I6I08_RS00235', 1),
#   ('I6I08_RS00235', 1),
#   ('NAD(P)H-dependent oxidoreductase', 'NAD(P)H-dependent oxidoreductase')),
#  ('I6I08_RS00235_IG',
#   53968,
#   54113,
#   ('I6I08_RS00235', 1),
#   ('I6I08_RS00240', 1),
#   ('NAD(P)H-dependent oxidoreductase',
#    'ABC-ATPase domain-containing protein')),
#  ('I6I08_RS00240',
#   54113,
#   56237,
#   ('I6I08_RS00240', 1),
#   ('I6I08_RS00240', 1),
#   ('ABC-ATPase domain-containing protein',
#    'ABC-ATPase domain-containing protein')),
#  ('I6I08_RS00240',
#   54113,
#   56237,
#   ('I6I08_RS00240', 1),
#   ('I6I08_RS00240', 1),
#   ('ABC-ATPase domain-containing protein',
#    'ABC-ATPase domain-containing protein')),
#  ('I6I08_RS00240_IG',
#   56237,
#   56267,
#   ('I6I08_RS00240', 1),
#   ('I6I08_RS00245', 1),
#   ('ABC-ATPase domain-containing protein', 'hypothetical protein')),
#  ('I6I08_RS00245',
#   56267,
#   57218,
#   ('I6I08_RS00245', 1),
#   ('I6I08_RS00245', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00245',
#   56267,
#   57218,
#   ('I6I08_RS00245', 1),
#   ('I6I08_RS00245', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00245_IG',
#   57218,
#   57347,
#   ('I6I08_RS00245', 1),
#   ('I6I08_RS00250', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00250',
#   57347,
#   58076,
#   ('I6I08_RS00250', -1),
#   ('I6I08_RS00250', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00250',
#   57347,
#   58076,
#   ('I6I08_RS00250', -1),
#   ('I6I08_RS00250', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00250_IG',
#   58076,
#   58557,
#   ('I6I08_RS00250', -1),
#   ('I6I08_RS00255', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00255',
#   58557,
#   58995,
#   ('I6I08_RS00255', 1),
#   ('I6I08_RS00255', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00255',
#   58557,
#   58995,
#   ('I6I08_RS00255', 1),
#   ('I6I08_RS00255', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00255_IG',
#   58995,
#   59189,
#   ('I6I08_RS00255', 1),
#   ('I6I08_RS00260', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00260',
#   59189,
#   60452,
#   ('I6I08_RS00260', 1),
#   ('I6I08_RS00260', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00260',
#   59189,
#   60452,
#   ('I6I08_RS00260', 1),
#   ('I6I08_RS00260', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00260_IG',
#   60452,
#   60631,
#   ('I6I08_RS00260', 1),
#   ('I6I08_RS00265', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00265',
#   60631,
#   61126,
#   ('I6I08_RS00265', 1),
#   ('I6I08_RS00265', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00265',
#   60631,
#   61126,
#   ('I6I08_RS00265', 1),
#   ('I6I08_RS00265', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00265_IG',
#   61126,
#   61253,
#   ('I6I08_RS00265', 1),
#   ('I6I08_RS00270', -1),
#   ('hypothetical protein', 'peptide-methionine (S)-S-oxide reductase MsrA')),
#  ('I6I08_RS00270',
#   61253,
#   61970,
#   ('I6I08_RS00270', -1),
#   ('I6I08_RS00270', -1),
#   ('peptide-methionine (S)-S-oxide reductase MsrA',
#    'peptide-methionine (S)-S-oxide reductase MsrA')),
#  ('I6I08_RS00270',
#   61253,
#   61970,
#   ('I6I08_RS00270', -1),
#   ('I6I08_RS00270', -1),
#   ('peptide-methionine (S)-S-oxide reductase MsrA',
#    'peptide-methionine (S)-S-oxide reductase MsrA')),
#  ('I6I08_RS00270_IG',
#   61970,
#   62137,
#   ('I6I08_RS00270', -1),
#   ('I6I08_RS00275', -1),
#   ('peptide-methionine (S)-S-oxide reductase MsrA',
#    'transcription elongation factor GreA')),
#  ('I6I08_RS00275',
#   62137,
#   62623,
#   ('I6I08_RS00275', -1),
#   ('I6I08_RS00275', -1),
#   ('transcription elongation factor GreA',
#    'transcription elongation factor GreA')),
#  ('I6I08_RS00275',
#   62137,
#   62623,
#   ('I6I08_RS00275', -1),
#   ('I6I08_RS00275', -1),
#   ('transcription elongation factor GreA',
#    'transcription elongation factor GreA')),
#  ('I6I08_RS00275_IG',
#   62623,
#   62965,
#   ('I6I08_RS00275', -1),
#   ('I6I08_RS00280', -1),
#   ('transcription elongation factor GreA', 'hemolysin III family protein')),
#  ('I6I08_RS00280',
#   62965,
#   63676,
#   ('I6I08_RS00280', -1),
#   ('I6I08_RS00280', -1),
#   ('hemolysin III family protein', 'hemolysin III family protein')),
#  ('I6I08_RS00280',
#   62965,
#   63676,
#   ('I6I08_RS00280', -1),
#   ('I6I08_RS00280', -1),
#   ('hemolysin III family protein', 'hemolysin III family protein')),
#  ('I6I08_RS00280_IG',
#   63676,
#   64041,
#   ('I6I08_RS00280', -1),
#   ('I6I08_RS00285', 1),
#   ('hemolysin III family protein',
#    'undecaprenyl diphosphate synthase family protein')),
#  ('I6I08_RS00285',
#   64041,
#   64869,
#   ('I6I08_RS00285', 1),
#   ('I6I08_RS00285', 1),
#   ('undecaprenyl diphosphate synthase family protein',
#    'undecaprenyl diphosphate synthase family protein')),
#  ('I6I08_RS00285',
#   64041,
#   64869,
#   ('I6I08_RS00285', 1),
#   ('I6I08_RS00285', 1),
#   ('undecaprenyl diphosphate synthase family protein',
#    'undecaprenyl diphosphate synthase family protein')),
#  ('I6I08_RS00285_IG',
#   64869,
#   65089,
#   ('I6I08_RS00285', 1),
#   ('I6I08_RS00290', -1),
#   ('undecaprenyl diphosphate synthase family protein',
#    'FCD domain-containing protein')),
#  ('I6I08_RS00290',
#   65089,
#   65803,
#   ('I6I08_RS00290', -1),
#   ('I6I08_RS00290', -1),
#   ('FCD domain-containing protein', 'FCD domain-containing protein')),
#  ('I6I08_RS00290',
#   65089,
#   65803,
#   ('I6I08_RS00290', -1),
#   ('I6I08_RS00290', -1),
#   ('FCD domain-containing protein', 'FCD domain-containing protein')),
#  ('I6I08_RS00290_IG',
#   65803,
#   65928,
#   ('I6I08_RS00290', -1),
#   ('I6I08_RS00295', 1),
#   ('FCD domain-containing protein', 'gluconokinase')),
#  ('I6I08_RS00295',
#   65928,
#   66456,
#   ('I6I08_RS00295', 1),
#   ('I6I08_RS00295', 1),
#   ('gluconokinase', 'gluconokinase')),
#  ('I6I08_RS00295',
#   65928,
#   66456,
#   ('I6I08_RS00295', 1),
#   ('I6I08_RS00295', 1),
#   ('gluconokinase', 'gluconokinase')),
#  ('I6I08_RS00295_IG',
#   66456,
#   66596,
#   ('I6I08_RS00295', 1),
#   ('I6I08_RS00300', 1),
#   ('gluconokinase', 'gluconate:H+ symporter')),
#  ('I6I08_RS00300',
#   66596,
#   68009,
#   ('I6I08_RS00300', 1),
#   ('I6I08_RS00300', 1),
#   ('gluconate:H+ symporter', 'gluconate:H+ symporter')),
#  ('I6I08_RS00300',
#   66596,
#   68009,
#   ('I6I08_RS00300', 1),
#   ('I6I08_RS00300', 1),
#   ('gluconate:H+ symporter', 'gluconate:H+ symporter')),
#  ('I6I08_RS00300_IG',
#   68009,
#   68533,
#   ('I6I08_RS00300', 1),
#   ('I6I08_RS00305', 1),
#   ('gluconate:H+ symporter', 'DEAD/DEAH box helicase')),
#  ('I6I08_RS00305',
#   68533,
#   69925,
#   ('I6I08_RS00305', 1),
#   ('I6I08_RS00305', 1),
#   ('DEAD/DEAH box helicase', 'DEAD/DEAH box helicase')),
#  ('I6I08_RS00305',
#   68533,
#   69925,
#   ('I6I08_RS00305', 1),
#   ('I6I08_RS00305', 1),
#   ('DEAD/DEAH box helicase', 'DEAD/DEAH box helicase')),
#  ('I6I08_RS00305_IG',
#   69925,
#   70157,
#   ('I6I08_RS00305', 1),
#   ('I6I08_RS00310', 1),
#   ('DEAD/DEAH box helicase', 'hypothetical protein')),
#  ('I6I08_RS00310',
#   70157,
#   71012,
#   ('I6I08_RS00310', 1),
#   ('I6I08_RS00310', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00310',
#   70157,
#   71012,
#   ('I6I08_RS00310', 1),
#   ('I6I08_RS00310', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00310_IG',
#   71012,
#   71634,
#   ('I6I08_RS00310', 1),
#   ('I6I08_RS00320', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00320',
#   71634,
#   71793,
#   ('I6I08_RS00320', -1),
#   ('I6I08_RS00320', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00320',
#   71634,
#   71793,
#   ('I6I08_RS00320', -1),
#   ('I6I08_RS00320', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00325',
#   71789,
#   72272,
#   ('I6I08_RS00325', -1),
#   ('I6I08_RS00325', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00325',
#   71789,
#   72272,
#   ('I6I08_RS00325', -1),
#   ('I6I08_RS00325', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00330',
#   72271,
#   72643,
#   ('I6I08_RS00330', -1),
#   ('I6I08_RS00330', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00330',
#   72271,
#   72643,
#   ('I6I08_RS00330', -1),
#   ('I6I08_RS00330', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00330_IG',
#   72643,
#   72665,
#   ('I6I08_RS00330', -1),
#   ('I6I08_RS00335', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00335',
#   72665,
#   74135,
#   ('I6I08_RS00335', -1),
#   ('I6I08_RS00335', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00335',
#   72665,
#   74135,
#   ('I6I08_RS00335', -1),
#   ('I6I08_RS00335', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00335_IG',
#   74135,
#   74458,
#   ('I6I08_RS00335', -1),
#   ('I6I08_RS00340', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00340',
#   74458,
#   75055,
#   ('I6I08_RS00340', -1),
#   ('I6I08_RS00340', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00340',
#   74458,
#   75055,
#   ('I6I08_RS00340', -1),
#   ('I6I08_RS00340', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00340_IG',
#   75055,
#   75261,
#   ('I6I08_RS00340', -1),
#   ('I6I08_RS00345', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00345',
#   75261,
#   76032,
#   ('I6I08_RS00345', -1),
#   ('I6I08_RS00345', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00345',
#   75261,
#   76032,
#   ('I6I08_RS00345', -1),
#   ('I6I08_RS00345', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00350',
#   76028,
#   77153,
#   ('I6I08_RS00350', -1),
#   ('I6I08_RS00350', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00350',
#   76028,
#   77153,
#   ('I6I08_RS00350', -1),
#   ('I6I08_RS00350', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00350_IG',
#   77153,
#   77156,
#   ('I6I08_RS00350', -1),
#   ('I6I08_RS00355', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00355',
#   77156,
#   78971,
#   ('I6I08_RS00355', -1),
#   ('I6I08_RS00355', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00355',
#   77156,
#   78971,
#   ('I6I08_RS00355', -1),
#   ('I6I08_RS00355', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00360',
#   78970,
#   83206,
#   ('I6I08_RS00360', -1),
#   ('I6I08_RS00360', -1),
#   ('tape measure protein', 'tape measure protein')),
#  ('I6I08_RS00360',
#   78970,
#   83206,
#   ('I6I08_RS00360', -1),
#   ('I6I08_RS00360', -1),
#   ('tape measure protein', 'tape measure protein')),
#  ('I6I08_RS00360_IG',
#   83206,
#   83255,
#   ('I6I08_RS00360', -1),
#   ('I6I08_RS00365', -1),
#   ('tape measure protein', 'hypothetical protein')),
#  ('I6I08_RS00365',
#   83255,
#   83630,
#   ('I6I08_RS00365', -1),
#   ('I6I08_RS00365', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00365',
#   83255,
#   83630,
#   ('I6I08_RS00365', -1),
#   ('I6I08_RS00365', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00365_IG',
#   83630,
#   83680,
#   ('I6I08_RS00365', -1),
#   ('I6I08_RS00370', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00370',
#   83680,
#   84016,
#   ('I6I08_RS00370', -1),
#   ('I6I08_RS00370', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00370',
#   83680,
#   84016,
#   ('I6I08_RS00370', -1),
#   ('I6I08_RS00370', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00370_IG',
#   84016,
#   84043,
#   ('I6I08_RS00370', -1),
#   ('I6I08_RS00375', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00375',
#   84043,
#   84262,
#   ('I6I08_RS00375', -1),
#   ('I6I08_RS00375', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00375',
#   84043,
#   84262,
#   ('I6I08_RS00375', -1),
#   ('I6I08_RS00375', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00375_IG',
#   84262,
#   84365,
#   ('I6I08_RS00375', -1),
#   ('I6I08_RS00380', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00380',
#   84365,
#   85034,
#   ('I6I08_RS00380', -1),
#   ('I6I08_RS00380', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00380',
#   84365,
#   85034,
#   ('I6I08_RS00380', -1),
#   ('I6I08_RS00380', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00380_IG',
#   85034,
#   85059,
#   ('I6I08_RS00380', -1),
#   ('I6I08_RS00385', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00385',
#   85059,
#   85455,
#   ('I6I08_RS00385', -1),
#   ('I6I08_RS00385', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00385',
#   85059,
#   85455,
#   ('I6I08_RS00385', -1),
#   ('I6I08_RS00385', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00390',
#   85451,
#   85805,
#   ('I6I08_RS00390', -1),
#   ('I6I08_RS00390', -1),
#   ('HK97 gp10 family phage protein', 'HK97 gp10 family phage protein')),
#  ('I6I08_RS00390',
#   85451,
#   85805,
#   ('I6I08_RS00390', -1),
#   ('I6I08_RS00390', -1),
#   ('HK97 gp10 family phage protein', 'HK97 gp10 family phage protein')),
#  ('I6I08_RS00390_IG',
#   85805,
#   85808,
#   ('I6I08_RS00390', -1),
#   ('I6I08_RS00395', -1),
#   ('HK97 gp10 family phage protein', 'hypothetical protein')),
#  ('I6I08_RS00395',
#   85808,
#   86153,
#   ('I6I08_RS00395', -1),
#   ('I6I08_RS00395', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00395',
#   85808,
#   86153,
#   ('I6I08_RS00395', -1),
#   ('I6I08_RS00395', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00400',
#   86149,
#   86719,
#   ('I6I08_RS00400', -1),
#   ('I6I08_RS00400', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00400',
#   86149,
#   86719,
#   ('I6I08_RS00400', -1),
#   ('I6I08_RS00400', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00400_IG',
#   86719,
#   86751,
#   ('I6I08_RS00400', -1),
#   ('I6I08_RS00405', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00405',
#   86751,
#   86961,
#   ('I6I08_RS00405', -1),
#   ('I6I08_RS00405', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00405',
#   86751,
#   86961,
#   ('I6I08_RS00405', -1),
#   ('I6I08_RS00405', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00405_IG',
#   86961,
#   86962,
#   ('I6I08_RS00405', -1),
#   ('I6I08_RS00410', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00410',
#   86962,
#   87814,
#   ('I6I08_RS00410', -1),
#   ('I6I08_RS00410', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00410',
#   86962,
#   87814,
#   ('I6I08_RS00410', -1),
#   ('I6I08_RS00410', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00410_IG',
#   87814,
#   87840,
#   ('I6I08_RS00410', -1),
#   ('I6I08_RS00415', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00415',
#   87840,
#   88440,
#   ('I6I08_RS00415', -1),
#   ('I6I08_RS00415', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00415',
#   87840,
#   88440,
#   ('I6I08_RS00415', -1),
#   ('I6I08_RS00415', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00415_IG',
#   88440,
#   88652,
#   ('I6I08_RS00415', -1),
#   ('I6I08_RS00420', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00420',
#   88652,
#   89912,
#   ('I6I08_RS00420', -1),
#   ('I6I08_RS00420', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00420',
#   88652,
#   89912,
#   ('I6I08_RS00420', -1),
#   ('I6I08_RS00420', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00420_IG',
#   89912,
#   89933,
#   ('I6I08_RS00420', -1),
#   ('I6I08_RS00425', -1),
#   ('hypothetical protein', 'phage portal protein')),
#  ('I6I08_RS00425',
#   89933,
#   91358,
#   ('I6I08_RS00425', -1),
#   ('I6I08_RS00425', -1),
#   ('phage portal protein', 'phage portal protein')),
#  ('I6I08_RS00425',
#   89933,
#   91358,
#   ('I6I08_RS00425', -1),
#   ('I6I08_RS00425', -1),
#   ('phage portal protein', 'phage portal protein')),
#  ('I6I08_RS00425_IG',
#   91358,
#   91366,
#   ('I6I08_RS00425', -1),
#   ('I6I08_RS00430', -1),
#   ('phage portal protein', 'terminase')),
#  ('I6I08_RS00430',
#   91366,
#   93040,
#   ('I6I08_RS00430', -1),
#   ('I6I08_RS00430', -1),
#   ('terminase', 'terminase')),
#  ('I6I08_RS00430',
#   91366,
#   93040,
#   ('I6I08_RS00430', -1),
#   ('I6I08_RS00430', -1),
#   ('terminase', 'terminase')),
#  ('I6I08_RS00430_IG',
#   93040,
#   93058,
#   ('I6I08_RS00430', -1),
#   ('I6I08_RS00435', -1),
#   ('terminase', 'hypothetical protein')),
#  ('I6I08_RS00435',
#   93058,
#   93445,
#   ('I6I08_RS00435', -1),
#   ('I6I08_RS00435', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00435',
#   93058,
#   93445,
#   ('I6I08_RS00435', -1),
#   ('I6I08_RS00435', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00435_IG',
#   93445,
#   93610,
#   ('I6I08_RS00435', -1),
#   ('I6I08_RS00440', 1),
#   ('hypothetical protein', 'DNA primase')),
#  ('I6I08_RS00440',
#   93610,
#   94177,
#   ('I6I08_RS00440', 1),
#   ('I6I08_RS00440', 1),
#   ('DNA primase', 'DNA primase')),
#  ('I6I08_RS00440',
#   93610,
#   94177,
#   ('I6I08_RS00440', 1),
#   ('I6I08_RS00440', 1),
#   ('DNA primase', 'DNA primase')),
#  ('I6I08_RS00440_IG',
#   94177,
#   94487,
#   ('I6I08_RS00440', 1),
#   ('I6I08_RS00445', 1),
#   ('DNA primase', 'hypothetical protein')),
#  ('I6I08_RS00445',
#   94487,
#   94631,
#   ('I6I08_RS00445', 1),
#   ('I6I08_RS00445', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00445',
#   94487,
#   94631,
#   ('I6I08_RS00445', 1),
#   ('I6I08_RS00445', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00445_IG',
#   94631,
#   94848,
#   ('I6I08_RS00445', 1),
#   ('I6I08_RS00450', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00450',
#   94848,
#   95208,
#   ('I6I08_RS00450', 1),
#   ('I6I08_RS00450', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00450',
#   94848,
#   95208,
#   ('I6I08_RS00450', 1),
#   ('I6I08_RS00450', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00450_IG',
#   95208,
#   95279,
#   ('I6I08_RS00450', 1),
#   ('I6I08_RS00455', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00455',
#   95279,
#   95510,
#   ('I6I08_RS00455', -1),
#   ('I6I08_RS00455', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00455',
#   95279,
#   95510,
#   ('I6I08_RS00455', -1),
#   ('I6I08_RS00455', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00460',
#   95506,
#   96343,
#   ('I6I08_RS00460', -1),
#   ('I6I08_RS00460', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00460',
#   95506,
#   96343,
#   ('I6I08_RS00460', -1),
#   ('I6I08_RS00460', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00460_IG',
#   96343,
#   96371,
#   ('I6I08_RS00460', -1),
#   ('I6I08_RS00465', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00465',
#   96371,
#   97769,
#   ('I6I08_RS00465', -1),
#   ('I6I08_RS00465', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00465',
#   96371,
#   97769,
#   ('I6I08_RS00465', -1),
#   ('I6I08_RS00465', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00465_IG',
#   97769,
#   97864,
#   ('I6I08_RS00465', -1),
#   ('I6I08_RS00470', -1),
#   ('hypothetical protein', 'single-stranded DNA-binding protein')),
#  ('I6I08_RS00470',
#   97864,
#   98425,
#   ('I6I08_RS00470', -1),
#   ('I6I08_RS00470', -1),
#   ('single-stranded DNA-binding protein',
#    'single-stranded DNA-binding protein')),
#  ('I6I08_RS00470',
#   97864,
#   98425,
#   ('I6I08_RS00470', -1),
#   ('I6I08_RS00470', -1),
#   ('single-stranded DNA-binding protein',
#    'single-stranded DNA-binding protein')),
#  ('I6I08_RS00470_IG',
#   98425,
#   98500,
#   ('I6I08_RS00470', -1),
#   ('I6I08_RS00475', -1),
#   ('single-stranded DNA-binding protein', 'hypothetical protein')),
#  ('I6I08_RS00475',
#   98500,
#   99088,
#   ('I6I08_RS00475', -1),
#   ('I6I08_RS00475', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00475',
#   98500,
#   99088,
#   ('I6I08_RS00475', -1),
#   ('I6I08_RS00475', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00475_IG',
#   99088,
#   99106,
#   ('I6I08_RS00475', -1),
#   ('I6I08_RS00480', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00480',
#   99106,
#   99511,
#   ('I6I08_RS00480', -1),
#   ('I6I08_RS00480', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00480',
#   99106,
#   99511,
#   ('I6I08_RS00480', -1),
#   ('I6I08_RS00480', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00485',
#   99471,
#   99714,
#   ('I6I08_RS00485', -1),
#   ('I6I08_RS00485', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00485',
#   99471,
#   99714,
#   ('I6I08_RS00485', -1),
#   ('I6I08_RS00485', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00490',
#   99710,
#   100118,
#   ('I6I08_RS00490', -1),
#   ('I6I08_RS00490', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00490',
#   99710,
#   100118,
#   ('I6I08_RS00490', -1),
#   ('I6I08_RS00490', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00495',
#   100114,
#   100405,
#   ('I6I08_RS00495', -1),
#   ('I6I08_RS00495', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00495',
#   100114,
#   100405,
#   ('I6I08_RS00495', -1),
#   ('I6I08_RS00495', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00500',
#   100401,
#   101040,
#   ('I6I08_RS00500', -1),
#   ('I6I08_RS00500', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00500',
#   100401,
#   101040,
#   ('I6I08_RS00500', -1),
#   ('I6I08_RS00500', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00505',
#   101036,
#   101951,
#   ('I6I08_RS00505', -1),
#   ('I6I08_RS00505', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00505',
#   101036,
#   101951,
#   ('I6I08_RS00505', -1),
#   ('I6I08_RS00505', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00510',
#   101947,
#   103789,
#   ('I6I08_RS00510', -1),
#   ('I6I08_RS00510', -1),
#   ('ParB N-terminal domain-containing protein',
#    'ParB N-terminal domain-containing protein')),
#  ('I6I08_RS00510',
#   101947,
#   103789,
#   ('I6I08_RS00510', -1),
#   ('I6I08_RS00510', -1),
#   ('ParB N-terminal domain-containing protein',
#    'ParB N-terminal domain-containing protein')),
#  ('I6I08_RS00510_IG',
#   103789,
#   104584,
#   ('I6I08_RS00510', -1),
#   ('I6I08_RS00515', -1),
#   ('ParB N-terminal domain-containing protein', 'hypothetical protein')),
#  ('I6I08_RS00515',
#   104584,
#   104950,
#   ('I6I08_RS00515', -1),
#   ('I6I08_RS00515', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00515',
#   104584,
#   104950,
#   ('I6I08_RS00515', -1),
#   ('I6I08_RS00515', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00515_IG',
#   104950,
#   105103,
#   ('I6I08_RS00515', -1),
#   ('I6I08_RS00520', -1),
#   ('hypothetical protein', 'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS00520',
#   105103,
#   105358,
#   ('I6I08_RS00520', -1),
#   ('I6I08_RS00520', -1),
#   ('helix-turn-helix domain-containing protein',
#    'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS00520',
#   105103,
#   105358,
#   ('I6I08_RS00520', -1),
#   ('I6I08_RS00520', -1),
#   ('helix-turn-helix domain-containing protein',
#    'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS00525',
#   105354,
#   105648,
#   ('I6I08_RS00525', -1),
#   ('I6I08_RS00525', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00525',
#   105354,
#   105648,
#   ('I6I08_RS00525', -1),
#   ('I6I08_RS00525', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00530',
#   105647,
#   105977,
#   ('I6I08_RS00530', -1),
#   ('I6I08_RS00530', -1),
#   ('helix-turn-helix transcriptional regulator',
#    'helix-turn-helix transcriptional regulator')),
#  ('I6I08_RS00530',
#   105647,
#   105977,
#   ('I6I08_RS00530', -1),
#   ('I6I08_RS00530', -1),
#   ('helix-turn-helix transcriptional regulator',
#    'helix-turn-helix transcriptional regulator')),
#  ('I6I08_RS00530_IG',
#   105977,
#   106058,
#   ('I6I08_RS00530', -1),
#   ('I6I08_RS00535', 1),
#   ('helix-turn-helix transcriptional regulator', 'hypothetical protein')),
#  ('I6I08_RS00535',
#   106058,
#   106562,
#   ('I6I08_RS00535', 1),
#   ('I6I08_RS00535', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00535',
#   106058,
#   106562,
#   ('I6I08_RS00535', 1),
#   ('I6I08_RS00535', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00535_IG',
#   106562,
#   106695,
#   ('I6I08_RS00535', 1),
#   ('I6I08_RS00540', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00540',
#   106695,
#   107130,
#   ('I6I08_RS00540', 1),
#   ('I6I08_RS00540', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00540',
#   106695,
#   107130,
#   ('I6I08_RS00540', 1),
#   ('I6I08_RS00540', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00540_IG',
#   107130,
#   107196,
#   ('I6I08_RS00540', 1),
#   ('I6I08_RS00545', -1),
#   ('hypothetical protein', 'DUF2335 domain-containing protein')),
#  ('I6I08_RS00545',
#   107196,
#   107766,
#   ('I6I08_RS00545', -1),
#   ('I6I08_RS00545', -1),
#   ('DUF2335 domain-containing protein', 'DUF2335 domain-containing protein')),
#  ('I6I08_RS00545',
#   107196,
#   107766,
#   ('I6I08_RS00545', -1),
#   ('I6I08_RS00545', -1),
#   ('DUF2335 domain-containing protein', 'DUF2335 domain-containing protein')),
#  ('I6I08_RS00545_IG',
#   107766,
#   107868,
#   ('I6I08_RS00545', -1),
#   ('I6I08_RS00550', -1),
#   ('DUF2335 domain-containing protein',
#    'tyrosine-type recombinase/integrase')),
#  ('I6I08_RS00550',
#   107868,
#   108888,
#   ('I6I08_RS00550', -1),
#   ('I6I08_RS00550', -1),
#   ('tyrosine-type recombinase/integrase',
#    'tyrosine-type recombinase/integrase')),
#  ('I6I08_RS00550',
#   107868,
#   108888,
#   ('I6I08_RS00550', -1),
#   ('I6I08_RS00550', -1),
#   ('tyrosine-type recombinase/integrase',
#    'tyrosine-type recombinase/integrase')),
#  ('I6I08_RS00550_IG',
#   108888,
#   109512,
#   ('I6I08_RS00550', -1),
#   ('I6I08_RS00560', 1),
#   ('tyrosine-type recombinase/integrase', 'hypothetical protein')),
#  ('I6I08_RS00560',
#   109512,
#   110175,
#   ('I6I08_RS00560', 1),
#   ('I6I08_RS00560', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00560',
#   109512,
#   110175,
#   ('I6I08_RS00560', 1),
#   ('I6I08_RS00560', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS00560_IG',
#   110175,
#   110512,
#   ('I6I08_RS00560', 1),
#   ('I6I08_RS00565', 1),
#   ('hypothetical protein', 'RNA degradosome polyphosphate kinase')),
#  ('I6I08_RS00565',
#   110512,
#   113473,
#   ('I6I08_RS00565', 1),
#   ('I6I08_RS00565', 1),
#   ('RNA degradosome polyphosphate kinase',
#    'RNA degradosome polyphosphate kinase')),
#  ('I6I08_RS00565',
#   110512,
#   113473,
#   ('I6I08_RS00565', 1),
#   ('I6I08_RS00565', 1),
#   ('RNA degradosome polyphosphate kinase',
#    'RNA degradosome polyphosphate kinase')),
#  ('I6I08_RS00565_IG',
#   113473,
#   113485,
#   ('I6I08_RS00565', 1),
#   ('I6I08_RS00570', 1),
#   ('RNA degradosome polyphosphate kinase', 'NUDIX hydrolase')),
#  ('I6I08_RS00570',
#   113485,
#   114514,
#   ('I6I08_RS00570', 1),
#   ('I6I08_RS00570', 1),
#   ('NUDIX hydrolase', 'NUDIX hydrolase')),
#  ('I6I08_RS00570',
#   113485,
#   114514,
#   ('I6I08_RS00570', 1),
#   ('I6I08_RS00570', 1),
#   ('NUDIX hydrolase', 'NUDIX hydrolase')),
#  ('I6I08_RS00570_IG',
#   114514,
#   114526,
#   ('I6I08_RS00570', 1),
# ...
#   ('I6I08_RS01670', 1),
#   ('ABC transporter ATP-binding protein',
#    'ABC transporter ATP-binding protein')),
#  ('I6I08_RS01670',
#   377017,
#   378319,
#   ('I6I08_RS01670', 1),
#   ('I6I08_RS01670', 1),
#   ('ABC transporter ATP-binding protein',
#    'ABC transporter ATP-binding protein')),
#  ('I6I08_RS01670_IG',
#   378319,
#   378346,
#   ('I6I08_RS01670', 1),
#   ('I6I08_RS01675', -1),
#   ('ABC transporter ATP-binding protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS01675',
#   378346,
#   379420,
#   ('I6I08_RS01675', -1),
#   ('I6I08_RS01675', -1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS01675',
#   378346,
#   379420,
#   ('I6I08_RS01675', -1),
#   ('I6I08_RS01675', -1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS01675_IG',
#   379420,
#   379556,
#   ('I6I08_RS01675', -1),
#   ('I6I08_RS01680', -1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS01680',
#   379556,
#   380567,
#   ('I6I08_RS01680', -1),
#   ('I6I08_RS01680', -1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS01680',
#   379556,
#   380567,
#   ('I6I08_RS01680', -1),
#   ('I6I08_RS01680', -1),
#   ('glycosyltransferase family 2 protein',
#    'glycosyltransferase family 2 protein')),
#  ('I6I08_RS01685',
#   380563,
#   381670,
#   ('I6I08_RS01685', -1),
#   ('I6I08_RS01685', -1),
#   ('glycosyltransferase family 4 protein',
#    'glycosyltransferase family 4 protein')),
#  ('I6I08_RS01685',
#   380563,
#   381670,
#   ('I6I08_RS01685', -1),
#   ('I6I08_RS01685', -1),
#   ('glycosyltransferase family 4 protein',
#    'glycosyltransferase family 4 protein')),
#  ('I6I08_RS01685_IG',
#   381670,
#   381843,
#   ('I6I08_RS01685', -1),
#   ('I6I08_RS01690', 1),
#   ('glycosyltransferase family 4 protein',
#    'glycosyltransferase family 4 protein')),
#  ('I6I08_RS01690',
#   381843,
#   382965,
#   ('I6I08_RS01690', 1),
#   ('I6I08_RS01690', 1),
#   ('glycosyltransferase family 4 protein',
#    'glycosyltransferase family 4 protein')),
#  ('I6I08_RS01690',
#   381843,
#   382965,
#   ('I6I08_RS01690', 1),
#   ('I6I08_RS01690', 1),
#   ('glycosyltransferase family 4 protein',
#    'glycosyltransferase family 4 protein')),
#  ('I6I08_RS01690_IG',
#   382965,
#   383113,
#   ('I6I08_RS01690', 1),
#   ('I6I08_RS01695', 1),
#   ('glycosyltransferase family 4 protein', 'NAD(P)-dependent oxidoreductase')),
#  ('I6I08_RS01695',
#   383113,
#   384043,
#   ('I6I08_RS01695', 1),
#   ('I6I08_RS01695', 1),
#   ('NAD(P)-dependent oxidoreductase', 'NAD(P)-dependent oxidoreductase')),
#  ('I6I08_RS01695',
#   383113,
#   384043,
#   ('I6I08_RS01695', 1),
#   ('I6I08_RS01695', 1),
#   ('NAD(P)-dependent oxidoreductase', 'NAD(P)-dependent oxidoreductase')),
#  ('I6I08_RS01695_IG',
#   384043,
#   384097,
#   ('I6I08_RS01695', 1),
#   ('I6I08_RS01700', 1),
#   ('NAD(P)-dependent oxidoreductase', 'DUF2142 domain-containing protein')),
#  ('I6I08_RS01700',
#   384097,
#   385663,
#   ('I6I08_RS01700', 1),
#   ('I6I08_RS01700', 1),
#   ('DUF2142 domain-containing protein', 'DUF2142 domain-containing protein')),
#  ('I6I08_RS01700',
#   384097,
#   385663,
#   ('I6I08_RS01700', 1),
#   ('I6I08_RS01700', 1),
#   ('DUF2142 domain-containing protein', 'DUF2142 domain-containing protein')),
#  ('I6I08_RS01700_IG',
#   385663,
#   385754,
#   ('I6I08_RS01700', 1),
#   ('I6I08_RS01705', -1),
#   ('DUF2142 domain-containing protein',
#    'glucose-1-phosphate thymidylyltransferase RfbA')),
#  ('I6I08_RS01705',
#   385754,
#   386627,
#   ('I6I08_RS01705', -1),
#   ('I6I08_RS01705', -1),
#   ('glucose-1-phosphate thymidylyltransferase RfbA',
#    'glucose-1-phosphate thymidylyltransferase RfbA')),
#  ('I6I08_RS01705',
#   385754,
#   386627,
#   ('I6I08_RS01705', -1),
#   ('I6I08_RS01705', -1),
#   ('glucose-1-phosphate thymidylyltransferase RfbA',
#    'glucose-1-phosphate thymidylyltransferase RfbA')),
#  ('I6I08_RS01705_IG',
#   386627,
#   386830,
#   ('I6I08_RS01705', -1),
#   ('I6I08_RS01710', 1),
#   ('glucose-1-phosphate thymidylyltransferase RfbA',
#    'dTDP-4-dehydrorhamnose 3,5-epimerase')),
#  ('I6I08_RS01710',
#   386830,
#   387412,
#   ('I6I08_RS01710', 1),
#   ('I6I08_RS01710', 1),
#   ('dTDP-4-dehydrorhamnose 3,5-epimerase',
#    'dTDP-4-dehydrorhamnose 3,5-epimerase')),
#  ('I6I08_RS01710',
#   386830,
#   387412,
#   ('I6I08_RS01710', 1),
#   ('I6I08_RS01710', 1),
#   ('dTDP-4-dehydrorhamnose 3,5-epimerase',
#    'dTDP-4-dehydrorhamnose 3,5-epimerase')),
#  ('I6I08_RS01710_IG',
#   387412,
#   387444,
#   ('I6I08_RS01710', 1),
#   ('I6I08_RS01715', 1),
#   ('dTDP-4-dehydrorhamnose 3,5-epimerase',
#    'mannose-6-phosphate isomerase, class I')),
#  ('I6I08_RS01715',
#   387444,
#   388635,
#   ('I6I08_RS01715', 1),
#   ('I6I08_RS01715', 1),
#   ('mannose-6-phosphate isomerase, class I',
#    'mannose-6-phosphate isomerase, class I')),
#  ('I6I08_RS01715',
#   387444,
#   388635,
#   ('I6I08_RS01715', 1),
#   ('I6I08_RS01715', 1),
#   ('mannose-6-phosphate isomerase, class I',
#    'mannose-6-phosphate isomerase, class I')),
#  ('I6I08_RS01715_IG',
#   388635,
#   388667,
#   ('I6I08_RS01715', 1),
#   ('I6I08_RS01720', -1),
#   ('mannose-6-phosphate isomerase, class I', 'hypothetical protein')),
#  ('I6I08_RS01720',
#   388667,
#   389459,
#   ('I6I08_RS01720', -1),
#   ('I6I08_RS01720', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS01720',
#   388667,
#   389459,
#   ('I6I08_RS01720', -1),
#   ('I6I08_RS01720', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS01720_IG',
#   389459,
#   389892,
#   ('I6I08_RS01720', -1),
#   ('I6I08_RS01725', 1),
#   ('hypothetical protein', 'WhiB family transcriptional regulator')),
#  ('I6I08_RS01725',
#   389892,
#   390108,
#   ('I6I08_RS01725', 1),
#   ('I6I08_RS01725', 1),
#   ('WhiB family transcriptional regulator',
#    'WhiB family transcriptional regulator')),
#  ('I6I08_RS01725',
#   389892,
#   390108,
#   ('I6I08_RS01725', 1),
#   ('I6I08_RS01725', 1),
#   ('WhiB family transcriptional regulator',
#    'WhiB family transcriptional regulator')),
#  ('I6I08_RS01730',
#   390104,
#   394154,
#   ('I6I08_RS01730', 1),
#   ('I6I08_RS01730', 1),
#   ('glycosyltransferase', 'glycosyltransferase')),
#  ('I6I08_RS01730',
#   390104,
#   394154,
#   ('I6I08_RS01730', 1),
#   ('I6I08_RS01730', 1),
#   ('glycosyltransferase', 'glycosyltransferase')),
#  ('I6I08_RS01735',
#   394150,
#   396106,
#   ('I6I08_RS01735', 1),
#   ('I6I08_RS01735', 1),
#   ('DUF5719 family protein', 'DUF5719 family protein')),
#  ('I6I08_RS01735',
#   394150,
#   396106,
#   ('I6I08_RS01735', 1),
#   ('I6I08_RS01735', 1),
#   ('DUF5719 family protein', 'DUF5719 family protein')),
#  ('I6I08_RS01735_IG',
#   396106,
#   396136,
#   ('I6I08_RS01735', 1),
#   ('I6I08_RS13310', -1),
#   ('DUF5719 family protein', 'metallopeptidase family protein')),
#  ('I6I08_RS13310',
#   396136,
#   396613,
#   ('I6I08_RS13310', -1),
#   ('I6I08_RS13310', -1),
#   ('metallopeptidase family protein', 'metallopeptidase family protein')),
#  ('I6I08_RS13310',
#   396136,
#   396613,
#   ('I6I08_RS13310', -1),
#   ('I6I08_RS13310', -1),
#   ('metallopeptidase family protein', 'metallopeptidase family protein')),
#  ('I6I08_RS13310_IG',
#   396613,
#   396673,
#   ('I6I08_RS13310', -1),
#   ('I6I08_RS01745', 1),
#   ('metallopeptidase family protein', 'DUF3499 domain-containing protein')),
#  ('I6I08_RS01745',
#   396673,
#   397108,
#   ('I6I08_RS01745', 1),
#   ('I6I08_RS01745', 1),
#   ('DUF3499 domain-containing protein', 'DUF3499 domain-containing protein')),
#  ('I6I08_RS01745',
#   396673,
#   397108,
#   ('I6I08_RS01745', 1),
#   ('I6I08_RS01745', 1),
#   ('DUF3499 domain-containing protein', 'DUF3499 domain-containing protein')),
#  ('I6I08_RS01750',
#   397104,
#   397344,
#   ('I6I08_RS01750', 1),
#   ('I6I08_RS01750', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS01750',
#   397104,
#   397344,
#   ('I6I08_RS01750', 1),
#   ('I6I08_RS01750', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS01750_IG',
#   397344,
#   397402,
#   ('I6I08_RS01750', 1),
#   ('I6I08_RS01755', -1),
#   ('hypothetical protein', 'RDD family protein')),
#  ('I6I08_RS01755',
#   397402,
#   398284,
#   ('I6I08_RS01755', -1),
#   ('I6I08_RS01755', -1),
#   ('RDD family protein', 'RDD family protein')),
#  ('I6I08_RS01755',
#   397402,
#   398284,
#   ('I6I08_RS01755', -1),
#   ('I6I08_RS01755', -1),
#   ('RDD family protein', 'RDD family protein')),
#  ('I6I08_RS01755_IG',
#   398284,
#   398298,
#   ('I6I08_RS01755', -1),
#   ('I6I08_RS01760', 1),
#   ('RDD family protein', 'stage II sporulation protein M')),
#  ('I6I08_RS01760',
#   398298,
#   399294,
#   ('I6I08_RS01760', 1),
#   ('I6I08_RS01760', 1),
#   ('stage II sporulation protein M', 'stage II sporulation protein M')),
#  ('I6I08_RS01760',
#   398298,
#   399294,
#   ('I6I08_RS01760', 1),
#   ('I6I08_RS01760', 1),
#   ('stage II sporulation protein M', 'stage II sporulation protein M')),
#  ('I6I08_RS01760_IG',
#   399294,
#   399317,
#   ('I6I08_RS01760', 1),
#   ('I6I08_RS01765', -1),
#   ('stage II sporulation protein M', 'DUF58 domain-containing protein')),
#  ('I6I08_RS01765',
#   399317,
#   400610,
#   ('I6I08_RS01765', -1),
#   ('I6I08_RS01765', -1),
#   ('DUF58 domain-containing protein', 'DUF58 domain-containing protein')),
#  ('I6I08_RS01765',
#   399317,
#   400610,
#   ('I6I08_RS01765', -1),
#   ('I6I08_RS01765', -1),
#   ('DUF58 domain-containing protein', 'DUF58 domain-containing protein')),
#  ('I6I08_RS01765_IG',
#   400610,
#   400675,
#   ('I6I08_RS01765', -1),
#   ('I6I08_RS01770', -1),
#   ('DUF58 domain-containing protein', 'MoxR family ATPase')),
#  ('I6I08_RS01770',
#   400675,
#   401779,
#   ('I6I08_RS01770', -1),
#   ('I6I08_RS01770', -1),
#   ('MoxR family ATPase', 'MoxR family ATPase')),
#  ('I6I08_RS01770',
#   400675,
#   401779,
#   ('I6I08_RS01770', -1),
#   ('I6I08_RS01770', -1),
#   ('MoxR family ATPase', 'MoxR family ATPase')),
#  ('I6I08_RS01775',
#   401775,
#   402987,
#   ('I6I08_RS01775', -1),
#   ('I6I08_RS01775', -1),
#   ('DUF4350 domain-containing protein', 'DUF4350 domain-containing protein')),
#  ('I6I08_RS01775',
#   401775,
#   402987,
#   ('I6I08_RS01775', -1),
#   ('I6I08_RS01775', -1),
#   ('DUF4350 domain-containing protein', 'DUF4350 domain-containing protein')),
#  ('I6I08_RS01780',
#   402983,
#   403670,
#   ('I6I08_RS01780', -1),
#   ('I6I08_RS01780', -1),
#   ('DUF4129 domain-containing protein', 'DUF4129 domain-containing protein')),
#  ('I6I08_RS01780',
#   402983,
#   403670,
#   ('I6I08_RS01780', -1),
#   ('I6I08_RS01780', -1),
#   ('DUF4129 domain-containing protein', 'DUF4129 domain-containing protein')),
#  ('I6I08_RS01780_IG',
#   403670,
#   403677,
#   ('I6I08_RS01780', -1),
#   ('I6I08_RS01785', -1),
#   ('DUF4129 domain-containing protein', 'hypothetical protein')),
#  ('I6I08_RS01785',
#   403677,
#   404997,
#   ('I6I08_RS01785', -1),
#   ('I6I08_RS01785', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS01785',
#   403677,
#   404997,
#   ('I6I08_RS01785', -1),
#   ('I6I08_RS01785', -1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ('I6I08_RS01785_IG',
#   404997,
#   405265,
#   ('I6I08_RS01785', -1),
#   ('I6I08_RS01790', 1),
#   ('hypothetical protein', 'response regulator transcription factor')),
#  ('I6I08_RS01790',
#   405265,
#   405946,
#   ('I6I08_RS01790', 1),
#   ('I6I08_RS01790', 1),
#   ('response regulator transcription factor',
#    'response regulator transcription factor')),
#  ('I6I08_RS01790',
#   405265,
#   405946,
#   ('I6I08_RS01790', 1),
#   ('I6I08_RS01790', 1),
#   ('response regulator transcription factor',
#    'response regulator transcription factor')),
#  ('I6I08_RS01790_IG',
#   405946,
#   405980,
#   ('I6I08_RS01790', 1),
#   ('I6I08_RS01795', 1),
#   ('response regulator transcription factor',
#    'HAMP domain-containing histidine kinase')),
#  ('I6I08_RS01795',
#   405980,
#   407864,
#   ('I6I08_RS01795', 1),
#   ('I6I08_RS01795', 1),
#   ('HAMP domain-containing histidine kinase',
#    'HAMP domain-containing histidine kinase')),
#  ('I6I08_RS01795',
#   405980,
#   407864,
#   ('I6I08_RS01795', 1),
#   ('I6I08_RS01795', 1),
#   ('HAMP domain-containing histidine kinase',
#    'HAMP domain-containing histidine kinase')),
#  ('I6I08_RS01800',
#   407860,
#   409666,
#   ('I6I08_RS01800', 1),
#   ('I6I08_RS01800', 1),
#   ('GerMN domain-containing protein', 'GerMN domain-containing protein')),
#  ('I6I08_RS01800',
#   407860,
#   409666,
#   ('I6I08_RS01800', 1),
#   ('I6I08_RS01800', 1),
#   ('GerMN domain-containing protein', 'GerMN domain-containing protein')),
#  ('I6I08_RS01800_IG',
#   409666,
#   409782,
#   ('I6I08_RS01800', 1),
#   ('I6I08_RS01805', -1),
#   ('GerMN domain-containing protein',
#    'ribosome-associated translation inhibitor RaiA')),
#  ('I6I08_RS01805',
#   409782,
#   410430,
#   ('I6I08_RS01805', -1),
#   ('I6I08_RS01805', -1),
#   ('ribosome-associated translation inhibitor RaiA',
#    'ribosome-associated translation inhibitor RaiA')),
#  ('I6I08_RS01805',
#   409782,
#   410430,
#   ('I6I08_RS01805', -1),
#   ('I6I08_RS01805', -1),
#   ('ribosome-associated translation inhibitor RaiA',
#    'ribosome-associated translation inhibitor RaiA')),
#  ('I6I08_RS01805_IG',
#   410430,
#   410646,
#   ('I6I08_RS01805', -1),
#   ('I6I08_RS01810', -1),
#   ('ribosome-associated translation inhibitor RaiA', 'ComF family protein')),
#  ('I6I08_RS01810',
#   410646,
#   411567,
#   ('I6I08_RS01810', -1),
#   ('I6I08_RS01810', -1),
#   ('ComF family protein', 'ComF family protein')),
#  ('I6I08_RS01810',
#   410646,
#   411567,
#   ('I6I08_RS01810', -1),
#   ('I6I08_RS01810', -1),
#   ('ComF family protein', 'ComF family protein')),
#  ('I6I08_RS01810_IG',
#   411567,
#   411897,
#   ('I6I08_RS01810', -1),
#   ('I6I08_RS01815', 1),
#   ('ComF family protein', 'preprotein translocase subunit SecA')),
#  ('I6I08_RS01815',
#   411897,
#   414729,
#   ('I6I08_RS01815', 1),
#   ('I6I08_RS01815', 1),
#   ('preprotein translocase subunit SecA',
#    'preprotein translocase subunit SecA')),
#  ('I6I08_RS01815',
#   411897,
#   414729,
#   ('I6I08_RS01815', 1),
#   ('I6I08_RS01815', 1),
#   ('preprotein translocase subunit SecA',
#    'preprotein translocase subunit SecA')),
#  ('I6I08_RS01815_IG',
#   414729,
#   414800,
#   ('I6I08_RS01815', 1),
#   ('I6I08_RS01820', -1),
#   ('preprotein translocase subunit SecA', 'Rv3235 family protein')),
#  ('I6I08_RS01820',
#   414800,
#   415316,
#   ('I6I08_RS01820', -1),
#   ('I6I08_RS01820', -1),
#   ('Rv3235 family protein', 'Rv3235 family protein')),
#  ('I6I08_RS01820',
#   414800,
#   415316,
#   ('I6I08_RS01820', -1),
#   ('I6I08_RS01820', -1),
#   ('Rv3235 family protein', 'Rv3235 family protein')),
#  ('I6I08_RS01820_IG',
#   415316,
#   415425,
#   ('I6I08_RS01820', -1),
#   ('I6I08_RS01825', -1),
#   ('Rv3235 family protein',
#    'LysM peptidoglycan-binding domain-containing protein')),
#  ('I6I08_RS01825',
#   415425,
#   416271,
#   ('I6I08_RS01825', -1),
#   ('I6I08_RS01825', -1),
#   ('LysM peptidoglycan-binding domain-containing protein',
#    'LysM peptidoglycan-binding domain-containing protein')),
#  ('I6I08_RS01825',
#   415425,
#   416271,
#   ('I6I08_RS01825', -1),
#   ('I6I08_RS01825', -1),
#   ('LysM peptidoglycan-binding domain-containing protein',
#    'LysM peptidoglycan-binding domain-containing protein')),
#  ('I6I08_RS01825_IG',
#   416271,
#   416451,
#   ('I6I08_RS01825', -1),
#   ('I6I08_RS01830', 1),
#   ('LysM peptidoglycan-binding domain-containing protein',
#    'Fis family transcriptional regulator')),
#  ('I6I08_RS01830',
#   416451,
#   417000,
#   ('I6I08_RS01830', 1),
#   ('I6I08_RS01830', 1),
#   ('Fis family transcriptional regulator',
#    'Fis family transcriptional regulator')),
#  ('I6I08_RS01830',
#   416451,
#   417000,
#   ('I6I08_RS01830', 1),
#   ('I6I08_RS01830', 1),
#   ('Fis family transcriptional regulator',
#    'Fis family transcriptional regulator')),
#  ('I6I08_RS01830_IG',
#   417000,
#   417023,
#   ('I6I08_RS01830', 1),
#   ('I6I08_RS01835', -1),
#   ('Fis family transcriptional regulator',
#    'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS01835',
#   417023,
#   417248,
#   ('I6I08_RS01835', -1),
#   ('I6I08_RS01835', -1),
#   ('helix-turn-helix domain-containing protein',
#    'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS01835',
#   417023,
#   417248,
#   ('I6I08_RS01835', -1),
#   ('I6I08_RS01835', -1),
#   ('helix-turn-helix domain-containing protein',
#    'helix-turn-helix domain-containing protein')),
#  ('I6I08_RS01835_IG',
#   417248,
#   417448,
#   ('I6I08_RS01835', -1),
#   ('I6I08_RS01840', 1),
#   ('helix-turn-helix domain-containing protein', 'hypothetical protein')),
#  ('I6I08_RS01840',
#   417448,
#   418129,
#   ('I6I08_RS01840', 1),
#   ('I6I08_RS01840', 1),
#   ('hypothetical protein', 'hypothetical protein')),
#  ...]

# %%
screen_dir = project_dir + '/R_Scape_Results_RFAM_v2'
screen_dir = project_dir + '/R_Scape_Initial_Screen_V2'
screen_dir = project_dir + '/R_Scape_Results_Downstream'
screen_dir = project_dir + '/R_Scape_Results_RProtein_Leprae'
seq_ids = util.list_dirs(screen_dir)
for id in seq_ids:
    if os.path.exists(screen_dir + '/' + str(id) + '/rscape_1.cov'):
        with open(screen_dir + '/' + str(id) + '/rscape_1.cov', 'r') as f:  
            num_pairs = 0
            e_values = []
            for l in f:
                if (not ('#' in l)):
                    a = l.split()
                    if len(a) > 3 and abs(int(a[2])-int(a[1])) > 3:    # Exclude covarying pairs less than 3 bp apart)
                        e_values.append(float(a[4]))
                        num_pairs +=1
        if len(e_values) > 0:
            tot = sum([math.log(x) for x  in e_values])
            num = len(e_values)
            combined_e_value = 1-chi2.cdf(-2*tot, 2*num)
        else:
            combined_e_value = 999
        if combined_e_value < 1:
            with open(screen_dir + '/' + str(id) + '/align_bh_2.sto', 'r') as g:  
                species_list = []
                for l in g:
                    if len(l) > 1 and (not ('#' in l)):
                        species_list.append(l.split()[0].split('/')[0])
            num_species = len(set(species_list))
            if 'NC_000962.3' in species_list:
                tb_ind = 'Y'
            else:
                tb_ind = 'N'
            #with open(screen_dir + '/' + str(id) + '/search_bh_1.sto', 'r') as g:  
            #    species_list = []
            #    for l in g:
            #        if len(l) > 1 and (not ('#' in l)):
            #            species_list.append(l.split()[0])
            #num_species_2 = len(set(species_list))
            structure_plotted = False
            if os.path.exists(screen_dir + '/' + str(id) + '/rscape_3.cacofold.R2R.sto.svg'):
                structure_plotted = True
                if num_species > 10 and combined_e_value < 1e-5:
                    print(id, product_dict[id], num_species, num_pairs, combined_e_value, structure_plotted, tb_ind)
# Out:
# NQ428_RS06720 50S ribosomal protein L10 526 15 0.0 True Y
# NQ428_RS07080 30S ribosomal protein S10 348 7 5.150324611236101e-13 True Y
# NQ428_RS07240 30S ribosomal protein S8 92 14 0.0 True N
# NQ428_RS07500 30S ribosomal protein S13 224 8 1.3988810110276972e-14 True Y
# NQ428_RS07665 50S ribosomal protein L13 139 4 1.4822347182974482e-07 True Y
# NQ428_RS12295 30S ribosomal protein S2 242 11 0.0 True Y

# %%
print(species_list)

# %%
def display_structure(locus):
    if os.path.exists(screen_dir + '/' + locus + '/rscape_3.cacofold.R2R.sto.svg'):
                return display.SVG(filename=screen_dir + '/' + locus + '/rscape_3.cacofold.R2R.sto.svg')

# %%
genome_record = next(SeqIO.parse(seq_dir + '/' + reference_species_filename, "genbank"))
product_dict = {}
for feature in genome_record.features:
    if not(feature.type == 'gene'):
        a = feature.qualifiers
        if a.get("locus_tag")!= None and a.get("product")!=None:
            product_dict[a.get("locus_tag")[0]] = a.get("product")[0]

# %%
from scipy.stats import chi2

# %%
def display_structure(locus):
    if os.path.exists(screen_dir + '/' + locus + '/rscape_3.cacofold.R2R.sto.svg'):
                return display.SVG(filename=screen_dir + '/' + locus + '/rscape_3.cacofold.R2R.sto.svg')

# %%
screen_dir = project_dir + '/R_Scape_Results_RFAM_v2'
screen_dir = project_dir + '/R_Scape_Initial_Screen_V2'
#screen_dir = project_dir + '/R_Scape_Results_Downstream'
seq_ids = util.list_dirs(screen_dir)
for id in seq_ids:
    if os.path.exists(screen_dir + '/' + str(id) + '/rscape_1.cov'):
        with open(screen_dir + '/' + str(id) + '/rscape_1.cov', 'r') as f:  
            num_pairs = 0
            e_values = []
            for l in f:
                if (not ('#' in l)):
                    a = l.split()
                    if len(a) > 3 and abs(int(a[2])-int(a[1])) > 3:    # Exclude covarying pairs less than 3 bp apart)
                        e_values.append(float(a[4]))
                        num_pairs +=1
        if len(e_values) > 0:
            tot = sum([math.log(x) for x  in e_values])
            num = len(e_values)
            combined_e_value = 1-chi2.cdf(-2*tot, 2*num)
        else:
            combined_e_value = 999
        if combined_e_value < 1:
            with open(screen_dir + '/' + str(id) + '/align_bh_2.sto', 'r') as g:  
                species_list = []
                for l in g:
                    if len(l) > 1 and (not ('#' in l)):
                        species_list.append(l.split()[0])
            num_species = len(set(species_list))
            
            #with open(screen_dir + '/' + str(id) + '/search_bh_1.sto', 'r') as g:  
            #    species_list = []
            #    for l in g:
            #        if len(l) > 1 and (not ('#' in l)):
            #            species_list.append(l.split()[0])
            #num_species_2 = len(set(species_list))
            structure_plotted = False
            if os.path.exists(screen_dir + '/' + str(id) + '/rscape_3.cacofold.R2R.sto.svg'):
                structure_plotted = True
                if num_species > 10 and combined_e_value < 1e-5:
                    print(id, product_dict[id], num_species, num_pairs, combined_e_value, structure_plotted)

# %%
display_structure('Rv0500A')

# %%
id = 'Rv2890c'
if os.path.exists(screen_dir + '/' + str(id) + '/hsummary_3.txt'):
        with open(screen_dir + '/' + str(id) + '/hsummary_3.txt', 'r') as f:  
            i = 0
            for l in f:
                if (not ('#' in l)):
                    a = l.split()[0].split('/')[0]
                    if '37Rv' in names_dict[a]:
                        print(l)
                        print(names_dict[a])
                    i+=1
print(i)

# %%
names_dict['NZ_CP066061.1']
# Out:
# 'Actinomyces oris'

# %%
filename_dict['NZ_CP066061.1']
# Out:
# 'GCF_016127955.1_ASM1612795v1_genomic.gbff'

# %%
class PDF(object):
  def __init__(self, pdf, size=(200,200)):
    self.pdf = pdf
    self.size = size

  def _repr_html_(self):
    return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(self.pdf, self.size)

  def _repr_latex_(self):
    return r'\includegraphics[width=1.0\textwidth]{{{0}}}'.format(self.pdf)

# %%
from IPython import display
display.SVG(filename=screen_dir+'/Rv0651'+'/rscape_3.cacofold.R2R.sto.svg')

# %%
util.reverse_complement(full_sequence[13016:13133])

# %%
if 1==1:
    translator = Translator()
    ids = ['GCF_016127955.1_ASM1612795v1_genomic.gbff']
    temp = []
    for id in ids:
        temp_1 = []
        for genome_record in SeqIO.parse(seq_dir + '/' + id, "genbank"):
            organism_name = genome_record.annotations['organism']
            accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
            organism_accession = organism_name.replace(' ', '_') + '_' + accession_ver
            print(accession_ver)
            if id == reference_species_filename:
                output = []
                features = []
                genome_record = next(SeqIO.parse(seq_dir + '/' + id, "genbank"))
                organism_name = genome_record.annotations['organism']
                accession_ver = genome_record.annotations['accessions'][0] + '.' + str(genome_record.annotations['sequence_version'])
                organism_accession = organism_name.replace(' ', '_') + '_' + accession_ver
                full_sequence = str(genome_record.seq)
                mycobrowser_df = pd.read_csv(datasets_dir+'/Mycobrowser_Release_4.csv')
                for i, r in mycobrowser_df.iterrows():
                    if r['Feature'] == 'CDS':
                        locus_tag = r['Locus']
                        accession_locus = accession_ver + '@' + locus_tag
                        start = int(r['Start'])-1
                        stop = int(r['Stop'])
                        if r['Strand'] == '+':
                            strand = 1
                        else:
                            strand = -1
                        product = r['Product']
                        translation = translator.translate_sequence(full_sequence[start:stop],strand, 0)[:-1]    #Remove stop codon from translation       
                        temp_1.append([organism_name, accession_ver, accession_locus, start, stop, strand, translation, locus_tag, product])     #Mycobrowser is 1-indexed
            else:
                if accession_ver == 'NZ_CP066061.1':
                    for feature in genome_record.features:
                        a = feature.qualifiers
                        print(a, feature.type)
                        if feature.type == 'CDS':
                            if a.get("locus_tag")!= None and a.get("translation")!= None:
                                locus_tag = a.get("locus_tag")[0]
                                accession_locus = accession_ver + '@' + locus_tag
                                translation = a.get("translation")[0]
                                if a.get("product")!= None:
                                    product = a.get("product")[0]
                                else:
                                    product = 'Product not in annotation'
                                temp_1.append([organism_name, accession_ver, accession_locus, int(feature.location.start), int(feature.location.end), int(feature.location.strand), translation, locus_tag, product])
            temp.append(temp_1)
    temp
# Out:
# NZ_CP066060.1
# NZ_CP066061.1
# OrderedDict([('organism', ['Actinomyces oris']), ('mol_type', ['genomic DNA']), ('strain', ['FDAARGOS_1051']), ('culture_collection', ['DSM:23056']), ('type_material', ['type strain of Actinomyces oris']), ('db_xref', ['taxon:544580']), ('plasmid', ['unnamed']), ('country', ['Germany: Braunschweig']), ('collected_by', ['DSMZ'])]) source
# OrderedDict([('gene', ['rrf']), ('locus_tag', ['I6I08_RS13285']), ('old_locus_tag', ['I6I08_13285']), ('db_xref', ['GeneID:64214272'])]) gene
# OrderedDict([('gene', ['rrf']), ('locus_tag', ['I6I08_RS13285']), ('old_locus_tag', ['I6I08_13285']), ('product', ['5S ribosomal RNA']), ('inference', ['COORDINATES: nucleotide motif:Rfam:14.4:RF00001', 'COORDINATES: profile:INFERNAL:1.1.1']), ('note', ['Derived by automated computational analysis using gene prediction method: cmsearch.']), ('db_xref', ['RFAM:RF00001', 'GeneID:64214272'])]) rRNA
# OrderedDict([('locus_tag', ['I6I08_RS13290']), ('old_locus_tag', ['I6I08_13290']), ('db_xref', ['GeneID:64214273'])]) gene
# OrderedDict([('locus_tag', ['I6I08_RS13290']), ('old_locus_tag', ['I6I08_13290']), ('product', ['23S ribosomal RNA']), ('inference', ['COORDINATES: nucleotide motif:Rfam:14.4:RF02541', 'COORDINATES: profile:INFERNAL:1.1.1']), ('note', ['Derived by automated computational analysis using gene prediction method: cmsearch.']), ('db_xref', ['RFAM:RF02541', 'GeneID:64214273'])]) rRNA

# %%
temp
# Out:
# [[], []]
