# %%
import subprocess
import os
from Bio.Blast import NCBIWWW, NCBIXML
import pandas as pd
from Comparative_Analysis import Utilities as util
from tqdm.auto import tqdm
from Bio import Entrez, SeqIO, AlignIO, pairwise2, Align, Seq, motifs
from Bio.Seq import Seq
from Bio.SeqFeature import SeqFeature, FeatureLocation
from joblib import Parallel, delayed
import math
import seaborn as sns

# %%
project_dir = 'D:/Project_Data/Project_6'
genome_datasets_dir = project_dir + '/Datasets/NCBI_Datasets'
refseq_dir = 'D:/NCBI_Dataset_Mycobacteria'
output_dir = project_dir + '/Output'
reference_species = 'GCF_000195955.2'
num_cores = 16
core_numbers = list(range(1, num_cores+1))

# %% [markdown]
# ##### Generate concatenated FASTA file for creating BLAST local database, together with dictionary of gene information

# %%
species_list = util.list_dirs(refseq_dir)
print(len(species_list))
# Out:
# 205

# %%
def parse_genome(num_subsets, subset_num, id_list):
    ids = util.chunk_list(id_list, num_subsets, subset_num)
    temp = []
    for id in ids:
        temp_1 = []
        genome_record = next(SeqIO.parse(refseq_dir + '/' + id + '/genomic.gbff', "genbank"))
        organism_name = genome_record.annotations['organism']
        full_sequence = genome_record.seq
        for feature in genome_record.features:
            a = feature.qualifiers
            if feature.type == 'CDS':
                if a.get("protein_id") != None and a.get("locus_tag")!= None and a.get("translation")!= None:
                    locus_tag = a.get("locus_tag")[0]
                    protein_id = a.get("protein_id")[0]
                    translation = a.get("translation")[0]
                    temp_1.append([id, organism_name, int(feature.location.start), int(feature.location.end), int(feature.location.strand), locus_tag, protein_id, translation])
        if len(temp_1) > 1000:
            temp.append(temp_1)
    return temp

# %%
parallel_output = Parallel(n_jobs=-1)(delayed(parse_genome)(num_cores, core_number, species_list) for core_number in core_numbers)
temp = [item for sublist in parallel_output for item in sublist]
gene_records = [item for sublist in temp for item in sublist]
reference_gene_records = [x for x in gene_records if x[0] == reference_species]

# %%
gene_record_lookup_dict = {}
for record in gene_records:
    gene_record_lookup_dict[record[0]+'|'+record[6]] = (record[1], record[2], record[3], record[4], record[5])

# %%
def produce_blast_file(record_list, output_filename):
    with open(output_filename, 'w',  newline='') as outfile:
        line_length = 60
        for record in tqdm(record_list):
            sequence = record[7]
            lines = []
            sequence_length = len(sequence)
            number_of_lines = math.ceil(sequence_length / line_length)
            lines.append(">" +record[0]+'|'+record[6]+ "\n")
            for i in range(number_of_lines):
                subsequence = sequence[i*line_length:(i+1)*line_length]
                lines.append(subsequence + "\n")
            outfile.write(''.join(lines))

# %%
produce_blast_file(gene_records, refseq_dir + '/all_myco_refseq.faa')
produce_blast_file(reference_gene_records, refseq_dir + '/reference_proteins.faa')

# %% [markdown]
# #### Build local blast database

# %%
#  Run the followint commands - to do: put in subprocess
#  makeblastdb -in all_myco_refseq.faa -dbtype prot -out myco_refseq    
#  Then copy all files produced into /BLAST/myco_refseq folder
#  Then change diretory to be in this and run              blastp -query d:\NCBI_Dataset_Mycobacteria\reference_proteins.faa -db myco_refseq -out blast_results.xml -evalue 0.001 -outfmt 5 -num_threads 16

# %%
#w_d = os.getcwd()
#os.chdir("D:/")
#subprocess.run('cd d:\\BLAST\\nr & blastp -query d:\\Protein_'+ref+'.faa -db nr -out nick.xml -evalue 0.001 -outfmt 5 -num_threads 16', shell=True, capture_output = True)
#os.chdir(w_d)

# %%
blast_results_list = []
result_handle = open("D:\\BLAST\\myco_refseq\\blast_results.xml")
blast_records = NCBIXML.parse(result_handle)
for blast_record in blast_records:
    for alignment in blast_record.alignments:
        for hsp in alignment.hsps:
            blast_results_list.append([blast_record.query, alignment.title, alignment.accession, alignment.length, hsp.expect, hsp.identities, hsp.query_start, hsp.query_end, hsp.sbjct_start, hsp.sbjct_end, hsp.strand, hsp.score])

# %%
blast_results_TB_genes_df = pd.DataFrame(blast_results_list, columns = ['query', 'title', 'accession', 'length', 'e_value', 'identities', 'query_start', 'query_end', 'subject_start','subject_end','subject_strand', 'score'])

# %%
blast_results_TB_genes_df[['ref_1','ref_2']] = blast_results_TB_genes_df['title'].str.split(' ', expand=True,)
blast_results_TB_genes_df['info']=  blast_results_TB_genes_df['ref_2'].map(gene_record_lookup_dict)
blast_results_TB_genes_df[['organism', 'start', 'end', 'strand', 'locus_tag']] = pd.DataFrame(blast_results_TB_genes_df['info'].tolist(), index=blast_results_TB_genes_df.index)
blast_results_TB_genes_df['q_info']=  blast_results_TB_genes_df['query'].map(gene_record_lookup_dict)
blast_results_TB_genes_df[['q_organism', 'q_start', 'q_end', 'q_strand', 'q_locus_tag']] = pd.DataFrame(blast_results_TB_genes_df['q_info'].tolist(), index=blast_results_TB_genes_df.index)

# %%
blast_results_TB_genes_df = blast_results_TB_genes_df.loc[blast_results_TB_genes_df.groupby(['organism','query'])['score'].idxmax()]
blast_results_TB_genes_df = blast_results_TB_genes_df.sort_values(['organism','q_start'])    #sort by target organisms
blast_results_TB_genes_df['q_previous_locus_tag']=blast_results_TB_genes_df['q_locus_tag'].shift(1)
blast_results_TB_genes_df['q_next_locus_tag']=blast_results_TB_genes_df['q_locus_tag'].shift(-1)
blast_results_TB_genes_df = blast_results_TB_genes_df.sort_values(['organism','start'])    #sort by target organisms
blast_results_TB_genes_df['previous_locus_tag']=blast_results_TB_genes_df['locus_tag'].shift(1)
blast_results_TB_genes_df['next_locus_tag']=blast_results_TB_genes_df['locus_tag'].shift(-1)

# %%
blast_results_TB_genes_df[0:4]
# Out:
#                            query  \
# 110  GCF_000195955.2|NP_214515.1
# 240  GCF_000195955.2|NP_214516.1
# 354  GCF_000195955.2|NP_214517.1
# 535  GCF_000195955.2|NP_214518.1
#
#                                                  title accession  length  \
# 110  gnl|BL_ORD_ID|424665 GCF_014643175.1|WP_188672...    424665     502
# 240  gnl|BL_ORD_ID|424666 GCF_014643175.1|WP_188672...    424666     395
# 354  gnl|BL_ORD_ID|424667 GCF_014643175.1|WP_188672...    424667     398
# 535  gnl|BL_ORD_ID|424668 GCF_014643175.1|WP_188672...    424668     185
#
#            e_value  identities  query_start  query_end  subject_start  \
# 110   0.000000e+00         331            1        506              1
# 240  3.001750e-164         238           10        402              3
# 354  2.741980e-125         204            1        376              1
# 535   3.175590e-55          95            9        187              8
#
#      subject_end subject_strand   score                 ref_1  \
# 110          501   (None, None)  1538.0  gnl|BL_ORD_ID|424665
# 240          395   (None, None)  1206.0  gnl|BL_ORD_ID|424666
# 354          373   (None, None)   948.0  gnl|BL_ORD_ID|424667
# 535          185   (None, None)   445.0  gnl|BL_ORD_ID|424668
#
#                               ref_2  \
# 110  GCF_014643175.1|WP_188672368.1
# 240  GCF_014643175.1|WP_188672371.1
# 354  GCF_014643175.1|WP_188672374.1
# 535  GCF_014643175.1|WP_188672378.1
#
#                                                   info  \
# 110  (Hoyosella rhizosphaerae, 1669907, 1671416, 1,...
# 240  (Hoyosella rhizosphaerae, 1672015, 1673203, 1,...
# 354  (Hoyosella rhizosphaerae, 1673209, 1674406, 1,...
# 535  (Hoyosella rhizosphaerae, 1674405, 1674963, 1,...
#
#                     organism    start      end  strand      locus_tag  \
# 110  Hoyosella rhizosphaerae  1669907  1671416       1  IEW73_RS07700
# 240  Hoyosella rhizosphaerae  1672015  1673203       1  IEW73_RS07705
# 354  Hoyosella rhizosphaerae  1673209  1674406       1  IEW73_RS07710
# 535  Hoyosella rhizosphaerae  1674405  1674963       1  IEW73_RS07715
#
#                                                 q_info  \
# 110  (Mycobacterium tuberculosis H37Rv, 0, 1524, 1,...
# 240  (Mycobacterium tuberculosis H37Rv, 2051, 3260,...
# 354  (Mycobacterium tuberculosis H37Rv, 3279, 4437,...
# 535  (Mycobacterium tuberculosis H37Rv, 4433, 4997,...
#
#                            q_organism  q_start  q_end  q_strand q_locus_tag  \
# 110  Mycobacterium tuberculosis H37Rv        0   1524         1      Rv0001
# 240  Mycobacterium tuberculosis H37Rv     2051   3260         1      Rv0002
# 354  Mycobacterium tuberculosis H37Rv     3279   4437         1      Rv0003
# 535  Mycobacterium tuberculosis H37Rv     4433   4997         1      Rv0004
#
#     q_previous_locus_tag q_next_locus_tag
# 110                  NaN           Rv0002
# 240               Rv0001           Rv0003
# 354               Rv0002           Rv0004
# 535               Rv0003           Rv0005

# %%
test = blast_results_TB_genes_df[blast_results_TB_genes_df.organism == 'Mycobacterium riyadhense']
#test = blast_results_TB_genes_df[blast_results_TB_genes_df.organism == 'Mycobacterium canettii CIPT 140010059']
#test = blast_results_TB_genes_df[blast_results_TB_genes_df.organism == 'Mycobacterium shinjukuense']

# %%
test2=test.loc[test.groupby('query')['score'].idxmax()]

# %%
len(test2)
# Out:
# 3554

# %%
sns.scatterplot(data = test2, x = 'q_start', y = 'start', s=2)
# Out:
# <AxesSubplot:xlabel='q_start', ylabel='start'>

# %%
test2[0:5]
# Out:
#                            query  \
# 9    GCF_000195955.2|NP_214515.1
# 132  GCF_000195955.2|NP_214516.1
# 253  GCF_000195955.2|NP_214517.1
# 435  GCF_000195955.2|NP_214518.1
# 560  GCF_000195955.2|NP_214519.2
#
#                                                  title accession  length  \
# 9    gnl|BL_ORD_ID|560619 GCF_905219535.1|WP_085253...    560619     507
# 132  gnl|BL_ORD_ID|565785 GCF_905219535.1|WP_204080...    565785     398
# 253  gnl|BL_ORD_ID|565784 GCF_905219535.1|WP_204080...    565784     385
# 435  gnl|BL_ORD_ID|565783 GCF_905219535.1|WP_085252...    565783     186
# 560  gnl|BL_ORD_ID|565782 GCF_905219535.1|WP_085253...    565782     677
#
#           e_value  identities  query_start  query_end  subject_start  \
# 9    0.000000e+00         452            1        507              1
# 132  0.000000e+00         360            1        402              1
# 253  0.000000e+00         315            1        383              1
# 435  2.292310e-87         143            1        187              1
# 560  0.000000e+00         610            1        675              1
#
#      subject_end subject_strand   score                 ref_1  \
# 9            507   (None, None)  2296.0  gnl|BL_ORD_ID|560619
# 132          398   (None, None)  1789.0  gnl|BL_ORD_ID|565785
# 253          383   (None, None)  1521.0  gnl|BL_ORD_ID|565784
# 435          186   (None, None)   656.0  gnl|BL_ORD_ID|565783
# 560          677   (None, None)  3170.0  gnl|BL_ORD_ID|565782
#
#                               ref_2  \
# 9    GCF_905219535.1|WP_085253042.1
# 132  GCF_905219535.1|WP_204080513.1
# 253  GCF_905219535.1|WP_204080512.1
# 435  GCF_905219535.1|WP_085252985.1
# 560  GCF_905219535.1|WP_085253043.1
#
#                                                   info  \
# 9    (Mycobacterium riyadhense, 262, 1786, -1, JX35...
# 132  (Mycobacterium riyadhense, 6242127, 6243324, -...
# 253  (Mycobacterium riyadhense, 6240968, 6242126, -...
# 435  (Mycobacterium riyadhense, 6240411, 6240972, -...
# 560  (Mycobacterium riyadhense, 6238133, 6240167, -...
#
#                      organism    start      end  strand      locus_tag  \
# 9    Mycobacterium riyadhense      262     1786      -1  JX352_RS00005
# 132  Mycobacterium riyadhense  6242127  6243324      -1  JX352_RS27600
# 253  Mycobacterium riyadhense  6240968  6242126      -1  JX352_RS27595
# 435  Mycobacterium riyadhense  6240411  6240972      -1  JX352_RS27590
# 560  Mycobacterium riyadhense  6238133  6240167      -1  JX352_RS27585
#
#                                                 q_info  \
# 9    (Mycobacterium tuberculosis H37Rv, 0, 1524, 1,...
# 132  (Mycobacterium tuberculosis H37Rv, 2051, 3260,...
# 253  (Mycobacterium tuberculosis H37Rv, 3279, 4437,...
# 435  (Mycobacterium tuberculosis H37Rv, 4433, 4997,...
# 560  (Mycobacterium tuberculosis H37Rv, 5239, 7267,...
#
#                            q_organism  q_start  q_end  q_strand q_locus_tag
# 9    Mycobacterium tuberculosis H37Rv        0   1524         1      Rv0001
# 132  Mycobacterium tuberculosis H37Rv     2051   3260         1      Rv0002
# 253  Mycobacterium tuberculosis H37Rv     3279   4437         1      Rv0003
# 435  Mycobacterium tuberculosis H37Rv     4433   4997         1      Rv0004
# 560  Mycobacterium tuberculosis H37Rv     5239   7267         1      Rv0005

# %%
blast_results_TB_genes_df.organism.unique()
# Out:
# array(['Mycobacterium canettii CIPT 140010059',
#        'Mycobacterium tuberculosis H37Rv', 'Mycobacterium spongiae',
#        'Mycobacterium basiliense', 'Mycobacterium conspicuum',
#        'Mycobacterium ostraviense', 'Mycobacterium kubicae',
#        'Mycobacterium shinjukuense', 'Mycobacterium malmoense',
#        'Mycobacterium riyadhense',
#        'Mycobacterium pseudoshottsii JCM 15466',
#        'Mycobacterium heidelbergense', 'Mycobacterium marinum',
#        'Mycobacterium haemophilum DSM 44634',
#        'Mycobacterium marseillense', 'Mycobacterium rhizamassiliense',
#        'Mycobacterium numidiamassiliense', 'Mycobacterium shottsii',
#        'Mycobacterium intracellulare ATCC 13950',
#        'Mycobacterium shigaense', 'Mycobacterium paraintracellulare',
#        'Mycobacterium mantenii', 'Mycobacterium europaeum',
#        'Mycobacterium branderi', 'Mycobacterium kansasii ATCC 12478',
#        'Mycobacterium simiae', 'Mycobacterium seoulense',
#        'Mycobacterium paraseoulense', 'Mycobacterium lacus',
#        'Mycobacterium florentinum', 'Mycobacterium noviomagense',
#        'Mycobacterium leprae', 'Mycobacterium stomatepiae',
#        'Mycobacterium parmense', 'Mycobacterium cookii',
#        'Mycobacterium vicinigordonae', 'Mycobacterium paragordonae',
#        'Mycobacterium lentiflavum', 'Mycobacterium heckeshornense',
#        'Mycolicibacterium aromaticivorans JS19b1 = JCM 16368',
#        'Mycolicibacterium farcinogenes', 'Mycobacterium senegalense',
#        'Mycolicibacterium anyangense', 'Mycolicibacterium aichiense',
#        'Mycolicibacterium septicum', 'Mycolicibacterium nivoides',
#        'Mycobacterium pallens', 'Mycolicibacterium houstonense',
#        'Mycolicibacterium boenickei', 'Mycolicibacterium setense',
#        'Mycolicibacterium chitae', 'Mycolicibacterium tokaiense',
#        'Mycolicibacterium mengxianglii', 'Mycolicibacterium fortuitum',
#        'Mycolicibacterium helvum', 'Mycolicibacterium sarraceniae',
#        'Mycobacterium doricum', 'Mycolicibacterium rutilum',
#        'Mycolicibacterium agri', 'Mycolicibacterium confluentis',
#        'Mycolicibacterium pulveris',
#        'Mycobacteroides chelonae CCUG 47445',
#        'Mycolicibacterium mageritense', 'Mycolicibacterium monacense',
#        'Mycolicibacterium gadium', 'Mycolicibacterium moriokaense',
#        'Mycobacteroides abscessus', 'Mycobacterium dioxanotrophicus',
#        'Mycobacteroides saopaulense', 'Mycobacteroides immunogenum',
#        'Mycolicibacterium gilvum Spyr1',
#        '[Mycobacterium] stephanolepidis', 'Mycobacteroides salmoniphilum',
#        'Mycolicibacterium smegmatis', 'Mycolicibacterium insubricum',
#        'Mycobacterium holsaticum', 'Mycolicibacterium arabiense',
#        'Mycolicibacterium vaccae 95051', 'Mycolicibacterium sediminis',
#        'Mycolicibacterium alvei', 'Mycolicibacterium austroafricanum',
#        'Mycolicibacterium vanbaalenii PYR-1',
#        'Mycobacterium frederiksbergense', 'Mycolicibacterium aurum',
#        'Mycolicibacterium madagascariense', 'Mycolicibacterium litorale',
#        'Mycolicibacterium parafortuitum', 'Mycolicibacterium neoaurum',
#        'Mycobacterium novum', 'Mycolicibacter algericus',
#        'Mycolicibacter sinensis', 'Mycolicibacterium poriferae',
#        'Mycolicibacterium psychrotolerans', 'Mycobacterium diernhoferi',
#        'Mycolicibacter terrae', 'Mycolicibacterium baixiangningiae',
#        'Mycolicibacterium duvalii', 'Mycolicibacter minnesotensis',
#        'Mycobacterium grossiae', 'Mycolicibacter hiberniae',
#        'Mycolicibacterium thermoresistibile',
#        'Mycolicibacterium cosmeticum',
#        'Mycolicibacterium fluoranthenivorans',
#        'Mycolicibacterium mucogenicum DSM 44124',
#        'Mycolicibacterium phocaicum', 'Mycolicibacterium aubagnense',
#        'Mycolicibacterium fallax',
#        'Mycolicibacterium hassiacum DSM 44199',
#        'Hoyosella subflava DQS3-9A1', 'Hoyosella rhizosphaerae',
#        'Mycobacterium asiaticum DSM 44297', 'Mycobacterium bourgelatii',
#        'Hoyosella suaedae', 'Mycolicibacterium lutetiense',
#        'Mycolicibacterium neworleansense'], dtype=object)

# %%
test.to_csv(project_dir + '/test_blast_df.csv')

# %%
#makeblastdb -in all_myco_refseq.fasta -dbtype prot -parse_seqids -out myco_refseq
